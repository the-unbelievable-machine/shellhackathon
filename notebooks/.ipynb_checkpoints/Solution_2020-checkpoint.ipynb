# %%
from math import sqrt
from itertools import product

import pandas as pd

from ortools.linear_solver import pywraplp
from ortools.init import pywrapinit

# %%
supply = pd.read_csv("../data/processed/exisiting_EV_infrastructure_2019.csv")

# %%
demand = pd.read_csv("../data/processed/Demand_Future.csv")

# %%
slow_charger = 200
slow_costs = 1.0*600
fast_charger = 400
fast_costs = 1.5*600

facilities = list(supply[["x_coordinate","y_coordinate"]].itertuples(index=False, name=None))
# real capacities
real_capacities = (supply["existing_num_SCS"]*slow_charger + supply["existing_num_FCS"]*fast_charger).tolist()
# maximum theoretical capacities
capacities = (supply["total_parking_slots"]*fast_charger).tolist()
# maximum slots for chargers
slots = supply["total_parking_slots"].tolist()

slow_slots = supply["existing_num_SCS"].tolist()
fast_slots = supply["existing_num_FCS"].tolist()

## For testing 
# slow_slots = [0]*len(facilities)
# fast_slots = [0]*len(facilities)

customers = list(demand[["x_coordinate","y_coordinate"]].itertuples(index=False, name=None))
demands = demand["2020"].tolist()

# %%
sum(capacities) > sum(demands), sum(capacities), sum(demands), sum(real_capacities)
# Out:
# (True, 1000000, 533059.8972105536, 473600.0)

# %%
# This function determines the Euclidean distance between a facility and customer sites.

def compute_distance(loc1, loc2):
    dx = loc1[0] - loc2[0]
    dy = loc1[1] - loc2[1]
    return sqrt(dx*dx + dy*dy)

# %%
# Compute key parameters of MIP model formulation

num_facilities = len(facilities)
num_customers = len(customers)
cartesian_prod = list(product(range(num_customers), range(num_facilities)))

# %%
# Compute distance matrix

distance = {(c,f): compute_distance(customers[c], facilities[f]) for c, f in cartesian_prod}

# %%
# solver = pywraplp.Solver.CreateSolver('CBC_MIXED_INTEGER_PROGRAMMING')
solver = pywraplp.Solver.CreateSolver('SCIP_MIXED_INTEGER_PROGRAMMING')

# %%
assign = {}
for i,j in distance.keys(): 
    assign[(i,j)] = solver.NumVar(0,solver.infinity(),"Assign")

# %%
# Constraint/Boundaries 2 
slow = {}
for j in range(num_facilities):
    slow[j] = solver.IntVar(slow_slots[j], solver.infinity(), "Slow")

fast = {}
for j in range(num_facilities):
    fast[j] = solver.IntVar(fast_slots[j], solver.infinity(), "Fast")

# %%
# Constraint 3 (slots)
for j in range(num_facilities):
    solver.Add(slow[j] + fast[j] <= slots[j])

# %%
# Constraint 5 (capacity constraints)
for j in range(num_facilities):
    solver.Add(sum(assign[(i,j)] for i in range(num_customers)) <= (slow[j]*200 + fast[j]*400))

# %%
# Constraint 6 (demand constraints)
for i in range(num_customers):
    solver.Add(sum(assign[(i,j)] for j in range(num_facilities)) == demands[i] )

# %%
objective = solver.Objective()

# %%
for j in range(num_facilities):
    objective.SetCoefficient(slow[j], slow_costs)
for j in range(num_facilities):
    objective.SetCoefficient(fast[j], fast_costs)

# %%
for i in range(num_customers):
    for j in range(num_facilities):
        objective.SetCoefficient(assign[(i,j)],distance[(i,j)])

# %%
objective.SetMinimization()

# %%
status = solver.Solve()

# %%
if status == pywraplp.Solver.OPTIMAL:
    print('Objective value =', solver.Objective().Value())
    print()
    print('Problem solved in %f milliseconds' % solver.wall_time())
    print('Problem solved in %d iterations' % solver.iterations())
    print('Problem solved in %d branch-and-bound nodes' % solver.nodes())
else:
    print('The problem does not have an optimal solution.')
# Out:
# Objective value = 3447334.1709842305
#
# Problem solved in 60193.000000 milliseconds
# Problem solved in 11332 iterations
# Problem solved in 1 branch-and-bound nodes

# %%
# display optimal values of decision variables
for j in range(num_facilities):
    print(f"\n Build {slow[j].solution_value() - slow_slots[j]} slow charger  and {fast[j].solution_value() - fast_slots[j]} fast charger at location {j + 1}.")
# Out:
#  Build 0.0 slow charger  and 0.0 fast charger at location 1.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 2.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 3.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 4.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 5.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 6.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 7.
#
#  Build 0.0 slow charger  and 11.0 fast charger at location 8.
#
#  Build 0.0 slow charger  and 4.0 fast charger at location 9.
#
#  Build 0.0 slow charger  and 6.0 fast charger at location 10.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 11.
#
#  Build 0.0 slow charger  and 8.0 fast charger at location 12.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 13.
#
#  Build 0.0 slow charger  and 6.0 fast charger at location 14.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 15.
#
#  Build 0.0 slow charger  and 3.0 fast charger at location 16.
#
#  Build 0.0 slow charger  and 5.0 fast charger at location 17.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 18.
#
#  Build 0.0 slow charger  and 7.0 fast charger at location 19.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 20.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 21.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 22.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 23.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 24.
#
#  Build 0.0 slow charger  and 7.0 fast charger at location 25.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 26.
#
#  Build 0.0 slow charger  and 5.0 fast charger at location 27.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 28.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 29.
#
#  Build 0.0 slow charger  and 4.0 fast charger at location 30.
#
#  Build 0.0 slow charger  and 7.0 fast charger at location 31.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 32.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 33.
#
#  Build 0.0 slow charger  and 1.0 fast charger at location 34.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 35.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 36.
#
#  Build 0.0 slow charger  and 10.0 fast charger at location 37.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 38.
#
#  Build 0.0 slow charger  and 5.0 fast charger at location 39.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 40.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 41.
#
#  Build 0.0 slow charger  and 2.0 fast charger at location 42.
#
#  Build 0.0 slow charger  and 4.0 fast charger at location 43.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 44.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 45.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 46.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 47.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 48.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 49.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 50.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 51.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 52.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 53.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 54.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 55.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 56.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 57.
#
#  Build 0.0 slow charger  and 2.0 fast charger at location 58.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 59.
#
#  Build 0.0 slow charger  and 11.0 fast charger at location 60.
#
#  Build 0.0 slow charger  and 4.0 fast charger at location 61.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 62.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 63.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 64.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 65.
#
#  Build 0.0 slow charger  and 3.0 fast charger at location 66.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 67.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 68.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 69.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 70.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 71.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 72.
#
#  Build 0.0 slow charger  and 2.0 fast charger at location 73.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 74.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 75.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 76.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 77.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 78.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 79.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 80.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 81.
#
#  Build 0.0 slow charger  and 7.0 fast charger at location 82.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 83.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 84.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 85.
#
#  Build 0.0 slow charger  and 6.0 fast charger at location 86.
#
#  Build 0.0 slow charger  and 5.0 fast charger at location 87.
#
#  Build 0.0 slow charger  and 13.0 fast charger at location 88.
#
#  Build 0.0 slow charger  and 1.0 fast charger at location 89.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 90.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 91.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 92.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 93.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 94.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 95.
#
#  Build 0.0 slow charger  and 5.0 fast charger at location 96.
#
#  Build 0.0 slow charger  and 3.0 fast charger at location 97.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 98.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 99.
#
#  Build 0.0 slow charger  and 11.0 fast charger at location 100.

# %%
# Shipments from facilities to customers.

for i, j in assign.keys():
    if (abs(assign[i, j].solution_value()) > 1e-6):
        print(f"\n Demand point {i + 1} receives {round(assign[i, j].solution_value(), 2)} of its demand {round(demands[i],2)} from parking slot {j + 1} .")
# Out:
#  Demand point 1 receives 27.16 of its demand 27.16 from parking slot 39 .
#
#  Demand point 2 receives 26.95 of its demand 26.95 from parking slot 39 .
#
#  Demand point 3 receives 25.93 of its demand 25.93 from parking slot 39 .
#
#  Demand point 4 receives 28.65 of its demand 28.65 from parking slot 39 .
#
#  Demand point 5 receives 29.72 of its demand 29.72 from parking slot 39 .
#
#  Demand point 6 receives 33.62 of its demand 33.62 from parking slot 39 .
#
#  Demand point 7 receives 34.74 of its demand 34.74 from parking slot 39 .
#
#  Demand point 8 receives 36.35 of its demand 36.35 from parking slot 39 .
#
#  Demand point 9 receives 42.32 of its demand 42.32 from parking slot 39 .
#
#  Demand point 10 receives 38.93 of its demand 38.93 from parking slot 39 .
#
#  Demand point 11 receives 44.87 of its demand 44.87 from parking slot 39 .
#
#  Demand point 12 receives 44.8 of its demand 44.8 from parking slot 39 .
#
#  Demand point 13 receives 41.29 of its demand 41.29 from parking slot 25 .
#
#  Demand point 14 receives 43.43 of its demand 43.43 from parking slot 25 .
#
#  Demand point 15 receives 36.25 of its demand 36.25 from parking slot 25 .
#
#  Demand point 16 receives 40.64 of its demand 40.64 from parking slot 25 .
#
#  Demand point 17 receives 42.23 of its demand 42.23 from parking slot 58 .
#
#  Demand point 18 receives 40.12 of its demand 40.12 from parking slot 58 .
#
#  Demand point 19 receives 40.51 of its demand 40.51 from parking slot 58 .
#
#  Demand point 20 receives 36.29 of its demand 36.29 from parking slot 61 .
#
#  Demand point 21 receives 40.41 of its demand 40.41 from parking slot 61 .
#
#  Demand point 22 receives 40.6 of its demand 40.6 from parking slot 61 .
#
#  Demand point 23 receives 40.77 of its demand 40.77 from parking slot 61 .
#
#  Demand point 24 receives 42.89 of its demand 42.89 from parking slot 61 .
#
#  Demand point 25 receives 38.49 of its demand 38.49 from parking slot 61 .
#
#  Demand point 26 receives 38.84 of its demand 38.84 from parking slot 61 .
#
#  Demand point 27 receives 34.45 of its demand 34.45 from parking slot 61 .
#
#  Demand point 28 receives 35.45 of its demand 35.45 from parking slot 61 .
#
#  Demand point 29 receives 36.37 of its demand 36.37 from parking slot 61 .
#
#  Demand point 30 receives 38.13 of its demand 38.13 from parking slot 61 .
#
#  Demand point 31 receives 45.03 of its demand 45.03 from parking slot 61 .
#
#  Demand point 32 receives 51.15 of its demand 51.15 from parking slot 61 .
#
#  Demand point 33 receives 66.7 of its demand 66.7 from parking slot 61 .
#
#  Demand point 34 receives 75.48 of its demand 75.48 from parking slot 61 .
#
#  Demand point 35 receives 89.94 of its demand 89.94 from parking slot 61 .
#
#  Demand point 36 receives 81.6 of its demand 81.6 from parking slot 61 .
#
#  Demand point 37 receives 88.08 of its demand 88.08 from parking slot 61 .
#
#  Demand point 38 receives 80.55 of its demand 80.55 from parking slot 61 .
#
#  Demand point 39 receives 84.49 of its demand 84.49 from parking slot 93 .
#
#  Demand point 40 receives 87.96 of its demand 87.96 from parking slot 93 .
#
#  Demand point 41 receives 152.76 of its demand 152.76 from parking slot 93 .
#
#  Demand point 42 receives 141.36 of its demand 141.36 from parking slot 93 .
#
#  Demand point 43 receives 124.67 of its demand 124.67 from parking slot 77 .
#
#  Demand point 44 receives 87.85 of its demand 87.85 from parking slot 77 .
#
#  Demand point 45 receives 73.7 of its demand 73.7 from parking slot 77 .
#
#  Demand point 46 receives 57.05 of its demand 57.05 from parking slot 77 .
#
#  Demand point 47 receives 55.67 of its demand 55.67 from parking slot 77 .
#
#  Demand point 48 receives 77.94 of its demand 77.94 from parking slot 77 .
#
#  Demand point 49 receives 71.05 of its demand 92.37 from parking slot 1 .
#
#  Demand point 49 receives 21.32 of its demand 92.37 from parking slot 11 .
#
#  Demand point 50 receives 81.24 of its demand 81.24 from parking slot 11 .
#
#  Demand point 51 receives 110.1 of its demand 110.1 from parking slot 11 .
#
#  Demand point 52 receives 142.36 of its demand 142.36 from parking slot 11 .
#
#  Demand point 53 receives 187.53 of its demand 187.53 from parking slot 11 .
#
#  Demand point 54 receives 125.77 of its demand 125.77 from parking slot 11 .
#
#  Demand point 55 receives 156.39 of its demand 156.39 from parking slot 11 .
#
#  Demand point 56 receives 111.31 of its demand 111.31 from parking slot 11 .
#
#  Demand point 57 receives 137.95 of its demand 137.95 from parking slot 11 .
#
#  Demand point 58 receives 92.44 of its demand 92.44 from parking slot 11 .
#
#  Demand point 59 receives 73.77 of its demand 73.77 from parking slot 36 .
#
#  Demand point 60 receives 74.93 of its demand 74.93 from parking slot 36 .
#
#  Demand point 61 receives 74.58 of its demand 74.58 from parking slot 36 .
#
#  Demand point 62 receives 59.34 of its demand 59.34 from parking slot 36 .
#
#  Demand point 63 receives 60.01 of its demand 60.01 from parking slot 36 .
#
#  Demand point 64 receives 63.42 of its demand 63.42 from parking slot 36 .
#
#  Demand point 65 receives 35.39 of its demand 35.39 from parking slot 39 .
#
#  Demand point 66 receives 26.88 of its demand 26.88 from parking slot 39 .
#
#  Demand point 67 receives 27.12 of its demand 27.12 from parking slot 39 .
#
#  Demand point 68 receives 29.89 of its demand 29.89 from parking slot 39 .
#
#  Demand point 69 receives 30.23 of its demand 30.23 from parking slot 39 .
#
#  Demand point 70 receives 30.15 of its demand 30.15 from parking slot 39 .
#
#  Demand point 71 receives 41.23 of its demand 41.23 from parking slot 39 .
#
#  Demand point 72 receives 55.94 of its demand 55.94 from parking slot 39 .
#
#  Demand point 73 receives 61.61 of its demand 61.61 from parking slot 39 .
#
#  Demand point 74 receives 52.49 of its demand 52.49 from parking slot 39 .
#
#  Demand point 75 receives 71.24 of its demand 71.24 from parking slot 39 .
#
#  Demand point 76 receives 58.29 of its demand 58.29 from parking slot 39 .
#
#  Demand point 77 receives 51.21 of its demand 51.21 from parking slot 25 .
#
#  Demand point 78 receives 34.2 of its demand 34.2 from parking slot 25 .
#
#  Demand point 79 receives 36.93 of its demand 36.93 from parking slot 25 .
#
#  Demand point 80 receives 47.24 of its demand 47.24 from parking slot 25 .
#
#  Demand point 81 receives 63.15 of its demand 63.15 from parking slot 58 .
#
#  Demand point 82 receives 55.37 of its demand 55.37 from parking slot 58 .
#
#  Demand point 83 receives 51.24 of its demand 51.24 from parking slot 58 .
#
#  Demand point 84 receives 48.7 of its demand 48.7 from parking slot 61 .
#
#  Demand point 85 receives 48.61 of its demand 48.61 from parking slot 61 .
#
#  Demand point 86 receives 48.68 of its demand 48.68 from parking slot 61 .
#
#  Demand point 87 receives 51.09 of its demand 51.09 from parking slot 61 .
#
#  Demand point 88 receives 61.77 of its demand 61.77 from parking slot 61 .
#
#  Demand point 89 receives 61.61 of its demand 61.61 from parking slot 61 .
#
#  Demand point 90 receives 47.51 of its demand 47.51 from parking slot 61 .
#
#  Demand point 91 receives 41.36 of its demand 41.36 from parking slot 61 .
#
#  Demand point 92 receives 37.29 of its demand 37.29 from parking slot 61 .
#
#  Demand point 93 receives 35.52 of its demand 35.52 from parking slot 61 .
#
#  Demand point 94 receives 37.97 of its demand 37.97 from parking slot 61 .
#
#  Demand point 95 receives 45.53 of its demand 45.53 from parking slot 61 .
#
#  Demand point 96 receives 51.37 of its demand 51.37 from parking slot 61 .
#
#  Demand point 97 receives 48.87 of its demand 48.87 from parking slot 61 .
#
#  Demand point 99 receives 80.78 of its demand 80.78 from parking slot 61 .
#
#  Demand point 100 receives 111.22 of its demand 111.22 from parking slot 61 .
#
#  Demand point 101 receives 136.85 of its demand 136.85 from parking slot 61 .
#
#  Demand point 102 receives 102.09 of its demand 102.09 from parking slot 93 .
#
#  Demand point 103 receives 129.38 of its demand 129.38 from parking slot 93 .
#
#  Demand point 104 receives 104.77 of its demand 104.77 from parking slot 93 .
#
#  Demand point 105 receives 179.2 of its demand 179.2 from parking slot 93 .
#
#  Demand point 106 receives 126.21 of its demand 126.21 from parking slot 77 .
#
#  Demand point 107 receives 119.65 of its demand 119.65 from parking slot 77 .
#
#  Demand point 108 receives 16.4 of its demand 16.4 from parking slot 77 .
#
#  Demand point 110 receives 78.48 of its demand 78.48 from parking slot 77 .
#
#  Demand point 111 receives 73.06 of its demand 73.06 from parking slot 77 .
#
#  Demand point 112 receives 79.18 of its demand 79.18 from parking slot 1 .
#
#  Demand point 113 receives 81.65 of its demand 81.65 from parking slot 1 .
#
#  Demand point 114 receives 76.97 of its demand 76.97 from parking slot 11 .
#
#  Demand point 115 receives 91.47 of its demand 91.47 from parking slot 11 .
#
#  Demand point 116 receives 145.81 of its demand 145.81 from parking slot 11 .
#
#  Demand point 117 receives 154.97 of its demand 154.97 from parking slot 11 .
#
#  Demand point 118 receives 81.32 of its demand 81.32 from parking slot 11 .
#
#  Demand point 119 receives 73.77 of its demand 73.77 from parking slot 11 .
#
#  Demand point 120 receives 93.56 of its demand 93.56 from parking slot 11 .
#
#  Demand point 121 receives 97.6 of its demand 97.6 from parking slot 11 .
#
#  Demand point 122 receives 78.63 of its demand 78.63 from parking slot 36 .
#
#  Demand point 123 receives 78.55 of its demand 78.55 from parking slot 36 .
#
#  Demand point 124 receives 75.87 of its demand 75.87 from parking slot 36 .
#
#  Demand point 125 receives 16.31 of its demand 16.31 from parking slot 36 .
#
#  Demand point 126 receives 14.29 of its demand 14.29 from parking slot 36 .
#
#  Demand point 127 receives 16.75 of its demand 16.75 from parking slot 36 .
#
#  Demand point 128 receives 65.21 of its demand 65.21 from parking slot 60 .
#
#  Demand point 129 receives 35.79 of its demand 35.79 from parking slot 39 .
#
#  Demand point 130 receives 32.49 of its demand 32.49 from parking slot 39 .
#
#  Demand point 131 receives 34.23 of its demand 34.23 from parking slot 39 .
#
#  Demand point 132 receives 34.97 of its demand 34.97 from parking slot 39 .
#
#  Demand point 133 receives 36.88 of its demand 36.88 from parking slot 39 .
#
#  Demand point 134 receives 35.84 of its demand 35.84 from parking slot 39 .
#
#  Demand point 135 receives 43.18 of its demand 43.18 from parking slot 39 .
#
#  Demand point 136 receives 58.56 of its demand 58.56 from parking slot 39 .
#
#  Demand point 137 receives 65.72 of its demand 65.72 from parking slot 39 .
#
#  Demand point 138 receives 58.44 of its demand 58.44 from parking slot 39 .
#
#  Demand point 139 receives 68.56 of its demand 68.56 from parking slot 39 .
#
#  Demand point 140 receives 66.68 of its demand 66.68 from parking slot 25 .
#
#  Demand point 141 receives 53.22 of its demand 53.22 from parking slot 25 .
#
#  Demand point 142 receives 42.36 of its demand 42.36 from parking slot 25 .
#
#  Demand point 143 receives 41.55 of its demand 41.55 from parking slot 25 .
#
#  Demand point 144 receives 53.16 of its demand 53.16 from parking slot 25 .
#
#  Demand point 145 receives 66.04 of its demand 66.04 from parking slot 58 .
#
#  Demand point 146 receives 58.73 of its demand 58.73 from parking slot 58 .
#
#  Demand point 147 receives 58.22 of its demand 58.22 from parking slot 58 .
#
#  Demand point 148 receives 51.02 of its demand 51.02 from parking slot 100 .
#
#  Demand point 149 receives 51.06 of its demand 51.06 from parking slot 61 .
#
#  Demand point 150 receives 54.7 of its demand 54.7 from parking slot 61 .
#
#  Demand point 151 receives 70.67 of its demand 70.67 from parking slot 61 .
#
#  Demand point 152 receives 80.8 of its demand 80.8 from parking slot 61 .
#
#  Demand point 153 receives 81.42 of its demand 81.42 from parking slot 61 .
#
#  Demand point 154 receives 59.31 of its demand 59.31 from parking slot 61 .
#
#  Demand point 155 receives 44.09 of its demand 44.09 from parking slot 61 .
#
#  Demand point 156 receives 43.4 of its demand 43.4 from parking slot 61 .
#
#  Demand point 157 receives 42.86 of its demand 42.86 from parking slot 61 .
#
#  Demand point 158 receives 42.54 of its demand 42.54 from parking slot 61 .
#
#  Demand point 159 receives 49.08 of its demand 49.08 from parking slot 61 .
#
#  Demand point 160 receives 55.59 of its demand 55.59 from parking slot 61 .
#
#  Demand point 161 receives 51.58 of its demand 51.58 from parking slot 61 .
#
#  Demand point 162 receives 73.12 of its demand 73.12 from parking slot 61 .
#
#  Demand point 163 receives 79.41 of its demand 79.41 from parking slot 61 .
#
#  Demand point 164 receives 66.12 of its demand 66.12 from parking slot 61 .
#
#  Demand point 165 receives 102.3 of its demand 102.3 from parking slot 61 .
#
#  Demand point 166 receives 132.54 of its demand 132.54 from parking slot 93 .
#
#  Demand point 167 receives 119.02 of its demand 119.02 from parking slot 93 .
#
#  Demand point 168 receives 96.74 of its demand 96.74 from parking slot 93 .
#
#  Demand point 169 receives 143.43 of its demand 143.43 from parking slot 93 .
#
#  Demand point 170 receives 116.26 of its demand 116.26 from parking slot 77 .
#
#  Demand point 171 receives 81.35 of its demand 81.35 from parking slot 77 .
#
#  Demand point 172 receives 83.43 of its demand 83.43 from parking slot 77 .
#
#  Demand point 176 receives 86.79 of its demand 86.79 from parking slot 1 .
#
#  Demand point 177 receives 102.07 of its demand 102.07 from parking slot 1 .
#
#  Demand point 178 receives 137.55 of its demand 137.55 from parking slot 11 .
#
#  Demand point 179 receives 109.01 of its demand 109.01 from parking slot 11 .
#
#  Demand point 180 receives 86.12 of its demand 86.12 from parking slot 11 .
#
#  Demand point 181 receives 72.57 of its demand 72.57 from parking slot 11 .
#
#  Demand point 182 receives 71.18 of its demand 71.18 from parking slot 11 .
#
#  Demand point 183 receives 74.88 of its demand 74.88 from parking slot 11 .
#
#  Demand point 184 receives 73.3 of its demand 73.3 from parking slot 11 .
#
#  Demand point 185 receives 63.15 of its demand 63.15 from parking slot 11 .
#
#  Demand point 186 receives 94.65 of its demand 94.65 from parking slot 36 .
#
#  Demand point 187 receives 85.01 of its demand 85.01 from parking slot 36 .
#
#  Demand point 188 receives 68.17 of its demand 68.17 from parking slot 36 .
#
#  Demand point 189 receives 1.84 of its demand 1.84 from parking slot 36 .
#
#  Demand point 190 receives 1.91 of its demand 1.91 from parking slot 36 .
#
#  Demand point 191 receives 2.16 of its demand 2.16 from parking slot 60 .
#
#  Demand point 192 receives 3.25 of its demand 3.25 from parking slot 60 .
#
#  Demand point 193 receives 42.59 of its demand 42.59 from parking slot 39 .
#
#  Demand point 194 receives 42.68 of its demand 42.68 from parking slot 39 .
#
#  Demand point 195 receives 54.34 of its demand 54.34 from parking slot 39 .
#
#  Demand point 196 receives 52.36 of its demand 52.36 from parking slot 39 .
#
#  Demand point 197 receives 40.53 of its demand 40.53 from parking slot 39 .
#
#  Demand point 198 receives 34.46 of its demand 34.46 from parking slot 39 .
#
#  Demand point 199 receives 35.35 of its demand 35.35 from parking slot 39 .
#
#  Demand point 200 receives 39.39 of its demand 39.39 from parking slot 39 .
#
#  Demand point 201 receives 43.49 of its demand 43.49 from parking slot 39 .
#
#  Demand point 202 receives 48.93 of its demand 48.93 from parking slot 39 .
#
#  Demand point 203 receives 55.5 of its demand 55.5 from parking slot 39 .
#
#  Demand point 204 receives 50.35 of its demand 50.35 from parking slot 25 .
#
#  Demand point 205 receives 48.29 of its demand 48.29 from parking slot 25 .
#
#  Demand point 206 receives 43.73 of its demand 43.73 from parking slot 25 .
#
#  Demand point 207 receives 49.55 of its demand 49.55 from parking slot 25 .
#
#  Demand point 208 receives 53.37 of its demand 53.37 from parking slot 25 .
#
#  Demand point 209 receives 50.67 of its demand 50.67 from parking slot 58 .
#
#  Demand point 210 receives 53.23 of its demand 53.23 from parking slot 58 .
#
#  Demand point 211 receives 48.16 of its demand 48.16 from parking slot 58 .
#
#  Demand point 212 receives 46.31 of its demand 46.31 from parking slot 100 .
#
#  Demand point 213 receives 46.38 of its demand 46.38 from parking slot 100 .
#
#  Demand point 214 receives 51.76 of its demand 51.76 from parking slot 100 .
#
#  Demand point 215 receives 63.88 of its demand 63.88 from parking slot 61 .
#
#  Demand point 216 receives 77.57 of its demand 77.57 from parking slot 61 .
#
#  Demand point 217 receives 80.0 of its demand 80.0 from parking slot 61 .
#
#  Demand point 218 receives 72.79 of its demand 72.79 from parking slot 75 .
#
#  Demand point 219 receives 1.5 of its demand 1.5 from parking slot 75 .
#
#  Demand point 220 receives 49.95 of its demand 49.95 from parking slot 75 .
#
#  Demand point 221 receives 49.06 of its demand 49.06 from parking slot 75 .
#
#  Demand point 222 receives 48.22 of its demand 48.22 from parking slot 75 .
#
#  Demand point 223 receives 47.85 of its demand 47.85 from parking slot 75 .
#
#  Demand point 224 receives 58.32 of its demand 58.32 from parking slot 75 .
#
#  Demand point 225 receives 32.76 of its demand 65.43 from parking slot 61 .
#
#  Demand point 225 receives 32.67 of its demand 65.43 from parking slot 75 .
#
#  Demand point 226 receives 77.61 of its demand 77.61 from parking slot 61 .
#
#  Demand point 227 receives 89.88 of its demand 89.88 from parking slot 61 .
#
#  Demand point 228 receives 57.24 of its demand 57.24 from parking slot 61 .
#
#  Demand point 229 receives 91.75 of its demand 91.75 from parking slot 93 .
#
#  Demand point 230 receives 100.77 of its demand 100.77 from parking slot 93 .
#
#  Demand point 231 receives 93.19 of its demand 93.19 from parking slot 93 .
#
#  Demand point 232 receives 99.38 of its demand 99.38 from parking slot 93 .
#
#  Demand point 233 receives 157.43 of its demand 157.43 from parking slot 93 .
#
#  Demand point 234 receives 172.89 of its demand 172.89 from parking slot 77 .
#
#  Demand point 235 receives 153.4 of its demand 153.4 from parking slot 77 .
#
#  Demand point 236 receives 165.09 of its demand 165.09 from parking slot 77 .
#
#  Demand point 237 receives 122.56 of its demand 122.56 from parking slot 77 .
#
#  Demand point 238 receives 45.86 of its demand 45.86 from parking slot 77 .
#
#  Demand point 240 receives 39.27 of its demand 39.27 from parking slot 1 .
#
#  Demand point 241 receives 122.42 of its demand 122.42 from parking slot 1 .
#
#  Demand point 242 receives 208.41 of its demand 208.41 from parking slot 1 .
#
#  Demand point 243 receives 209.95 of its demand 209.95 from parking slot 11 .
#
#  Demand point 244 receives 89.42 of its demand 89.42 from parking slot 11 .
#
#  Demand point 245 receives 76.48 of its demand 76.48 from parking slot 11 .
#
#  Demand point 246 receives 4.38 of its demand 4.38 from parking slot 11 .
#
#  Demand point 247 receives 76.96 of its demand 76.96 from parking slot 11 .
#
#  Demand point 248 receives 98.77 of its demand 98.77 from parking slot 11 .
#
#  Demand point 249 receives 80.67 of its demand 80.67 from parking slot 60 .
#
#  Demand point 250 receives 91.9 of its demand 91.9 from parking slot 36 .
#
#  Demand point 251 receives 85.81 of its demand 85.81 from parking slot 36 .
#
#  Demand point 252 receives 2.25 of its demand 2.25 from parking slot 36 .
#
#  Demand point 253 receives 1.96 of its demand 1.96 from parking slot 36 .
#
#  Demand point 254 receives 3.05 of its demand 3.05 from parking slot 36 .
#
#  Demand point 255 receives 3.95 of its demand 3.95 from parking slot 60 .
#
#  Demand point 256 receives 3.62 of its demand 3.62 from parking slot 60 .
#
#  Demand point 257 receives 49.37 of its demand 49.37 from parking slot 89 .
#
#  Demand point 258 receives 53.94 of its demand 53.94 from parking slot 39 .
#
#  Demand point 259 receives 63.62 of its demand 63.62 from parking slot 39 .
#
#  Demand point 260 receives 58.25 of its demand 58.25 from parking slot 39 .
#
#  Demand point 261 receives 46.29 of its demand 46.29 from parking slot 39 .
#
#  Demand point 262 receives 36.53 of its demand 36.53 from parking slot 39 .
#
#  Demand point 263 receives 34.66 of its demand 34.66 from parking slot 39 .
#
#  Demand point 264 receives 37.76 of its demand 37.76 from parking slot 39 .
#
#  Demand point 265 receives 45.11 of its demand 45.11 from parking slot 39 .
#
#  Demand point 266 receives 59.13 of its demand 59.13 from parking slot 39 .
#
#  Demand point 267 receives 62.73 of its demand 62.73 from parking slot 39 .
#
#  Demand point 268 receives 54.31 of its demand 54.31 from parking slot 25 .
#
#  Demand point 269 receives 48.19 of its demand 48.19 from parking slot 25 .
#
#  Demand point 270 receives 45.05 of its demand 45.05 from parking slot 25 .
#
#  Demand point 271 receives 42.42 of its demand 42.42 from parking slot 25 .
#
#  Demand point 272 receives 39.8 of its demand 39.8 from parking slot 25 .
#
#  Demand point 273 receives 37.93 of its demand 37.93 from parking slot 58 .
#
#  Demand point 274 receives 44.11 of its demand 44.11 from parking slot 58 .
#
#  Demand point 275 receives 6.3 of its demand 42.18 from parking slot 58 .
#
#  Demand point 275 receives 35.88 of its demand 42.18 from parking slot 100 .
#
#  Demand point 276 receives 40.62 of its demand 40.62 from parking slot 100 .
#
#  Demand point 277 receives 44.09 of its demand 44.09 from parking slot 100 .
#
#  Demand point 278 receives 48.78 of its demand 48.78 from parking slot 100 .
#
#  Demand point 279 receives 63.59 of its demand 63.59 from parking slot 100 .
#
#  Demand point 280 receives 78.12 of its demand 78.12 from parking slot 100 .
#
#  Demand point 281 receives 77.04 of its demand 77.04 from parking slot 61 .
#
#  Demand point 282 receives 73.86 of its demand 73.86 from parking slot 75 .
#
#  Demand point 283 receives 71.35 of its demand 71.35 from parking slot 75 .
#
#  Demand point 284 receives 66.71 of its demand 66.71 from parking slot 75 .
#
#  Demand point 285 receives 60.62 of its demand 60.62 from parking slot 75 .
#
#  Demand point 286 receives 59.67 of its demand 59.67 from parking slot 75 .
#
#  Demand point 287 receives 68.29 of its demand 68.29 from parking slot 75 .
#
#  Demand point 288 receives 73.12 of its demand 73.12 from parking slot 75 .
#
#  Demand point 289 receives 71.18 of its demand 71.18 from parking slot 75 .
#
#  Demand point 290 receives 80.34 of its demand 80.34 from parking slot 75 .
#
#  Demand point 291 receives 93.87 of its demand 93.87 from parking slot 75 .
#
#  Demand point 292 receives 89.2 of its demand 89.2 from parking slot 75 .
#
#  Demand point 293 receives 162.18 of its demand 162.18 from parking slot 93 .
#
#  Demand point 294 receives 113.07 of its demand 113.07 from parking slot 93 .
#
#  Demand point 295 receives 163.07 of its demand 163.07 from parking slot 93 .
#
#  Demand point 296 receives 193.96 of its demand 193.96 from parking slot 93 .
#
#  Demand point 297 receives 212.64 of its demand 212.64 from parking slot 93 .
#
#  Demand point 298 receives 269.64 of its demand 269.64 from parking slot 77 .
#
#  Demand point 299 receives 212.27 of its demand 212.27 from parking slot 77 .
#
#  Demand point 300 receives 254.27 of its demand 254.27 from parking slot 77 .
#
#  Demand point 301 receives 240.89 of its demand 240.89 from parking slot 77 .
#
#  Demand point 302 receives 186.45 of its demand 186.45 from parking slot 96 .
#
#  Demand point 303 receives 120.71 of its demand 120.71 from parking slot 1 .
#
#  Demand point 304 receives 125.82 of its demand 125.82 from parking slot 1 .
#
#  Demand point 305 receives 168.6 of its demand 168.6 from parking slot 1 .
#
#  Demand point 306 receives 236.47 of its demand 236.47 from parking slot 1 .
#
#  Demand point 307 receives 171.63 of its demand 171.63 from parking slot 11 .
#
#  Demand point 308 receives 93.5 of its demand 93.5 from parking slot 11 .
#
#  Demand point 309 receives 77.61 of its demand 77.61 from parking slot 11 .
#
#  Demand point 310 receives 8.25 of its demand 8.25 from parking slot 11 .
#
#  Demand point 311 receives 73.61 of its demand 73.61 from parking slot 11 .
#
#  Demand point 312 receives 72.82 of its demand 72.82 from parking slot 60 .
#
#  Demand point 313 receives 140.11 of its demand 140.11 from parking slot 36 .
#
#  Demand point 314 receives 108.51 of its demand 108.51 from parking slot 36 .
#
#  Demand point 315 receives 66.63 of its demand 66.63 from parking slot 36 .
#
#  Demand point 316 receives 1.75 of its demand 1.75 from parking slot 36 .
#
#  Demand point 317 receives 1.98 of its demand 1.98 from parking slot 36 .
#
#  Demand point 318 receives 2.67 of its demand 2.67 from parking slot 60 .
#
#  Demand point 319 receives 6.25 of its demand 6.25 from parking slot 60 .
#
#  Demand point 320 receives 6.74 of its demand 6.74 from parking slot 60 .
#
#  Demand point 321 receives 46.87 of its demand 46.87 from parking slot 89 .
#
#  Demand point 322 receives 50.68 of its demand 50.68 from parking slot 89 .
#
#  Demand point 323 receives 49.22 of its demand 49.22 from parking slot 39 .
#
#  Demand point 324 receives 43.83 of its demand 43.83 from parking slot 39 .
#
#  Demand point 325 receives 34.69 of its demand 34.69 from parking slot 39 .
#
#  Demand point 326 receives 36.51 of its demand 36.51 from parking slot 39 .
#
#  Demand point 327 receives 38.41 of its demand 38.41 from parking slot 39 .
#
#  Demand point 328 receives 38.97 of its demand 38.97 from parking slot 39 .
#
#  Demand point 329 receives 51.04 of its demand 51.04 from parking slot 39 .
#
#  Demand point 330 receives 65.84 of its demand 65.84 from parking slot 39 .
#
#  Demand point 331 receives 74.91 of its demand 74.91 from parking slot 39 .
#
#  Demand point 332 receives 72.24 of its demand 72.24 from parking slot 25 .
#
#  Demand point 333 receives 51.96 of its demand 51.96 from parking slot 25 .
#
#  Demand point 334 receives 53.13 of its demand 53.13 from parking slot 25 .
#
#  Demand point 335 receives 46.65 of its demand 46.65 from parking slot 25 .
#
#  Demand point 336 receives 39.12 of its demand 39.12 from parking slot 25 .
#
#  Demand point 337 receives 37.9 of its demand 37.9 from parking slot 58 .
#
#  Demand point 338 receives 38.16 of its demand 38.16 from parking slot 58 .
#
#  Demand point 339 receives 39.42 of its demand 39.42 from parking slot 100 .
#
#  Demand point 340 receives 39.87 of its demand 39.87 from parking slot 100 .
#
#  Demand point 341 receives 42.14 of its demand 42.14 from parking slot 100 .
#
#  Demand point 342 receives 51.52 of its demand 51.52 from parking slot 100 .
#
#  Demand point 343 receives 50.71 of its demand 50.71 from parking slot 100 .
#
#  Demand point 344 receives 69.45 of its demand 69.45 from parking slot 100 .
#
#  Demand point 345 receives 66.22 of its demand 66.22 from parking slot 100 .
#
#  Demand point 346 receives 34.16 of its demand 65.16 from parking slot 75 .
#
#  Demand point 346 receives 31.0 of its demand 65.16 from parking slot 100 .
#
#  Demand point 347 receives 52.83 of its demand 52.83 from parking slot 75 .
#
#  Demand point 348 receives 51.89 of its demand 51.89 from parking slot 75 .
#
#  Demand point 349 receives 53.6 of its demand 53.6 from parking slot 75 .
#
#  Demand point 350 receives 76.92 of its demand 76.92 from parking slot 75 .
#
#  Demand point 351 receives 79.82 of its demand 79.82 from parking slot 75 .
#
#  Demand point 352 receives 88.05 of its demand 88.05 from parking slot 75 .
#
#  Demand point 353 receives 87.58 of its demand 87.58 from parking slot 75 .
#
#  Demand point 354 receives 97.19 of its demand 97.19 from parking slot 75 .
#
#  Demand point 355 receives 94.93 of its demand 94.93 from parking slot 75 .
#
#  Demand point 356 receives 97.15 of its demand 97.15 from parking slot 75 .
#
#  Demand point 357 receives 138.83 of its demand 138.83 from parking slot 93 .
#
#  Demand point 358 receives 151.2 of its demand 151.2 from parking slot 93 .
#
#  Demand point 359 receives 209.24 of its demand 209.24 from parking slot 93 .
#
#  Demand point 360 receives 288.83 of its demand 288.83 from parking slot 93 .
#
#  Demand point 361 receives 281.63 of its demand 281.63 from parking slot 93 .
#
#  Demand point 362 receives 266.01 of its demand 266.01 from parking slot 93 .
#
#  Demand point 363 receives 161.67 of its demand 289.48 from parking slot 77 .
#
#  Demand point 363 receives 127.81 of its demand 289.48 from parking slot 93 .
#
#  Demand point 364 receives 229.73 of its demand 229.73 from parking slot 77 .
#
#  Demand point 365 receives 184.79 of its demand 184.79 from parking slot 96 .
#
#  Demand point 366 receives 208.7 of its demand 208.7 from parking slot 96 .
#
#  Demand point 367 receives 169.01 of its demand 169.01 from parking slot 1 .
#
#  Demand point 368 receives 167.4 of its demand 167.4 from parking slot 1 .
#
#  Demand point 369 receives 132.3 of its demand 132.3 from parking slot 1 .
#
#  Demand point 370 receives 166.85 of its demand 166.85 from parking slot 1 .
#
#  Demand point 371 receives 138.04 of its demand 138.04 from parking slot 1 .
#
#  Demand point 372 receives 105.57 of its demand 105.57 from parking slot 11 .
#
#  Demand point 373 receives 129.16 of its demand 129.16 from parking slot 11 .
#
#  Demand point 374 receives 116.32 of its demand 116.32 from parking slot 11 .
#
#  Demand point 375 receives 115.0 of its demand 115.0 from parking slot 11 .
#
#  Demand point 376 receives 119.86 of its demand 119.86 from parking slot 60 .
#
#  Demand point 377 receives 155.83 of its demand 155.83 from parking slot 36 .
#
#  Demand point 378 receives 136.35 of its demand 136.35 from parking slot 36 .
#
#  Demand point 379 receives 82.11 of its demand 82.11 from parking slot 36 .
#
#  Demand point 380 receives 5.49 of its demand 5.49 from parking slot 36 .
#
#  Demand point 381 receives 5.5 of its demand 5.5 from parking slot 60 .
#
#  Demand point 382 receives 2.69 of its demand 2.69 from parking slot 60 .
#
#  Demand point 383 receives 7.69 of its demand 7.69 from parking slot 60 .
#
#  Demand point 384 receives 4.22 of its demand 4.22 from parking slot 60 .
#
#  Demand point 385 receives 67.3 of its demand 67.3 from parking slot 89 .
#
#  Demand point 386 receives 63.1 of its demand 63.1 from parking slot 89 .
#
#  Demand point 387 receives 46.14 of its demand 46.14 from parking slot 89 .
#
#  Demand point 388 receives 17.92 of its demand 17.92 from parking slot 39 .
#
#  Demand point 389 receives 34.08 of its demand 34.08 from parking slot 39 .
#
#  Demand point 390 receives 35.32 of its demand 35.32 from parking slot 39 .
#
#  Demand point 391 receives 40.45 of its demand 40.45 from parking slot 39 .
#
#  Demand point 392 receives 45.87 of its demand 45.87 from parking slot 39 .
#
#  Demand point 393 receives 53.01 of its demand 53.01 from parking slot 39 .
#
#  Demand point 394 receives 77.04 of its demand 77.04 from parking slot 39 .
#
#  Demand point 395 receives 78.72 of its demand 78.72 from parking slot 25 .
#
#  Demand point 396 receives 76.79 of its demand 76.79 from parking slot 25 .
#
#  Demand point 397 receives 56.9 of its demand 56.9 from parking slot 25 .
#
#  Demand point 398 receives 55.58 of its demand 55.58 from parking slot 25 .
#
#  Demand point 399 receives 47.65 of its demand 47.65 from parking slot 25 .
#
#  Demand point 400 receives 44.24 of its demand 44.24 from parking slot 25 .
#
#  Demand point 401 receives 41.44 of its demand 41.44 from parking slot 58 .
#
#  Demand point 402 receives 39.28 of its demand 39.28 from parking slot 58 .
#
#  Demand point 403 receives 39.92 of its demand 39.92 from parking slot 100 .
#
#  Demand point 404 receives 43.78 of its demand 43.78 from parking slot 100 .
#
#  Demand point 405 receives 44.7 of its demand 44.7 from parking slot 100 .
#
#  Demand point 406 receives 45.17 of its demand 45.17 from parking slot 100 .
#
#  Demand point 407 receives 68.28 of its demand 68.28 from parking slot 100 .
#
#  Demand point 408 receives 76.01 of its demand 76.01 from parking slot 100 .
#
#  Demand point 409 receives 76.67 of its demand 76.67 from parking slot 100 .
#
#  Demand point 410 receives 78.34 of its demand 78.34 from parking slot 100 .
#
#  Demand point 411 receives 72.08 of its demand 72.08 from parking slot 100 .
#
#  Demand point 412 receives 76.33 of its demand 76.33 from parking slot 75 .
#
#  Demand point 413 receives 82.83 of its demand 82.83 from parking slot 75 .
#
#  Demand point 414 receives 86.26 of its demand 86.26 from parking slot 75 .
#
#  Demand point 415 receives 82.43 of its demand 82.43 from parking slot 75 .
#
#  Demand point 416 receives 86.56 of its demand 86.56 from parking slot 75 .
#
#  Demand point 417 receives 81.03 of its demand 81.03 from parking slot 75 .
#
#  Demand point 419 receives 82.4 of its demand 82.4 from parking slot 75 .
#
#  Demand point 420 receives 92.31 of its demand 92.31 from parking slot 75 .
#
#  Demand point 421 receives 140.76 of its demand 140.76 from parking slot 93 .
#
#  Demand point 422 receives 294.59 of its demand 294.59 from parking slot 93 .
#
#  Demand point 423 receives 299.42 of its demand 299.42 from parking slot 93 .
#
#  Demand point 424 receives 298.11 of its demand 298.11 from parking slot 93 .
#
#  Demand point 425 receives 260.39 of its demand 260.39 from parking slot 93 .
#
#  Demand point 426 receives 266.98 of its demand 266.98 from parking slot 93 .
#
#  Demand point 427 receives 237.6 of its demand 237.6 from parking slot 70 .
#
#  Demand point 428 receives 238.79 of its demand 238.79 from parking slot 70 .
#
#  Demand point 429 receives 212.81 of its demand 212.81 from parking slot 96 .
#
#  Demand point 430 receives 190.74 of its demand 190.74 from parking slot 96 .
#
#  Demand point 431 receives 272.89 of its demand 272.89 from parking slot 1 .
#
#  Demand point 432 receives 178.74 of its demand 178.74 from parking slot 1 .
#
#  Demand point 433 receives 83.26 of its demand 83.26 from parking slot 1 .
#
#  Demand point 434 receives 85.96 of its demand 85.96 from parking slot 1 .
#
#  Demand point 435 receives 84.6 of its demand 84.6 from parking slot 1 .
#
#  Demand point 436 receives 119.05 of its demand 119.05 from parking slot 11 .
#
#  Demand point 437 receives 86.93 of its demand 86.93 from parking slot 11 .
#
#  Demand point 438 receives 77.76 of its demand 77.76 from parking slot 11 .
#
#  Demand point 439 receives 75.05 of its demand 75.05 from parking slot 60 .
#
#  Demand point 440 receives 89.16 of its demand 89.16 from parking slot 60 .
#
#  Demand point 441 receives 139.3 of its demand 139.3 from parking slot 36 .
#
#  Demand point 442 receives 147.46 of its demand 147.46 from parking slot 36 .
#
#  Demand point 443 receives 136.61 of its demand 136.61 from parking slot 36 .
#
#  Demand point 444 receives 1.48 of its demand 95.03 from parking slot 36 .
#
#  Demand point 444 receives 93.55 of its demand 95.03 from parking slot 60 .
#
#  Demand point 445 receives 80.27 of its demand 80.27 from parking slot 60 .
#
#  Demand point 446 receives 93.25 of its demand 93.25 from parking slot 60 .
#
#  Demand point 447 receives 62.8 of its demand 62.8 from parking slot 60 .
#
#  Demand point 448 receives 0.45 of its demand 0.45 from parking slot 60 .
#
#  Demand point 449 receives 66.41 of its demand 66.41 from parking slot 89 .
#
#  Demand point 450 receives 73.92 of its demand 73.92 from parking slot 89 .
#
#  Demand point 451 receives 46.98 of its demand 46.98 from parking slot 89 .
#
#  Demand point 452 receives 18.47 of its demand 18.47 from parking slot 89 .
#
#  Demand point 453 receives 34.95 of its demand 34.95 from parking slot 39 .
#
#  Demand point 454 receives 37.38 of its demand 37.38 from parking slot 39 .
#
#  Demand point 455 receives 42.5 of its demand 42.5 from parking slot 39 .
#
#  Demand point 456 receives 49.72 of its demand 49.72 from parking slot 39 .
#
#  Demand point 457 receives 46.96 of its demand 46.96 from parking slot 39 .
#
#  Demand point 458 receives 50.83 of its demand 50.83 from parking slot 39 .
#
#  Demand point 459 receives 61.58 of its demand 61.58 from parking slot 25 .
#
#  Demand point 460 receives 74.15 of its demand 74.15 from parking slot 25 .
#
#  Demand point 461 receives 70.22 of its demand 70.22 from parking slot 25 .
#
#  Demand point 462 receives 67.86 of its demand 67.86 from parking slot 25 .
#
#  Demand point 463 receives 21.9 of its demand 21.9 from parking slot 25 .
#
#  Demand point 464 receives 58.16 of its demand 58.16 from parking slot 25 .
#
#  Demand point 465 receives 52.55 of its demand 52.55 from parking slot 58 .
#
#  Demand point 466 receives 47.14 of its demand 47.14 from parking slot 58 .
#
#  Demand point 467 receives 46.68 of its demand 46.68 from parking slot 100 .
#
#  Demand point 468 receives 49.01 of its demand 49.01 from parking slot 100 .
#
#  Demand point 469 receives 45.91 of its demand 45.91 from parking slot 100 .
#
#  Demand point 470 receives 43.48 of its demand 43.48 from parking slot 100 .
#
#  Demand point 471 receives 56.14 of its demand 56.14 from parking slot 100 .
#
#  Demand point 472 receives 81.37 of its demand 81.37 from parking slot 100 .
#
#  Demand point 473 receives 67.59 of its demand 67.59 from parking slot 100 .
#
#  Demand point 474 receives 64.03 of its demand 64.03 from parking slot 100 .
#
#  Demand point 475 receives 82.41 of its demand 82.41 from parking slot 100 .
#
#  Demand point 476 receives 76.67 of its demand 76.67 from parking slot 100 .
#
#  Demand point 477 receives 72.78 of its demand 72.78 from parking slot 75 .
#
#  Demand point 478 receives 74.58 of its demand 74.58 from parking slot 75 .
#
#  Demand point 479 receives 80.51 of its demand 80.51 from parking slot 75 .
#
#  Demand point 480 receives 79.22 of its demand 79.22 from parking slot 75 .
#
#  Demand point 481 receives 75.46 of its demand 75.46 from parking slot 75 .
#
#  Demand point 482 receives 80.72 of its demand 80.72 from parking slot 75 .
#
#  Demand point 483 receives 79.9 of its demand 79.9 from parking slot 75 .
#
#  Demand point 484 receives 117.38 of its demand 117.38 from parking slot 70 .
#
#  Demand point 485 receives 125.6 of its demand 125.6 from parking slot 70 .
#
#  Demand point 486 receives 19.8 of its demand 135.7 from parking slot 70 .
#
#  Demand point 486 receives 115.9 of its demand 135.7 from parking slot 93 .
#
#  Demand point 487 receives 149.87 of its demand 149.87 from parking slot 93 .
#
#  Demand point 488 receives 249.26 of its demand 249.26 from parking slot 93 .
#
#  Demand point 489 receives 274.83 of its demand 274.83 from parking slot 70 .
#
#  Demand point 490 receives 301.74 of its demand 301.74 from parking slot 70 .
#
#  Demand point 491 receives 301.28 of its demand 301.28 from parking slot 70 .
#
#  Demand point 492 receives 272.19 of its demand 272.19 from parking slot 70 .
#
#  Demand point 493 receives 224.39 of its demand 224.39 from parking slot 96 .
#
#  Demand point 494 receives 262.39 of its demand 262.39 from parking slot 96 .
#
#  Demand point 495 receives 228.12 of its demand 276.81 from parking slot 1 .
#
#  Demand point 495 receives 48.69 of its demand 276.81 from parking slot 96 .
#
#  Demand point 496 receives 177.0 of its demand 177.0 from parking slot 1 .
#
#  Demand point 497 receives 84.06 of its demand 84.06 from parking slot 1 .
#
#  Demand point 498 receives 81.68 of its demand 81.68 from parking slot 1 .
#
#  Demand point 499 receives 80.26 of its demand 80.26 from parking slot 1 .
#
#  Demand point 500 receives 77.72 of its demand 77.72 from parking slot 1 .
#
#  Demand point 501 receives 78.48 of its demand 78.48 from parking slot 1 .
#
#  Demand point 502 receives 84.49 of its demand 84.49 from parking slot 60 .
#
#  Demand point 503 receives 89.09 of its demand 89.09 from parking slot 60 .
#
#  Demand point 504 receives 171.66 of its demand 171.66 from parking slot 60 .
#
#  Demand point 505 receives 164.44 of its demand 164.44 from parking slot 36 .
#
#  Demand point 506 receives 89.7 of its demand 89.7 from parking slot 36 .
#
#  Demand point 507 receives 82.31 of its demand 82.31 from parking slot 36 .
#
#  Demand point 508 receives 67.95 of its demand 67.95 from parking slot 60 .
#
#  Demand point 509 receives 86.16 of its demand 86.16 from parking slot 60 .
#
#  Demand point 510 receives 76.36 of its demand 76.36 from parking slot 60 .
#
#  Demand point 511 receives 1.83 of its demand 1.83 from parking slot 60 .
#
#  Demand point 513 receives 57.81 of its demand 57.81 from parking slot 89 .
#
#  Demand point 514 receives 51.15 of its demand 51.15 from parking slot 89 .
#
#  Demand point 515 receives 44.73 of its demand 44.73 from parking slot 89 .
#
#  Demand point 516 receives 18.53 of its demand 18.53 from parking slot 89 .
#
#  Demand point 517 receives 38.32 of its demand 38.32 from parking slot 39 .
#
#  Demand point 518 receives 42.38 of its demand 42.38 from parking slot 39 .
#
#  Demand point 519 receives 47.59 of its demand 47.59 from parking slot 39 .
#
#  Demand point 520 receives 49.76 of its demand 49.76 from parking slot 39 .
#
#  Demand point 521 receives 57.57 of its demand 57.57 from parking slot 39 .
#
#  Demand point 522 receives 56.6 of its demand 56.6 from parking slot 39 .
#
#  Demand point 523 receives 67.6 of its demand 67.6 from parking slot 25 .
#
#  Demand point 524 receives 74.69 of its demand 74.69 from parking slot 25 .
#
#  Demand point 525 receives 79.41 of its demand 79.41 from parking slot 25 .
#
#  Demand point 526 receives 76.01 of its demand 76.01 from parking slot 25 .
#
#  Demand point 527 receives 81.7 of its demand 81.7 from parking slot 25 .
#
#  Demand point 528 receives 26.24 of its demand 68.75 from parking slot 25 .
#
#  Demand point 528 receives 42.51 of its demand 68.75 from parking slot 58 .
#
#  Demand point 529 receives 73.23 of its demand 73.23 from parking slot 58 .
#
#  Demand point 530 receives 51.91 of its demand 51.91 from parking slot 58 .
#
#  Demand point 531 receives 63.75 of its demand 63.75 from parking slot 100 .
#
#  Demand point 532 receives 63.81 of its demand 63.81 from parking slot 100 .
#
#  Demand point 533 receives 50.35 of its demand 50.35 from parking slot 100 .
#
#  Demand point 534 receives 47.91 of its demand 47.91 from parking slot 100 .
#
#  Demand point 535 receives 66.79 of its demand 66.79 from parking slot 100 .
#
#  Demand point 536 receives 73.06 of its demand 73.06 from parking slot 100 .
#
#  Demand point 537 receives 79.91 of its demand 79.91 from parking slot 100 .
#
#  Demand point 538 receives 71.31 of its demand 71.31 from parking slot 100 .
#
#  Demand point 539 receives 89.97 of its demand 89.97 from parking slot 100 .
#
#  Demand point 540 receives 93.61 of its demand 93.61 from parking slot 100 .
#
#  Demand point 541 receives 83.09 of its demand 83.09 from parking slot 100 .
#
#  Demand point 542 receives 77.34 of its demand 77.34 from parking slot 100 .
#
#  Demand point 543 receives 108.66 of its demand 108.66 from parking slot 75 .
#
#  Demand point 544 receives 86.31 of its demand 86.31 from parking slot 75 .
#
#  Demand point 545 receives 83.53 of its demand 83.53 from parking slot 75 .
#
#  Demand point 546 receives 146.51 of its demand 146.51 from parking slot 75 .
#
#  Demand point 547 receives 121.13 of its demand 121.13 from parking slot 70 .
#
#  Demand point 548 receives 118.48 of its demand 118.48 from parking slot 70 .
#
#  Demand point 549 receives 84.87 of its demand 84.87 from parking slot 70 .
#
#  Demand point 550 receives 95.31 of its demand 95.31 from parking slot 70 .
#
#  Demand point 551 receives 123.91 of its demand 123.91 from parking slot 70 .
#
#  Demand point 552 receives 144.17 of its demand 144.17 from parking slot 70 .
#
#  Demand point 553 receives 185.36 of its demand 185.36 from parking slot 70 .
#
#  Demand point 554 receives 276.45 of its demand 276.45 from parking slot 70 .
#
#  Demand point 555 receives 278.11 of its demand 278.11 from parking slot 70 .
#
#  Demand point 556 receives 246.41 of its demand 246.41 from parking slot 70 .
#
#  Demand point 557 receives 198.07 of its demand 198.07 from parking slot 96 .
#
#  Demand point 558 receives 181.34 of its demand 181.34 from parking slot 96 .
#
#  Demand point 559 receives 170.82 of its demand 170.82 from parking slot 96 .
#
#  Demand point 560 receives 114.8 of its demand 114.8 from parking slot 1 .
#
#  Demand point 561 receives 115.02 of its demand 115.02 from parking slot 1 .
#
#  Demand point 562 receives 90.09 of its demand 90.09 from parking slot 1 .
#
#  Demand point 563 receives 77.7 of its demand 77.7 from parking slot 1 .
#
#  Demand point 564 receives 78.63 of its demand 78.63 from parking slot 1 .
#
#  Demand point 565 receives 89.33 of its demand 89.33 from parking slot 1 .
#
#  Demand point 566 receives 78.37 of its demand 78.37 from parking slot 60 .
#
#  Demand point 567 receives 75.5 of its demand 75.5 from parking slot 60 .
#
#  Demand point 568 receives 84.18 of its demand 84.18 from parking slot 36 .
#
#  Demand point 569 receives 110.14 of its demand 110.14 from parking slot 36 .
#
#  Demand point 570 receives 73.67 of its demand 73.67 from parking slot 36 .
#
#  Demand point 571 receives 82.13 of its demand 82.13 from parking slot 60 .
#
#  Demand point 572 receives 79.58 of its demand 79.58 from parking slot 60 .
#
#  Demand point 573 receives 74.15 of its demand 74.15 from parking slot 60 .
#
#  Demand point 574 receives 55.8 of its demand 55.8 from parking slot 60 .
#
#  Demand point 575 receives 2.16 of its demand 2.16 from parking slot 60 .
#
#  Demand point 576 receives 2.09 of its demand 2.09 from parking slot 60 .
#
#  Demand point 577 receives 59.92 of its demand 59.92 from parking slot 89 .
#
#  Demand point 578 receives 50.52 of its demand 50.52 from parking slot 89 .
#
#  Demand point 579 receives 45.59 of its demand 45.59 from parking slot 89 .
#
#  Demand point 580 receives 42.55 of its demand 42.55 from parking slot 89 .
#
#  Demand point 581 receives 46.11 of its demand 46.11 from parking slot 89 .
#
#  Demand point 582 receives 52.19 of its demand 52.19 from parking slot 39 .
#
#  Demand point 583 receives 44.63 of its demand 44.63 from parking slot 39 .
#
#  Demand point 584 receives 49.37 of its demand 49.37 from parking slot 39 .
#
#  Demand point 585 receives 57.52 of its demand 57.52 from parking slot 39 .
#
#  Demand point 586 receives 58.01 of its demand 58.01 from parking slot 39 .
#
#  Demand point 587 receives 68.69 of its demand 68.69 from parking slot 25 .
#
#  Demand point 588 receives 71.61 of its demand 71.61 from parking slot 25 .
#
#  Demand point 589 receives 81.79 of its demand 81.79 from parking slot 25 .
#
#  Demand point 590 receives 76.81 of its demand 76.81 from parking slot 25 .
#
#  Demand point 591 receives 69.52 of its demand 69.52 from parking slot 25 .
#
#  Demand point 592 receives 67.14 of its demand 67.14 from parking slot 58 .
#
#  Demand point 593 receives 64.71 of its demand 64.71 from parking slot 58 .
#
#  Demand point 594 receives 73.81 of its demand 73.81 from parking slot 58 .
#
#  Demand point 595 receives 73.29 of its demand 73.29 from parking slot 100 .
#
#  Demand point 597 receives 74.17 of its demand 74.17 from parking slot 100 .
#
#  Demand point 598 receives 73.29 of its demand 73.29 from parking slot 100 .
#
#  Demand point 599 receives 68.73 of its demand 68.73 from parking slot 100 .
#
#  Demand point 600 receives 76.58 of its demand 76.58 from parking slot 100 .
#
#  Demand point 601 receives 71.62 of its demand 71.62 from parking slot 100 .
#
#  Demand point 602 receives 81.36 of its demand 81.36 from parking slot 100 .
#
#  Demand point 603 receives 79.16 of its demand 79.16 from parking slot 100 .
#
#  Demand point 604 receives 113.48 of its demand 113.48 from parking slot 100 .
#
#  Demand point 605 receives 80.34 of its demand 80.34 from parking slot 100 .
#
#  Demand point 606 receives 106.62 of its demand 106.62 from parking slot 100 .
#
#  Demand point 607 receives 134.03 of its demand 134.03 from parking slot 100 .
#
#  Demand point 608 receives 89.63 of its demand 89.63 from parking slot 75 .
#
#  Demand point 609 receives 89.35 of its demand 89.35 from parking slot 75 .
#
#  Demand point 610 receives 217.47 of its demand 217.47 from parking slot 70 .
#
#  Demand point 611 receives 156.11 of its demand 156.11 from parking slot 70 .
#
#  Demand point 612 receives 98.87 of its demand 98.87 from parking slot 70 .
#
#  Demand point 613 receives 84.58 of its demand 84.58 from parking slot 70 .
#
#  Demand point 614 receives 82.82 of its demand 82.82 from parking slot 70 .
#
#  Demand point 615 receives 73.32 of its demand 73.32 from parking slot 70 .
#
#  Demand point 616 receives 84.49 of its demand 84.49 from parking slot 70 .
#
#  Demand point 617 receives 116.27 of its demand 116.27 from parking slot 70 .
#
#  Demand point 618 receives 154.22 of its demand 154.22 from parking slot 70 .
#
#  Demand point 619 receives 151.16 of its demand 151.16 from parking slot 70 .
#
#  Demand point 620 receives 120.57 of its demand 120.57 from parking slot 70 .
#
#  Demand point 621 receives 121.43 of its demand 121.43 from parking slot 96 .
#
#  Demand point 622 receives 128.99 of its demand 128.99 from parking slot 96 .
#
#  Demand point 623 receives 122.71 of its demand 122.71 from parking slot 96 .
#
# ...
#
#  Demand point 3890 receives 21.54 of its demand 21.54 from parking slot 3 .
#
#  Demand point 3891 receives 23.58 of its demand 23.58 from parking slot 3 .
#
#  Demand point 3892 receives 12.52 of its demand 12.52 from parking slot 3 .
#
#  Demand point 3893 receives 14.55 of its demand 14.55 from parking slot 3 .
#
#  Demand point 3894 receives 13.32 of its demand 13.32 from parking slot 3 .
#
#  Demand point 3895 receives 14.36 of its demand 14.36 from parking slot 3 .
#
#  Demand point 3896 receives 16.45 of its demand 16.45 from parking slot 3 .
#
#  Demand point 3897 receives 16.21 of its demand 16.21 from parking slot 3 .
#
#  Demand point 3898 receives 17.84 of its demand 17.84 from parking slot 3 .
#
#  Demand point 3899 receives 14.83 of its demand 14.83 from parking slot 17 .
#
#  Demand point 3900 receives 8.41 of its demand 8.41 from parking slot 17 .
#
#  Demand point 3901 receives 3.82 of its demand 3.82 from parking slot 17 .
#
#  Demand point 3902 receives 82.18 of its demand 82.18 from parking slot 17 .
#
#  Demand point 3903 receives 83.28 of its demand 83.28 from parking slot 17 .
#
#  Demand point 3904 receives 77.69 of its demand 77.69 from parking slot 17 .
#
#  Demand point 3905 receives 1.67 of its demand 1.67 from parking slot 62 .
#
#  Demand point 3906 receives 1.81 of its demand 1.81 from parking slot 62 .
#
#  Demand point 3907 receives 2.14 of its demand 2.14 from parking slot 62 .
#
#  Demand point 3908 receives 2.15 of its demand 2.15 from parking slot 62 .
#
#  Demand point 3909 receives 2.37 of its demand 2.37 from parking slot 62 .
#
#  Demand point 3910 receives 3.01 of its demand 3.01 from parking slot 62 .
#
#  Demand point 3911 receives 3.81 of its demand 3.81 from parking slot 62 .
#
#  Demand point 3912 receives 4.17 of its demand 4.17 from parking slot 62 .
#
#  Demand point 3913 receives 3.84 of its demand 3.84 from parking slot 62 .
#
#  Demand point 3914 receives 3.75 of its demand 3.75 from parking slot 45 .
#
#  Demand point 3915 receives 0.78 of its demand 0.78 from parking slot 45 .
#
#  Demand point 3916 receives 10.68 of its demand 10.68 from parking slot 45 .
#
#  Demand point 3917 receives 16.53 of its demand 16.53 from parking slot 45 .
#
#  Demand point 3918 receives 11.18 of its demand 11.18 from parking slot 45 .
#
#  Demand point 3919 receives 11.98 of its demand 11.98 from parking slot 45 .
#
#  Demand point 3920 receives 11.4 of its demand 11.4 from parking slot 45 .
#
#  Demand point 3921 receives 11.97 of its demand 11.97 from parking slot 45 .
#
#  Demand point 3922 receives 9.98 of its demand 9.98 from parking slot 94 .
#
#  Demand point 3923 receives 5.99 of its demand 5.99 from parking slot 94 .
#
#  Demand point 3924 receives 11.44 of its demand 11.44 from parking slot 94 .
#
#  Demand point 3925 receives 12.23 of its demand 12.23 from parking slot 94 .
#
#  Demand point 3926 receives 14.87 of its demand 14.87 from parking slot 94 .
#
#  Demand point 3927 receives 15.15 of its demand 15.15 from parking slot 94 .
#
#  Demand point 3928 receives 11.45 of its demand 11.45 from parking slot 94 .
#
#  Demand point 3929 receives 9.51 of its demand 9.51 from parking slot 94 .
#
#  Demand point 3930 receives 7.03 of its demand 7.03 from parking slot 53 .
#
#  Demand point 3931 receives 5.64 of its demand 5.64 from parking slot 53 .
#
#  Demand point 3932 receives 6.69 of its demand 6.69 from parking slot 6 .
#
#  Demand point 3933 receives 17.1 of its demand 17.1 from parking slot 6 .
#
#  Demand point 3934 receives 12.08 of its demand 12.08 from parking slot 6 .
#
#  Demand point 3935 receives 16.93 of its demand 16.93 from parking slot 6 .
#
#  Demand point 3936 receives 17.45 of its demand 17.45 from parking slot 6 .
#
#  Demand point 3937 receives 28.08 of its demand 28.08 from parking slot 6 .
#
#  Demand point 3938 receives 27.8 of its demand 27.8 from parking slot 6 .
#
#  Demand point 3939 receives 26.39 of its demand 26.39 from parking slot 6 .
#
#  Demand point 3940 receives 27.08 of its demand 27.08 from parking slot 6 .
#
#  Demand point 3941 receives 23.44 of its demand 23.44 from parking slot 6 .
#
#  Demand point 3942 receives 19.91 of its demand 19.91 from parking slot 6 .
#
#  Demand point 3943 receives 21.29 of its demand 21.29 from parking slot 2 .
#
#  Demand point 3944 receives 22.78 of its demand 22.78 from parking slot 73 .
#
#  Demand point 3945 receives 21.08 of its demand 21.08 from parking slot 73 .
#
#  Demand point 3946 receives 13.46 of its demand 13.46 from parking slot 73 .
#
#  Demand point 3947 receives 23.21 of its demand 23.21 from parking slot 3 .
#
#  Demand point 3948 receives 22.55 of its demand 22.55 from parking slot 3 .
#
#  Demand point 3949 receives 17.37 of its demand 17.37 from parking slot 3 .
#
#  Demand point 3950 receives 21.77 of its demand 21.77 from parking slot 3 .
#
#  Demand point 3951 receives 21.2 of its demand 21.2 from parking slot 3 .
#
#  Demand point 3952 receives 23.04 of its demand 23.04 from parking slot 3 .
#
#  Demand point 3953 receives 23.0 of its demand 23.0 from parking slot 3 .
#
#  Demand point 3954 receives 23.41 of its demand 23.41 from parking slot 3 .
#
#  Demand point 3955 receives 24.43 of its demand 24.43 from parking slot 3 .
#
#  Demand point 3956 receives 20.84 of its demand 20.84 from parking slot 3 .
#
#  Demand point 3957 receives 18.57 of its demand 18.57 from parking slot 3 .
#
#  Demand point 3958 receives 12.88 of its demand 12.88 from parking slot 3 .
#
#  Demand point 3959 receives 10.44 of its demand 10.44 from parking slot 3 .
#
#  Demand point 3960 receives 18.49 of its demand 18.49 from parking slot 3 .
#
#  Demand point 3961 receives 11.82 of its demand 11.82 from parking slot 3 .
#
#  Demand point 3962 receives 15.98 of its demand 15.98 from parking slot 3 .
#
#  Demand point 3963 receives 18.11 of its demand 18.11 from parking slot 3 .
#
#  Demand point 3964 receives 9.89 of its demand 14.09 from parking slot 3 .
#
#  Demand point 3964 receives 4.2 of its demand 14.09 from parking slot 17 .
#
#  Demand point 3965 receives 6.93 of its demand 6.93 from parking slot 17 .
#
#  Demand point 3966 receives 4.19 of its demand 4.19 from parking slot 17 .
#
#  Demand point 3967 receives 15.34 of its demand 15.34 from parking slot 17 .
#
#  Demand point 3968 receives 89.31 of its demand 89.31 from parking slot 17 .
#
#  Demand point 3969 receives 1.7 of its demand 1.7 from parking slot 62 .
#
#  Demand point 3970 receives 1.94 of its demand 1.94 from parking slot 62 .
#
#  Demand point 3971 receives 2.0 of its demand 2.0 from parking slot 62 .
#
#  Demand point 3972 receives 2.15 of its demand 2.15 from parking slot 62 .
#
#  Demand point 3973 receives 2.19 of its demand 2.19 from parking slot 62 .
#
#  Demand point 3974 receives 2.44 of its demand 2.44 from parking slot 62 .
#
#  Demand point 3975 receives 4.17 of its demand 4.17 from parking slot 62 .
#
#  Demand point 3976 receives 5.19 of its demand 5.19 from parking slot 62 .
#
#  Demand point 3977 receives 5.13 of its demand 5.13 from parking slot 62 .
#
#  Demand point 3978 receives 4.42 of its demand 4.42 from parking slot 62 .
#
#  Demand point 3979 receives 11.36 of its demand 11.36 from parking slot 45 .
#
#  Demand point 3980 receives 13.97 of its demand 13.97 from parking slot 45 .
#
#  Demand point 3981 receives 14.06 of its demand 14.06 from parking slot 45 .
#
#  Demand point 3982 receives 10.55 of its demand 10.55 from parking slot 45 .
#
#  Demand point 3983 receives 11.16 of its demand 11.16 from parking slot 45 .
#
#  Demand point 3984 receives 10.78 of its demand 10.78 from parking slot 45 .
#
#  Demand point 3985 receives 10.22 of its demand 10.22 from parking slot 45 .
#
#  Demand point 3986 receives 9.18 of its demand 9.18 from parking slot 94 .
#
#  Demand point 3987 receives 10.79 of its demand 10.79 from parking slot 94 .
#
#  Demand point 3988 receives 11.72 of its demand 11.72 from parking slot 94 .
#
#  Demand point 3989 receives 11.86 of its demand 11.86 from parking slot 94 .
#
#  Demand point 3990 receives 18.62 of its demand 18.62 from parking slot 94 .
#
#  Demand point 3991 receives 17.52 of its demand 17.52 from parking slot 94 .
#
#  Demand point 3992 receives 11.96 of its demand 11.96 from parking slot 94 .
#
#  Demand point 3993 receives 5.3 of its demand 5.3 from parking slot 94 .
#
#  Demand point 3994 receives 4.34 of its demand 4.34 from parking slot 53 .
#
#  Demand point 3995 receives 3.88 of its demand 3.88 from parking slot 6 .
#
#  Demand point 3996 receives 4.88 of its demand 4.88 from parking slot 6 .
#
#  Demand point 3997 receives 8.92 of its demand 8.92 from parking slot 6 .
#
#  Demand point 3998 receives 16.81 of its demand 16.81 from parking slot 6 .
#
#  Demand point 3999 receives 22.69 of its demand 22.69 from parking slot 6 .
#
#  Demand point 4000 receives 17.2 of its demand 17.2 from parking slot 6 .
#
#  Demand point 4001 receives 26.34 of its demand 26.34 from parking slot 6 .
#
#  Demand point 4002 receives 26.85 of its demand 26.85 from parking slot 6 .
#
#  Demand point 4003 receives 13.87 of its demand 13.87 from parking slot 6 .
#
#  Demand point 4004 receives 24.61 of its demand 24.61 from parking slot 6 .
#
#  Demand point 4005 receives 26.19 of its demand 26.19 from parking slot 6 .
#
#  Demand point 4006 receives 19.64 of its demand 19.64 from parking slot 6 .
#
#  Demand point 4007 receives 18.65 of its demand 18.65 from parking slot 2 .
#
#  Demand point 4008 receives 25.06 of its demand 25.06 from parking slot 2 .
#
#  Demand point 4009 receives 22.62 of its demand 22.62 from parking slot 73 .
#
#  Demand point 4010 receives 17.58 of its demand 17.58 from parking slot 73 .
#
#  Demand point 4011 receives 24.02 of its demand 24.02 from parking slot 3 .
#
#  Demand point 4012 receives 23.16 of its demand 23.16 from parking slot 3 .
#
#  Demand point 4013 receives 18.14 of its demand 18.14 from parking slot 3 .
#
#  Demand point 4014 receives 17.37 of its demand 17.37 from parking slot 3 .
#
#  Demand point 4015 receives 17.25 of its demand 17.25 from parking slot 3 .
#
#  Demand point 4016 receives 18.0 of its demand 18.0 from parking slot 3 .
#
#  Demand point 4017 receives 23.59 of its demand 23.59 from parking slot 3 .
#
#  Demand point 4018 receives 24.69 of its demand 24.69 from parking slot 3 .
#
#  Demand point 4019 receives 25.73 of its demand 25.73 from parking slot 3 .
#
#  Demand point 4020 receives 25.02 of its demand 25.02 from parking slot 3 .
#
#  Demand point 4021 receives 22.75 of its demand 22.75 from parking slot 3 .
#
#  Demand point 4022 receives 19.81 of its demand 19.81 from parking slot 3 .
#
#  Demand point 4023 receives 13.84 of its demand 13.84 from parking slot 3 .
#
#  Demand point 4024 receives 8.62 of its demand 8.62 from parking slot 3 .
#
#  Demand point 4025 receives 7.54 of its demand 7.54 from parking slot 3 .
#
#  Demand point 4026 receives 10.56 of its demand 10.56 from parking slot 3 .
#
#  Demand point 4027 receives 15.24 of its demand 15.24 from parking slot 3 .
#
#  Demand point 4028 receives 13.4 of its demand 13.4 from parking slot 3 .
#
#  Demand point 4029 receives 5.37 of its demand 5.37 from parking slot 3 .
#
#  Demand point 4030 receives 3.02 of its demand 3.02 from parking slot 3 .
#
#  Demand point 4031 receives 6.64 of its demand 6.64 from parking slot 17 .
#
#  Demand point 4032 receives 11.4 of its demand 11.4 from parking slot 17 .
#
#  Demand point 4033 receives 1.95 of its demand 1.95 from parking slot 62 .
#
#  Demand point 4034 receives 2.17 of its demand 2.17 from parking slot 62 .
#
#  Demand point 4035 receives 2.11 of its demand 2.11 from parking slot 62 .
#
#  Demand point 4036 receives 2.32 of its demand 2.32 from parking slot 62 .
#
#  Demand point 4037 receives 2.73 of its demand 2.73 from parking slot 62 .
#
#  Demand point 4038 receives 2.85 of its demand 2.85 from parking slot 62 .
#
#  Demand point 4039 receives 4.71 of its demand 4.71 from parking slot 62 .
#
#  Demand point 4040 receives 6.12 of its demand 6.12 from parking slot 62 .
#
#  Demand point 4041 receives 5.95 of its demand 5.95 from parking slot 62 .
#
#  Demand point 4042 receives 10.0 of its demand 10.0 from parking slot 62 .
#
#  Demand point 4043 receives 12.55 of its demand 12.55 from parking slot 62 .
#
#  Demand point 4044 receives 11.47 of its demand 11.47 from parking slot 45 .
#
#  Demand point 4045 receives 8.02 of its demand 8.02 from parking slot 45 .
#
#  Demand point 4046 receives 8.17 of its demand 8.17 from parking slot 45 .
#
#  Demand point 4047 receives 8.4 of its demand 8.4 from parking slot 45 .
#
#  Demand point 4048 receives 6.59 of its demand 6.59 from parking slot 45 .
#
#  Demand point 4049 receives 9.05 of its demand 9.05 from parking slot 45 .
#
#  Demand point 4050 receives 7.82 of its demand 7.82 from parking slot 94 .
#
#  Demand point 4051 receives 12.42 of its demand 12.42 from parking slot 94 .
#
#  Demand point 4052 receives 16.16 of its demand 16.16 from parking slot 94 .
#
#  Demand point 4053 receives 15.93 of its demand 15.93 from parking slot 94 .
#
#  Demand point 4054 receives 16.74 of its demand 16.74 from parking slot 94 .
#
#  Demand point 4055 receives 17.48 of its demand 17.48 from parking slot 94 .
#
#  Demand point 4056 receives 18.16 of its demand 18.16 from parking slot 94 .
#
#  Demand point 4057 receives 9.7 of its demand 9.7 from parking slot 94 .
#
#  Demand point 4058 receives 5.43 of its demand 5.43 from parking slot 6 .
#
#  Demand point 4059 receives 3.8 of its demand 3.8 from parking slot 6 .
#
#  Demand point 4060 receives 3.2 of its demand 3.2 from parking slot 6 .
#
#  Demand point 4061 receives 5.84 of its demand 5.84 from parking slot 6 .
#
#  Demand point 4062 receives 17.6 of its demand 17.6 from parking slot 6 .
#
#  Demand point 4063 receives 19.48 of its demand 19.48 from parking slot 6 .
#
#  Demand point 4064 receives 17.52 of its demand 17.52 from parking slot 6 .
#
#  Demand point 4065 receives 25.01 of its demand 25.01 from parking slot 6 .
#
#  Demand point 4066 receives 27.4 of its demand 27.4 from parking slot 6 .
#
#  Demand point 4067 receives 27.51 of its demand 27.51 from parking slot 6 .
#
#  Demand point 4068 receives 26.58 of its demand 26.58 from parking slot 6 .
#
#  Demand point 4069 receives 21.5 of its demand 21.5 from parking slot 6 .
#
#  Demand point 4070 receives 19.36 of its demand 19.36 from parking slot 6 .
#
#  Demand point 4071 receives 19.97 of its demand 19.97 from parking slot 6 .
#
#  Demand point 4072 receives 23.53 of its demand 23.53 from parking slot 2 .
#
#  Demand point 4073 receives 24.68 of its demand 24.68 from parking slot 73 .
#
#  Demand point 4074 receives 26.48 of its demand 26.48 from parking slot 3 .
#
#  Demand point 4075 receives 25.25 of its demand 25.25 from parking slot 3 .
#
#  Demand point 4076 receives 23.73 of its demand 23.73 from parking slot 3 .
#
#  Demand point 4077 receives 21.09 of its demand 21.09 from parking slot 3 .
#
#  Demand point 4078 receives 18.15 of its demand 18.15 from parking slot 3 .
#
#  Demand point 4079 receives 16.48 of its demand 16.48 from parking slot 3 .
#
#  Demand point 4080 receives 18.55 of its demand 18.55 from parking slot 3 .
#
#  Demand point 4081 receives 24.46 of its demand 24.46 from parking slot 3 .
#
#  Demand point 4082 receives 25.09 of its demand 25.09 from parking slot 3 .
#
#  Demand point 4083 receives 21.57 of its demand 21.57 from parking slot 3 .
#
#  Demand point 4084 receives 25.59 of its demand 25.59 from parking slot 3 .
#
#  Demand point 4085 receives 20.03 of its demand 20.03 from parking slot 3 .
#
#  Demand point 4086 receives 21.69 of its demand 21.69 from parking slot 3 .
#
#  Demand point 4087 receives 12.98 of its demand 12.98 from parking slot 3 .
#
#  Demand point 4088 receives 7.12 of its demand 7.12 from parking slot 3 .
#
#  Demand point 4089 receives 4.97 of its demand 4.97 from parking slot 3 .
#
#  Demand point 4090 receives 9.22 of its demand 9.22 from parking slot 3 .
#
#  Demand point 4091 receives 17.71 of its demand 17.71 from parking slot 3 .
#
#  Demand point 4092 receives 12.23 of its demand 12.23 from parking slot 3 .
#
#  Demand point 4093 receives 3.8 of its demand 3.8 from parking slot 3 .
#
#  Demand point 4094 receives 7.37 of its demand 7.37 from parking slot 3 .
#
#  Demand point 4095 receives 14.0 of its demand 14.0 from parking slot 3 .
#
#  Demand point 4096 receives 14.99 of its demand 14.99 from parking slot 3 .

# %%
total_supply = 0
for j in range(num_facilities):
    total_supply += slow[j].solution_value()*200 + fast[j].solution_value()*400

# %%
sum(demands), total_supply
# Out:
# (533059.8972105536, 540800.0)

# %%
total_demand = 0.0
for i in range(num_customers):
    for j in range(num_facilities):
        total_demand += assign[(i,j)].solution_value()

# %%
sum(demands), total_demand
# Out:
# (533059.8972105536, 533059.8972105532)

# %%
slow_list = []
for j in range(num_facilities):
    slow_list.append((2020, "SCS", "", j, slow[j].solution_value()))
fast_list = []
for j in range(num_facilities):
    fast_list.append((2020, "FCS", "", j, fast[j].solution_value()))

# %%
assign_list = []
for i in range(num_customers):
    for j in range(num_facilities):
        assign_list.append((2019, "DS", i, j, assign[(i,j)].solution_value()))

# %%
result = slow_list + fast_list + assign_list

# %%
df_result = pd.DataFrame(result, columns=["year", "data_type", "demand_point_index", "supply_point_index", "value"])

# %%
df_result
# Out:
#         year data_type demand_point_index  supply_point_index  value
# 0       2020       SCS                                      0    5.0
# 1       2020       SCS                                      1    4.0
# 2       2020       SCS                                      2    6.0
# 3       2020       SCS                                      3    5.0
# 4       2020       SCS                                      4   11.0
# ...      ...       ...                ...                 ...    ...
# 409795  2019        DS               4095                  95    0.0
# 409796  2019        DS               4095                  96    0.0
# 409797  2019        DS               4095                  97    0.0
# 409798  2019        DS               4095                  98    0.0
# 409799  2019        DS               4095                  99    0.0
#
# [409800 rows x 5 columns]

# %%
df_result.to_csv("../data/processed/result_2020.csv")

# %%
supply_2020 = supply.copy()
supply_2020["existing_num_SCS"] = [entry[4] for entry in slow_list]
supply_2020["existing_num_FCS"] = [entry[4] for entry in fast_list]

# %%
supply_2020
# Out:
#     Unnamed: 0  supply_point_index  x_coordinate  y_coordinate  \
# 0            0                   0     50.163110     19.412014
# 1            1                   1     37.336451     58.119225
# 2            2                   2     46.709232     57.525650
# 3            3                   3     30.528626     55.379835
# 4            4                   4     51.521781     35.116755
# ..         ...                 ...           ...           ...
# 95          95                  95     45.471204     20.999414
# 96          96                  96     30.318396     33.388335
# 97          97                  97     36.218839     22.235766
# 98          98                  98     42.936915     38.122442
# 99          99                  99     19.590263      3.830284
#
#     total_parking_slots  existing_num_SCS  existing_num_FCS
# 0                    23               5.0              18.0
# 1                    27               4.0               7.0
# 2                    31               6.0              14.0
# 3                    26               5.0               5.0
# 4                    32              11.0               6.0
# ..                  ...               ...               ...
# 95                   24               3.0              21.0
# 96                   32               5.0              27.0
# 97                   32               4.0              28.0
# 98                   28               7.0               5.0
# 99                   24               2.0              22.0
#
# [100 rows x 7 columns]

# %%
supply_2020.to_csv("../data/processed/exisiting_EV_infrastructure_2020.csv")
