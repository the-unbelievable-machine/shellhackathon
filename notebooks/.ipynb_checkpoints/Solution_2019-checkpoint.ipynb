# %%
from math import sqrt
from itertools import product

import pandas as pd

from ortools.linear_solver import pywraplp
from ortools.init import pywrapinit

# %%
supply = pd.read_csv("../data/raw/exisiting_EV_infrastructure_2018.csv")

# %%
demand = pd.read_csv("../data/processed/Demand_Future.csv")

# %%
slow_charger = 200
slow_costs = 1.0*600
fast_charger = 400
fast_costs = 1.5*600

facilities = list(supply[["x_coordinate","y_coordinate"]].itertuples(index=False, name=None))
# real capacities
real_capacities = (supply["existing_num_SCS"]*slow_charger + supply["existing_num_FCS"]*fast_charger).tolist()
# maximum theoretical capacities
capacities = (supply["total_parking_slots"]*fast_charger).tolist()
# maximum slots for chargers
slots = supply["total_parking_slots"].tolist()

slow_slots = supply["existing_num_SCS"].tolist()
fast_slots = supply["existing_num_FCS"].tolist()

## For testing 
# slow_slots = [0]*len(facilities)
# fast_slots = [0]*len(facilities)

customers = list(demand[["x_coordinate","y_coordinate"]].itertuples(index=False, name=None))
demands = demand["2019"].tolist()

# %%
sum(capacities) > sum(demands), sum(capacities), sum(demands), sum(real_capacities)
# Out:
# (True, 1000000, 444363.90464364795, 361600)

# %%
# This function determines the Euclidean distance between a facility and customer sites.

def compute_distance(loc1, loc2):
    dx = loc1[0] - loc2[0]
    dy = loc1[1] - loc2[1]
    return sqrt(dx*dx + dy*dy)

# %%
# Compute key parameters of MIP model formulation

num_facilities = len(facilities)
num_customers = len(customers)
cartesian_prod = list(product(range(num_customers), range(num_facilities)))

# %%
# Compute distance matrix

distance = {(c,f): compute_distance(customers[c], facilities[f]) for c, f in cartesian_prod}

# %%
# solver = pywraplp.Solver.CreateSolver('CBC_MIXED_INTEGER_PROGRAMMING')
solver = pywraplp.Solver.CreateSolver('SCIP_MIXED_INTEGER_PROGRAMMING')

# %%
assign = {}
for i,j in distance.keys(): 
    assign[(i,j)] = solver.NumVar(0,solver.infinity(),"Assign")

# %%
# Constraint/Boundaries 2 
slow = {}
for j in range(num_facilities):
    slow[j] = solver.IntVar(slow_slots[j], solver.infinity(), "Slow")

fast = {}
for j in range(num_facilities):
    fast[j] = solver.IntVar(fast_slots[j], solver.infinity(), "Fast")

# %%
# Constraint 3 (slots)
for j in range(num_facilities):
    solver.Add(slow[j] + fast[j] <= slots[j])

# %%
# Constraint 5 (capacity constraints)
for j in range(num_facilities):
    solver.Add(sum(assign[(i,j)] for i in range(num_customers)) <= (slow[j]*200 + fast[j]*400))

# %%
# Constraint 6 (demand constraints)
for i in range(num_customers):
    solver.Add(sum(assign[(i,j)] for j in range(num_facilities)) == demands[i] )

# %%
objective = solver.Objective()

# %%
for j in range(num_facilities):
    objective.SetCoefficient(slow[j], slow_costs)
for j in range(num_facilities):
    objective.SetCoefficient(fast[j], fast_costs)

# %%
for i in range(num_customers):
    for j in range(num_facilities):
        objective.SetCoefficient(assign[(i,j)],distance[(i,j)])

# %%
objective.SetMinimization()

# %%
status = solver.Solve()

# %%
if status == pywraplp.Solver.OPTIMAL:
    print('Objective value =', solver.Objective().Value())
    print()
    print('Problem solved in %f milliseconds' % solver.wall_time())
    print('Problem solved in %d iterations' % solver.iterations())
    print('Problem solved in %d branch-and-bound nodes' % solver.nodes())
else:
    print('The problem does not have an optimal solution.')
# Out:
# Objective value = 2778785.7865769984
#
# Problem solved in 50969.000000 milliseconds
# Problem solved in 21549 iterations
# Problem solved in 2 branch-and-bound nodes

# %%
# display optimal values of decision variables
for j in range(num_facilities):
    print(f"\n Build {slow[j].solution_value() - slow_slots[j]} slow charger  and {fast[j].solution_value() - fast_slots[j]} fast charger at location {j + 1}.")
# Out:
#  Build 0.0 slow charger  and 15.0 fast charger at location 1.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 2.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 3.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 4.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 5.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 6.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 7.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 8.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 9.
#
#  Build 0.0 slow charger  and 4.0 fast charger at location 10.
#
#  Build 0.0 slow charger  and 8.0 fast charger at location 11.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 12.
#
#  Build 0.0 slow charger  and 12.0 fast charger at location 13.
#
#  Build 0.0 slow charger  and 1.0 fast charger at location 14.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 15.
#
#  Build 0.0 slow charger  and 10.0 fast charger at location 16.
#
#  Build 0.0 slow charger  and 1.0 fast charger at location 17.
#
#  Build 0.0 slow charger  and 3.0 fast charger at location 18.
#
#  Build 0.0 slow charger  and 10.0 fast charger at location 19.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 20.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 21.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 22.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 23.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 24.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 25.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 26.
#
#  Build 0.0 slow charger  and 2.0 fast charger at location 27.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 28.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 29.
#
#  Build 0.0 slow charger  and 10.0 fast charger at location 30.
#
#  Build 0.0 slow charger  and 5.0 fast charger at location 31.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 32.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 33.
#
#  Build 0.0 slow charger  and 1.0 fast charger at location 34.
#
#  Build 0.0 slow charger  and 13.0 fast charger at location 35.
#
#  Build 0.0 slow charger  and 6.0 fast charger at location 36.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 37.
#
#  Build 0.0 slow charger  and 5.0 fast charger at location 38.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 39.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 40.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 41.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 42.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 43.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 44.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 45.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 46.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 47.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 48.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 49.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 50.
#
#  Build 0.0 slow charger  and 15.0 fast charger at location 51.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 52.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 53.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 54.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 55.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 56.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 57.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 58.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 59.
#
#  Build 0.0 slow charger  and 2.0 fast charger at location 60.
#
#  Build 0.0 slow charger  and 1.0 fast charger at location 61.
#
#  Build 0.0 slow charger  and -0.0 fast charger at location 62.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 63.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 64.
#
#  Build 0.0 slow charger  and 15.0 fast charger at location 65.
#
#  Build 0.0 slow charger  and 15.0 fast charger at location 66.
#
#  Build 0.0 slow charger  and 10.0 fast charger at location 67.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 68.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 69.
#
#  Build 0.0 slow charger  and 19.0 fast charger at location 70.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 71.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 72.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 73.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 74.
#
#  Build 0.0 slow charger  and 7.0 fast charger at location 75.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 76.
#
#  Build 0.0 slow charger  and 4.0 fast charger at location 77.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 78.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 79.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 80.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 81.
#
#  Build 0.0 slow charger  and 14.0 fast charger at location 82.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 83.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 84.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 85.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 86.
#
#  Build 0.0 slow charger  and 1.0 fast charger at location 87.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 88.
#
#  Build 0.0 slow charger  and 11.0 fast charger at location 89.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 90.
#
#  Build 0.0 slow charger  and 10.0 fast charger at location 91.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 92.
#
#  Build 0.0 slow charger  and 10.0 fast charger at location 93.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 94.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 95.
#
#  Build 0.0 slow charger  and 12.0 fast charger at location 96.
#
#  Build 0.0 slow charger  and 14.0 fast charger at location 97.
#
#  Build 0.0 slow charger  and 14.0 fast charger at location 98.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 99.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 100.

# %%
# Shipments from facilities to customers.

for i, j in assign.keys():
    if (abs(assign[i, j].solution_value()) > 1e-6):
        print(f"\n Demand point {i + 1} receives {round(assign[i, j].solution_value(), 2)} of its demand {round(demands[i],2)} from parking slot {j + 1} .")
# Out:
#  Demand point 1 receives 19.36 of its demand 19.36 from parking slot 39 .
#
#  Demand point 2 receives 19.9 of its demand 19.9 from parking slot 39 .
#
#  Demand point 3 receives 19.39 of its demand 19.39 from parking slot 39 .
#
#  Demand point 4 receives 21.28 of its demand 21.28 from parking slot 39 .
#
#  Demand point 5 receives 20.79 of its demand 20.79 from parking slot 39 .
#
#  Demand point 6 receives 21.4 of its demand 21.4 from parking slot 39 .
#
#  Demand point 7 receives 24.66 of its demand 24.66 from parking slot 39 .
#
#  Demand point 8 receives 25.8 of its demand 25.8 from parking slot 39 .
#
#  Demand point 9 receives 28.64 of its demand 28.64 from parking slot 39 .
#
#  Demand point 10 receives 28.26 of its demand 28.26 from parking slot 39 .
#
#  Demand point 11 receives 33.99 of its demand 33.99 from parking slot 39 .
#
#  Demand point 12 receives 33.3 of its demand 33.3 from parking slot 39 .
#
#  Demand point 13 receives 30.3 of its demand 30.3 from parking slot 25 .
#
#  Demand point 14 receives 31.9 of its demand 31.9 from parking slot 25 .
#
#  Demand point 15 receives 26.06 of its demand 26.06 from parking slot 25 .
#
#  Demand point 16 receives 29.14 of its demand 29.14 from parking slot 25 .
#
#  Demand point 17 receives 27.64 of its demand 27.64 from parking slot 58 .
#
#  Demand point 18 receives 27.84 of its demand 27.84 from parking slot 58 .
#
#  Demand point 19 receives 28.88 of its demand 28.88 from parking slot 58 .
#
#  Demand point 20 receives 26.55 of its demand 26.55 from parking slot 61 .
#
#  Demand point 21 receives 30.38 of its demand 30.38 from parking slot 61 .
#
#  Demand point 22 receives 29.47 of its demand 29.47 from parking slot 61 .
#
#  Demand point 23 receives 30.32 of its demand 30.32 from parking slot 61 .
#
#  Demand point 24 receives 30.93 of its demand 30.93 from parking slot 61 .
#
#  Demand point 25 receives 27.95 of its demand 27.95 from parking slot 61 .
#
#  Demand point 26 receives 29.16 of its demand 29.16 from parking slot 61 .
#
#  Demand point 27 receives 23.28 of its demand 23.28 from parking slot 61 .
#
#  Demand point 28 receives 24.23 of its demand 24.23 from parking slot 61 .
#
#  Demand point 29 receives 25.25 of its demand 25.25 from parking slot 61 .
#
#  Demand point 30 receives 27.1 of its demand 27.1 from parking slot 61 .
#
#  Demand point 31 receives 32.69 of its demand 32.69 from parking slot 61 .
#
#  Demand point 32 receives 41.1 of its demand 41.1 from parking slot 61 .
#
#  Demand point 33 receives 48.52 of its demand 48.52 from parking slot 61 .
#
#  Demand point 34 receives 54.21 of its demand 54.21 from parking slot 61 .
#
#  Demand point 35 receives 67.27 of its demand 67.27 from parking slot 61 .
#
#  Demand point 36 receives 63.68 of its demand 63.68 from parking slot 61 .
#
#  Demand point 37 receives 68.4 of its demand 68.4 from parking slot 93 .
#
#  Demand point 38 receives 59.17 of its demand 59.17 from parking slot 93 .
#
#  Demand point 39 receives 69.19 of its demand 69.19 from parking slot 93 .
#
#  Demand point 40 receives 68.41 of its demand 68.41 from parking slot 93 .
#
#  Demand point 41 receives 118.71 of its demand 118.71 from parking slot 93 .
#
#  Demand point 42 receives 113.04 of its demand 113.04 from parking slot 77 .
#
#  Demand point 43 receives 94.54 of its demand 94.54 from parking slot 77 .
#
#  Demand point 44 receives 64.67 of its demand 64.67 from parking slot 77 .
#
#  Demand point 45 receives 52.82 of its demand 52.82 from parking slot 77 .
#
#  Demand point 46 receives 41.26 of its demand 41.26 from parking slot 77 .
#
#  Demand point 47 receives 42.07 of its demand 42.07 from parking slot 77 .
#
#  Demand point 48 receives 62.19 of its demand 62.19 from parking slot 77 .
#
#  Demand point 49 receives 68.51 of its demand 68.51 from parking slot 11 .
#
#  Demand point 50 receives 61.24 of its demand 61.24 from parking slot 11 .
#
#  Demand point 51 receives 81.71 of its demand 81.71 from parking slot 11 .
#
#  Demand point 52 receives 108.99 of its demand 108.99 from parking slot 11 .
#
#  Demand point 53 receives 163.77 of its demand 163.77 from parking slot 11 .
#
#  Demand point 54 receives 99.73 of its demand 99.73 from parking slot 11 .
#
#  Demand point 55 receives 118.57 of its demand 118.57 from parking slot 11 .
#
#  Demand point 56 receives 81.88 of its demand 81.88 from parking slot 11 .
#
#  Demand point 57 receives 98.23 of its demand 98.23 from parking slot 11 .
#
#  Demand point 58 receives 71.82 of its demand 71.82 from parking slot 11 .
#
#  Demand point 59 receives 55.8 of its demand 55.8 from parking slot 11 .
#
#  Demand point 60 receives 54.15 of its demand 54.15 from parking slot 36 .
#
#  Demand point 61 receives 55.17 of its demand 55.17 from parking slot 36 .
#
#  Demand point 62 receives 42.08 of its demand 42.08 from parking slot 36 .
#
#  Demand point 63 receives 42.48 of its demand 42.48 from parking slot 36 .
#
#  Demand point 64 receives 48.37 of its demand 48.37 from parking slot 36 .
#
#  Demand point 65 receives 23.64 of its demand 23.64 from parking slot 39 .
#
#  Demand point 66 receives 18.73 of its demand 18.73 from parking slot 39 .
#
#  Demand point 67 receives 20.01 of its demand 20.01 from parking slot 39 .
#
#  Demand point 68 receives 20.81 of its demand 20.81 from parking slot 39 .
#
#  Demand point 69 receives 21.8 of its demand 21.8 from parking slot 39 .
#
#  Demand point 70 receives 23.54 of its demand 23.54 from parking slot 39 .
#
#  Demand point 71 receives 28.73 of its demand 28.73 from parking slot 39 .
#
#  Demand point 72 receives 38.62 of its demand 38.62 from parking slot 39 .
#
#  Demand point 73 receives 44.8 of its demand 44.8 from parking slot 39 .
#
#  Demand point 74 receives 36.64 of its demand 36.64 from parking slot 39 .
#
#  Demand point 75 receives 48.17 of its demand 48.17 from parking slot 39 .
#
#  Demand point 76 receives 41.97 of its demand 41.97 from parking slot 39 .
#
#  Demand point 77 receives 36.78 of its demand 36.78 from parking slot 25 .
#
#  Demand point 78 receives 23.45 of its demand 23.45 from parking slot 25 .
#
#  Demand point 79 receives 27.65 of its demand 27.65 from parking slot 25 .
#
#  Demand point 80 receives 33.31 of its demand 33.31 from parking slot 25 .
#
#  Demand point 81 receives 47.35 of its demand 47.35 from parking slot 58 .
#
#  Demand point 82 receives 41.46 of its demand 41.46 from parking slot 58 .
#
#  Demand point 83 receives 41.17 of its demand 41.17 from parking slot 58 .
#
#  Demand point 84 receives 35.15 of its demand 35.15 from parking slot 61 .
#
#  Demand point 85 receives 34.86 of its demand 34.86 from parking slot 61 .
#
#  Demand point 86 receives 35.48 of its demand 35.48 from parking slot 61 .
#
#  Demand point 87 receives 37.2 of its demand 37.2 from parking slot 61 .
#
#  Demand point 88 receives 42.6 of its demand 42.6 from parking slot 61 .
#
#  Demand point 89 receives 43.12 of its demand 43.12 from parking slot 61 .
#
#  Demand point 90 receives 34.13 of its demand 34.13 from parking slot 61 .
#
#  Demand point 91 receives 29.73 of its demand 29.73 from parking slot 61 .
#
#  Demand point 92 receives 26.58 of its demand 26.58 from parking slot 61 .
#
#  Demand point 93 receives 26.96 of its demand 26.96 from parking slot 61 .
#
#  Demand point 94 receives 28.55 of its demand 28.55 from parking slot 61 .
#
#  Demand point 95 receives 33.91 of its demand 33.91 from parking slot 61 .
#
#  Demand point 96 receives 39.7 of its demand 39.7 from parking slot 61 .
#
#  Demand point 97 receives 36.44 of its demand 36.44 from parking slot 61 .
#
#  Demand point 99 receives 56.25 of its demand 56.25 from parking slot 61 .
#
#  Demand point 100 receives 80.71 of its demand 80.71 from parking slot 61 .
#
#  Demand point 101 receives 102.05 of its demand 102.05 from parking slot 93 .
#
#  Demand point 102 receives 76.31 of its demand 76.31 from parking slot 93 .
#
#  Demand point 103 receives 91.88 of its demand 91.88 from parking slot 93 .
#
#  Demand point 104 receives 78.02 of its demand 78.02 from parking slot 93 .
#
#  Demand point 105 receives 137.64 of its demand 137.64 from parking slot 93 .
#
#  Demand point 106 receives 88.66 of its demand 88.66 from parking slot 77 .
#
#  Demand point 107 receives 93.77 of its demand 93.77 from parking slot 77 .
#
#  Demand point 108 receives 10.2 of its demand 10.2 from parking slot 77 .
#
#  Demand point 110 receives 56.98 of its demand 56.98 from parking slot 77 .
#
#  Demand point 111 receives 50.64 of its demand 50.64 from parking slot 77 .
#
#  Demand point 112 receives 61.36 of its demand 61.36 from parking slot 77 .
#
#  Demand point 113 receives 59.2 of its demand 59.2 from parking slot 11 .
#
#  Demand point 114 receives 54.07 of its demand 54.07 from parking slot 11 .
#
#  Demand point 115 receives 70.51 of its demand 70.51 from parking slot 11 .
#
#  Demand point 116 receives 112.49 of its demand 112.49 from parking slot 11 .
#
#  Demand point 117 receives 117.08 of its demand 117.08 from parking slot 11 .
#
#  Demand point 118 receives 59.31 of its demand 59.31 from parking slot 11 .
#
#  Demand point 119 receives 56.13 of its demand 56.13 from parking slot 11 .
#
#  Demand point 120 receives 75.66 of its demand 75.66 from parking slot 11 .
#
#  Demand point 121 receives 74.26 of its demand 74.26 from parking slot 11 .
#
#  Demand point 122 receives 62.86 of its demand 62.86 from parking slot 11 .
#
#  Demand point 123 receives 57.67 of its demand 57.67 from parking slot 36 .
#
#  Demand point 124 receives 57.24 of its demand 57.24 from parking slot 36 .
#
#  Demand point 125 receives 11.63 of its demand 11.63 from parking slot 36 .
#
#  Demand point 126 receives 9.46 of its demand 9.46 from parking slot 36 .
#
#  Demand point 127 receives 11.41 of its demand 11.41 from parking slot 36 .
#
#  Demand point 128 receives 47.04 of its demand 47.04 from parking slot 36 .
#
#  Demand point 129 receives 23.63 of its demand 23.63 from parking slot 89 .
#
#  Demand point 130 receives 21.85 of its demand 21.85 from parking slot 39 .
#
#  Demand point 131 receives 23.17 of its demand 23.17 from parking slot 39 .
#
#  Demand point 132 receives 24.67 of its demand 24.67 from parking slot 39 .
#
#  Demand point 133 receives 27.1 of its demand 27.1 from parking slot 39 .
#
#  Demand point 134 receives 25.62 of its demand 25.62 from parking slot 39 .
#
#  Demand point 135 receives 31.34 of its demand 31.34 from parking slot 39 .
#
#  Demand point 136 receives 41.14 of its demand 41.14 from parking slot 39 .
#
#  Demand point 137 receives 47.48 of its demand 47.48 from parking slot 39 .
#
#  Demand point 138 receives 41.15 of its demand 41.15 from parking slot 39 .
#
#  Demand point 139 receives 47.15 of its demand 47.15 from parking slot 39 .
#
#  Demand point 140 receives 47.7 of its demand 47.7 from parking slot 39 .
#
#  Demand point 141 receives 39.92 of its demand 39.92 from parking slot 25 .
#
#  Demand point 142 receives 31.73 of its demand 31.73 from parking slot 25 .
#
#  Demand point 143 receives 30.01 of its demand 30.01 from parking slot 25 .
#
#  Demand point 144 receives 40.19 of its demand 40.19 from parking slot 25 .
#
#  Demand point 145 receives 49.91 of its demand 49.91 from parking slot 58 .
#
#  Demand point 146 receives 45.06 of its demand 45.06 from parking slot 58 .
#
#  Demand point 147 receives 45.11 of its demand 45.11 from parking slot 58 .
#
#  Demand point 148 receives 38.91 of its demand 38.91 from parking slot 100 .
#
#  Demand point 149 receives 40.97 of its demand 40.97 from parking slot 61 .
#
#  Demand point 150 receives 42.47 of its demand 42.47 from parking slot 61 .
#
#  Demand point 151 receives 47.77 of its demand 47.77 from parking slot 61 .
#
#  Demand point 152 receives 56.91 of its demand 56.91 from parking slot 61 .
#
#  Demand point 153 receives 57.93 of its demand 57.93 from parking slot 61 .
#
#  Demand point 154 receives 44.15 of its demand 44.15 from parking slot 61 .
#
#  Demand point 155 receives 31.94 of its demand 31.94 from parking slot 61 .
#
#  Demand point 156 receives 31.22 of its demand 31.22 from parking slot 61 .
#
#  Demand point 157 receives 30.77 of its demand 30.77 from parking slot 61 .
#
#  Demand point 158 receives 31.68 of its demand 31.68 from parking slot 61 .
#
#  Demand point 159 receives 34.89 of its demand 34.89 from parking slot 61 .
#
#  Demand point 160 receives 39.88 of its demand 39.88 from parking slot 61 .
#
#  Demand point 161 receives 36.14 of its demand 40.23 from parking slot 61 .
#
#  Demand point 161 receives 4.09 of its demand 40.23 from parking slot 75 .
#
#  Demand point 162 receives 51.01 of its demand 51.01 from parking slot 75 .
#
#  Demand point 163 receives 59.79 of its demand 59.79 from parking slot 75 .
#
#  Demand point 164 receives 43.03 of its demand 48.15 from parking slot 75 .
#
#  Demand point 164 receives 5.12 of its demand 48.15 from parking slot 93 .
#
#  Demand point 165 receives 75.79 of its demand 75.79 from parking slot 93 .
#
#  Demand point 166 receives 100.91 of its demand 100.91 from parking slot 93 .
#
#  Demand point 167 receives 83.44 of its demand 83.44 from parking slot 93 .
#
#  Demand point 168 receives 74.85 of its demand 74.85 from parking slot 93 .
#
#  Demand point 169 receives 113.75 of its demand 113.75 from parking slot 93 .
#
#  Demand point 170 receives 82.9 of its demand 82.9 from parking slot 77 .
#
#  Demand point 171 receives 59.29 of its demand 59.29 from parking slot 77 .
#
#  Demand point 172 receives 66.54 of its demand 66.54 from parking slot 77 .
#
#  Demand point 176 receives 8.7 of its demand 68.28 from parking slot 1 .
#
#  Demand point 176 receives 59.58 of its demand 68.28 from parking slot 77 .
#
#  Demand point 177 receives 75.6 of its demand 75.6 from parking slot 11 .
#
#  Demand point 178 receives 105.46 of its demand 105.46 from parking slot 11 .
#
#  Demand point 179 receives 78.45 of its demand 78.45 from parking slot 11 .
#
#  Demand point 180 receives 64.83 of its demand 64.83 from parking slot 11 .
#
#  Demand point 181 receives 50.05 of its demand 50.05 from parking slot 11 .
#
#  Demand point 182 receives 53.93 of its demand 53.93 from parking slot 11 .
#
#  Demand point 183 receives 56.9 of its demand 56.9 from parking slot 11 .
#
#  Demand point 184 receives 51.57 of its demand 51.57 from parking slot 11 .
#
#  Demand point 185 receives 46.73 of its demand 46.73 from parking slot 11 .
#
#  Demand point 186 receives 76.46 of its demand 76.46 from parking slot 11 .
#
#  Demand point 187 receives 65.96 of its demand 65.96 from parking slot 36 .
#
#  Demand point 188 receives 49.45 of its demand 49.45 from parking slot 36 .
#
#  Demand point 189 receives 1.25 of its demand 1.25 from parking slot 36 .
#
#  Demand point 190 receives 1.32 of its demand 1.32 from parking slot 36 .
#
#  Demand point 191 receives 1.49 of its demand 1.49 from parking slot 36 .
#
#  Demand point 192 receives 2.28 of its demand 2.28 from parking slot 36 .
#
#  Demand point 193 receives 30.67 of its demand 30.67 from parking slot 89 .
#
#  Demand point 194 receives 30.7 of its demand 30.7 from parking slot 89 .
#
#  Demand point 195 receives 38.55 of its demand 38.55 from parking slot 39 .
#
#  Demand point 196 receives 37.47 of its demand 37.47 from parking slot 39 .
#
#  Demand point 197 receives 30.13 of its demand 30.13 from parking slot 39 .
#
#  Demand point 198 receives 24.23 of its demand 24.23 from parking slot 39 .
#
#  Demand point 199 receives 26.34 of its demand 26.34 from parking slot 39 .
#
#  Demand point 200 receives 28.82 of its demand 28.82 from parking slot 39 .
#
#  Demand point 201 receives 31.65 of its demand 31.65 from parking slot 39 .
#
#  Demand point 202 receives 36.67 of its demand 36.67 from parking slot 39 .
#
#  Demand point 203 receives 41.6 of its demand 41.6 from parking slot 39 .
#
#  Demand point 204 receives 40.18 of its demand 40.18 from parking slot 25 .
#
#  Demand point 205 receives 39.55 of its demand 39.55 from parking slot 25 .
#
#  Demand point 206 receives 32.72 of its demand 32.72 from parking slot 25 .
#
#  Demand point 207 receives 36.75 of its demand 36.75 from parking slot 25 .
#
#  Demand point 208 receives 38.83 of its demand 38.83 from parking slot 25 .
#
#  Demand point 209 receives 36.47 of its demand 36.47 from parking slot 58 .
#
#  Demand point 210 receives 40.95 of its demand 40.95 from parking slot 58 .
#
#  Demand point 211 receives 35.05 of its demand 35.05 from parking slot 58 .
#
#  Demand point 212 receives 33.81 of its demand 33.81 from parking slot 100 .
#
#  Demand point 213 receives 33.11 of its demand 33.11 from parking slot 100 .
#
#  Demand point 214 receives 39.42 of its demand 39.42 from parking slot 61 .
#
#  Demand point 215 receives 45.48 of its demand 45.48 from parking slot 61 .
#
#  Demand point 216 receives 54.9 of its demand 54.9 from parking slot 61 .
#
#  Demand point 217 receives 57.68 of its demand 57.68 from parking slot 75 .
#
#  Demand point 218 receives 49.77 of its demand 49.77 from parking slot 75 .
#
#  Demand point 219 receives 1.13 of its demand 1.13 from parking slot 75 .
#
#  Demand point 220 receives 38.12 of its demand 38.12 from parking slot 75 .
#
#  Demand point 221 receives 35.5 of its demand 35.5 from parking slot 75 .
#
#  Demand point 222 receives 39.52 of its demand 39.52 from parking slot 75 .
#
#  Demand point 223 receives 36.87 of its demand 36.87 from parking slot 75 .
#
#  Demand point 224 receives 40.62 of its demand 40.62 from parking slot 75 .
#
#  Demand point 225 receives 48.95 of its demand 48.95 from parking slot 75 .
#
#  Demand point 226 receives 59.27 of its demand 59.27 from parking slot 75 .
#
#  Demand point 227 receives 60.27 of its demand 60.27 from parking slot 75 .
#
#  Demand point 228 receives 40.59 of its demand 40.59 from parking slot 93 .
#
#  Demand point 229 receives 72.8 of its demand 72.8 from parking slot 93 .
#
#  Demand point 230 receives 75.49 of its demand 75.49 from parking slot 93 .
#
#  Demand point 231 receives 72.36 of its demand 72.36 from parking slot 93 .
#
#  Demand point 232 receives 75.48 of its demand 75.48 from parking slot 93 .
#
#  Demand point 233 receives 120.33 of its demand 120.33 from parking slot 93 .
#
#  Demand point 234 receives 135.41 of its demand 135.41 from parking slot 77 .
#
#  Demand point 235 receives 118.49 of its demand 118.49 from parking slot 77 .
#
#  Demand point 236 receives 129.41 of its demand 129.41 from parking slot 77 .
#
#  Demand point 237 receives 89.1 of its demand 89.1 from parking slot 77 .
#
#  Demand point 238 receives 33.1 of its demand 33.1 from parking slot 77 .
#
#  Demand point 240 receives 26.73 of its demand 26.73 from parking slot 1 .
#
#  Demand point 241 receives 91.8 of its demand 91.8 from parking slot 1 .
#
#  Demand point 242 receives 178.11 of its demand 178.11 from parking slot 11 .
#
#  Demand point 243 receives 175.22 of its demand 175.22 from parking slot 11 .
#
#  Demand point 244 receives 72.76 of its demand 72.76 from parking slot 11 .
#
#  Demand point 245 receives 54.92 of its demand 54.92 from parking slot 11 .
#
#  Demand point 246 receives 3.08 of its demand 3.08 from parking slot 11 .
#
#  Demand point 247 receives 58.14 of its demand 58.14 from parking slot 11 .
#
#  Demand point 248 receives 75.13 of its demand 75.13 from parking slot 11 .
#
#  Demand point 249 receives 60.36 of its demand 60.36 from parking slot 11 .
#
#  Demand point 250 receives 74.08 of its demand 74.08 from parking slot 36 .
#
#  Demand point 251 receives 63.01 of its demand 63.01 from parking slot 36 .
#
#  Demand point 252 receives 1.58 of its demand 1.58 from parking slot 36 .
#
#  Demand point 253 receives 1.41 of its demand 1.41 from parking slot 36 .
#
#  Demand point 254 receives 2.13 of its demand 2.13 from parking slot 36 .
#
#  Demand point 255 receives 2.74 of its demand 2.74 from parking slot 36 .
#
#  Demand point 256 receives 2.52 of its demand 2.52 from parking slot 36 .
#
#  Demand point 257 receives 36.89 of its demand 36.89 from parking slot 89 .
#
#  Demand point 258 receives 39.42 of its demand 39.42 from parking slot 89 .
#
#  Demand point 259 receives 48.68 of its demand 48.68 from parking slot 89 .
#
#  Demand point 260 receives 39.45 of its demand 39.45 from parking slot 39 .
#
#  Demand point 261 receives 34.14 of its demand 34.14 from parking slot 39 .
#
#  Demand point 262 receives 26.34 of its demand 26.34 from parking slot 39 .
#
#  Demand point 263 receives 25.62 of its demand 25.62 from parking slot 39 .
#
#  Demand point 264 receives 25.83 of its demand 25.83 from parking slot 39 .
#
#  Demand point 265 receives 34.98 of its demand 34.98 from parking slot 39 .
#
#  Demand point 266 receives 45.59 of its demand 45.59 from parking slot 39 .
#
#  Demand point 267 receives 42.9 of its demand 42.9 from parking slot 39 .
#
#  Demand point 268 receives 40.43 of its demand 40.43 from parking slot 25 .
#
#  Demand point 269 receives 37.67 of its demand 37.67 from parking slot 25 .
#
#  Demand point 270 receives 32.39 of its demand 32.39 from parking slot 25 .
#
#  Demand point 271 receives 30.62 of its demand 30.62 from parking slot 25 .
#
#  Demand point 272 receives 28.92 of its demand 28.92 from parking slot 25 .
#
#  Demand point 273 receives 25.68 of its demand 25.68 from parking slot 58 .
#
#  Demand point 274 receives 31.68 of its demand 31.68 from parking slot 58 .
#
#  Demand point 275 receives 30.02 of its demand 30.02 from parking slot 100 .
#
#  Demand point 276 receives 29.39 of its demand 29.39 from parking slot 100 .
#
#  Demand point 277 receives 30.24 of its demand 30.24 from parking slot 100 .
#
#  Demand point 278 receives 35.61 of its demand 35.61 from parking slot 100 .
#
#  Demand point 279 receives 44.95 of its demand 44.95 from parking slot 100 .
#
#  Demand point 280 receives 54.17 of its demand 54.17 from parking slot 61 .
#
#  Demand point 281 receives 53.02 of its demand 53.02 from parking slot 75 .
#
#  Demand point 282 receives 49.6 of its demand 49.6 from parking slot 75 .
#
#  Demand point 283 receives 49.29 of its demand 49.29 from parking slot 75 .
#
#  Demand point 284 receives 46.99 of its demand 46.99 from parking slot 75 .
#
#  Demand point 285 receives 43.48 of its demand 43.48 from parking slot 75 .
#
#  Demand point 286 receives 44.93 of its demand 44.93 from parking slot 75 .
#
#  Demand point 287 receives 50.75 of its demand 50.75 from parking slot 75 .
#
#  Demand point 288 receives 53.73 of its demand 53.73 from parking slot 75 .
#
#  Demand point 289 receives 48.78 of its demand 48.78 from parking slot 75 .
#
#  Demand point 290 receives 61.81 of its demand 61.81 from parking slot 75 .
#
#  Demand point 291 receives 66.34 of its demand 66.34 from parking slot 75 .
#
#  Demand point 292 receives 71.69 of its demand 71.69 from parking slot 93 .
#
#  Demand point 293 receives 126.98 of its demand 126.98 from parking slot 93 .
#
#  Demand point 294 receives 79.43 of its demand 79.43 from parking slot 93 .
#
#  Demand point 295 receives 131.39 of its demand 131.39 from parking slot 93 .
#
#  Demand point 296 receives 169.02 of its demand 169.02 from parking slot 93 .
#
#  Demand point 297 receives 183.96 of its demand 183.96 from parking slot 93 .
#
#  Demand point 298 receives 225.37 of its demand 225.37 from parking slot 77 .
#
#  Demand point 299 receives 178.85 of its demand 178.85 from parking slot 77 .
#
#  Demand point 300 receives 213.31 of its demand 213.31 from parking slot 77 .
#
#  Demand point 301 receives 205.43 of its demand 205.43 from parking slot 77 .
#
#  Demand point 302 receives 164.25 of its demand 164.25 from parking slot 77 .
#
#  Demand point 303 receives 89.71 of its demand 89.71 from parking slot 1 .
#
#  Demand point 304 receives 98.95 of its demand 98.95 from parking slot 1 .
#
#  Demand point 305 receives 131.51 of its demand 131.51 from parking slot 1 .
#
#  Demand point 306 receives 202.97 of its demand 202.97 from parking slot 11 .
#
#  Demand point 307 receives 139.12 of its demand 139.12 from parking slot 11 .
#
#  Demand point 308 receives 76.59 of its demand 76.59 from parking slot 11 .
#
#  Demand point 309 receives 59.69 of its demand 59.69 from parking slot 11 .
#
#  Demand point 310 receives 5.38 of its demand 5.38 from parking slot 11 .
#
#  Demand point 311 receives 53.57 of its demand 53.57 from parking slot 11 .
#
#  Demand point 312 receives 53.49 of its demand 53.49 from parking slot 11 .
#
#  Demand point 313 receives 106.58 of its demand 106.58 from parking slot 36 .
#
#  Demand point 314 receives 79.53 of its demand 79.53 from parking slot 36 .
#
#  Demand point 315 receives 49.94 of its demand 49.94 from parking slot 36 .
#
#  Demand point 316 receives 1.33 of its demand 1.33 from parking slot 36 .
#
#  Demand point 317 receives 1.41 of its demand 1.41 from parking slot 36 .
#
#  Demand point 318 receives 1.86 of its demand 1.86 from parking slot 36 .
#
#  Demand point 319 receives 4.45 of its demand 4.45 from parking slot 36 .
#
#  Demand point 320 receives 4.54 of its demand 4.54 from parking slot 36 .
#
#  Demand point 321 receives 35.25 of its demand 35.25 from parking slot 89 .
#
#  Demand point 322 receives 36.14 of its demand 36.14 from parking slot 89 .
#
#  Demand point 323 receives 35.83 of its demand 35.83 from parking slot 89 .
#
#  Demand point 324 receives 31.89 of its demand 31.89 from parking slot 89 .
#
#  Demand point 325 receives 24.81 of its demand 24.81 from parking slot 39 .
#
#  Demand point 326 receives 25.66 of its demand 25.66 from parking slot 39 .
#
#  Demand point 327 receives 28.67 of its demand 28.67 from parking slot 39 .
#
#  Demand point 328 receives 28.06 of its demand 28.06 from parking slot 39 .
#
#  Demand point 329 receives 39.31 of its demand 39.31 from parking slot 39 .
#
#  Demand point 330 receives 48.09 of its demand 48.09 from parking slot 39 .
#
#  Demand point 331 receives 51.5 of its demand 51.5 from parking slot 39 .
#
#  Demand point 332 receives 48.43 of its demand 48.43 from parking slot 25 .
#
#  Demand point 333 receives 39.46 of its demand 39.46 from parking slot 25 .
#
#  Demand point 334 receives 43.55 of its demand 43.55 from parking slot 25 .
#
#  Demand point 335 receives 34.2 of its demand 34.2 from parking slot 25 .
#
#  Demand point 336 receives 29.34 of its demand 29.34 from parking slot 25 .
#
#  Demand point 337 receives 28.76 of its demand 28.76 from parking slot 58 .
#
#  Demand point 338 receives 27.73 of its demand 27.73 from parking slot 58 .
#
#  Demand point 339 receives 29.08 of its demand 29.08 from parking slot 100 .
#
#  Demand point 340 receives 28.76 of its demand 28.76 from parking slot 100 .
#
#  Demand point 341 receives 29.93 of its demand 29.93 from parking slot 100 .
#
#  Demand point 342 receives 41.62 of its demand 41.62 from parking slot 100 .
#
#  Demand point 343 receives 39.76 of its demand 39.76 from parking slot 100 .
#
#  Demand point 344 receives 47.35 of its demand 47.35 from parking slot 100 .
#
#  Demand point 345 receives 45.82 of its demand 45.82 from parking slot 61 .
#
#  Demand point 346 receives 48.93 of its demand 48.93 from parking slot 75 .
#
#  Demand point 347 receives 39.42 of its demand 39.42 from parking slot 75 .
#
#  Demand point 348 receives 40.55 of its demand 40.55 from parking slot 75 .
#
#  Demand point 349 receives 40.46 of its demand 40.46 from parking slot 75 .
#
#  Demand point 350 receives 53.23 of its demand 53.23 from parking slot 75 .
#
#  Demand point 351 receives 63.07 of its demand 63.07 from parking slot 75 .
#
#  Demand point 352 receives 66.14 of its demand 66.14 from parking slot 75 .
#
#  Demand point 353 receives 68.24 of its demand 68.24 from parking slot 75 .
#
#  Demand point 354 receives 72.32 of its demand 72.32 from parking slot 75 .
#
#  Demand point 355 receives 71.65 of its demand 71.65 from parking slot 75 .
#
#  Demand point 356 receives 72.06 of its demand 72.06 from parking slot 93 .
#
#  Demand point 357 receives 108.16 of its demand 108.16 from parking slot 93 .
#
#  Demand point 358 receives 121.63 of its demand 121.63 from parking slot 93 .
#
#  Demand point 359 receives 180.62 of its demand 180.62 from parking slot 93 .
#
#  Demand point 360 receives 248.62 of its demand 248.62 from parking slot 93 .
#
#  Demand point 361 receives 236.32 of its demand 236.32 from parking slot 93 .
#
#  Demand point 362 receives 219.64 of its demand 219.64 from parking slot 93 .
#
#  Demand point 363 receives 248.97 of its demand 248.97 from parking slot 77 .
#
#  Demand point 364 receives 201.14 of its demand 201.14 from parking slot 77 .
#
#  Demand point 365 receives 156.64 of its demand 156.64 from parking slot 77 .
#
#  Demand point 366 receives 181.34 of its demand 181.34 from parking slot 1 .
#
#  Demand point 367 receives 131.85 of its demand 131.85 from parking slot 1 .
#
#  Demand point 368 receives 131.85 of its demand 131.85 from parking slot 1 .
#
#  Demand point 369 receives 102.72 of its demand 102.72 from parking slot 1 .
#
#  Demand point 370 receives 128.6 of its demand 128.6 from parking slot 1 .
#
#  Demand point 371 receives 105.51 of its demand 105.51 from parking slot 11 .
#
#  Demand point 372 receives 77.8 of its demand 77.8 from parking slot 11 .
#
#  Demand point 373 receives 95.88 of its demand 95.88 from parking slot 11 .
#
#  Demand point 374 receives 84.49 of its demand 84.49 from parking slot 11 .
#
#  Demand point 375 receives 84.56 of its demand 84.56 from parking slot 11 .
#
#  Demand point 376 receives 60.48 of its demand 87.43 from parking slot 11 .
#
#  Demand point 376 receives 26.95 of its demand 87.43 from parking slot 36 .
#
#  Demand point 377 receives 122.11 of its demand 122.11 from parking slot 36 .
#
#  Demand point 378 receives 103.85 of its demand 103.85 from parking slot 36 .
#
#  Demand point 379 receives 68.69 of its demand 68.69 from parking slot 36 .
#
#  Demand point 380 receives 3.93 of its demand 3.93 from parking slot 36 .
#
#  Demand point 381 receives 4.0 of its demand 4.0 from parking slot 36 .
#
#  Demand point 382 receives 2.01 of its demand 2.01 from parking slot 36 .
#
#  Demand point 383 receives 4.75 of its demand 4.75 from parking slot 36 .
#
#  Demand point 384 receives 2.87 of its demand 2.87 from parking slot 60 .
#
#  Demand point 385 receives 46.12 of its demand 46.12 from parking slot 89 .
#
#  Demand point 386 receives 43.74 of its demand 43.74 from parking slot 89 .
#
#  Demand point 387 receives 34.5 of its demand 34.5 from parking slot 89 .
#
#  Demand point 388 receives 11.8 of its demand 11.8 from parking slot 89 .
#
#  Demand point 389 receives 25.11 of its demand 25.11 from parking slot 89 .
#
#  Demand point 390 receives 24.92 of its demand 24.92 from parking slot 39 .
#
#  Demand point 391 receives 30.5 of its demand 30.5 from parking slot 39 .
#
#  Demand point 392 receives 34.09 of its demand 34.09 from parking slot 39 .
#
#  Demand point 393 receives 38.72 of its demand 38.72 from parking slot 39 .
#
#  Demand point 394 receives 54.48 of its demand 54.48 from parking slot 39 .
#
#  Demand point 395 receives 55.72 of its demand 55.72 from parking slot 39 .
#
#  Demand point 396 receives 52.93 of its demand 52.93 from parking slot 25 .
#
#  Demand point 397 receives 41.72 of its demand 41.72 from parking slot 25 .
#
#  Demand point 398 receives 40.85 of its demand 40.85 from parking slot 25 .
#
#  Demand point 399 receives 36.6 of its demand 36.6 from parking slot 25 .
#
#  Demand point 400 receives 32.13 of its demand 32.13 from parking slot 25 .
#
#  Demand point 401 receives 29.5 of its demand 29.5 from parking slot 58 .
#
#  Demand point 402 receives 29.45 of its demand 29.45 from parking slot 58 .
#
#  Demand point 403 receives 29.88 of its demand 29.88 from parking slot 100 .
#
#  Demand point 404 receives 32.23 of its demand 32.23 from parking slot 100 .
#
#  Demand point 405 receives 33.41 of its demand 33.41 from parking slot 100 .
#
#  Demand point 406 receives 32.97 of its demand 32.97 from parking slot 100 .
#
#  Demand point 407 receives 46.42 of its demand 46.42 from parking slot 100 .
#
#  Demand point 408 receives 51.47 of its demand 51.47 from parking slot 100 .
#
#  Demand point 409 receives 54.79 of its demand 54.79 from parking slot 100 .
#
#  Demand point 410 receives 36.67 of its demand 56.17 from parking slot 75 .
#
#  Demand point 410 receives 19.5 of its demand 56.17 from parking slot 100 .
#
#  Demand point 411 receives 52.12 of its demand 52.12 from parking slot 75 .
#
#  Demand point 412 receives 52.71 of its demand 52.71 from parking slot 75 .
#
#  Demand point 413 receives 60.63 of its demand 60.63 from parking slot 75 .
#
#  Demand point 414 receives 62.51 of its demand 62.51 from parking slot 75 .
#
#  Demand point 415 receives 59.59 of its demand 59.59 from parking slot 75 .
#
#  Demand point 416 receives 59.6 of its demand 59.6 from parking slot 75 .
#
#  Demand point 417 receives 60.77 of its demand 60.77 from parking slot 75 .
#
#  Demand point 419 receives 67.11 of its demand 67.11 from parking slot 75 .
#
#  Demand point 420 receives 72.81 of its demand 72.81 from parking slot 93 .
#
#  Demand point 421 receives 102.78 of its demand 102.78 from parking slot 93 .
#
#  Demand point 422 receives 257.84 of its demand 257.84 from parking slot 93 .
#
#  Demand point 423 receives 266.53 of its demand 266.53 from parking slot 93 .
#
#  Demand point 424 receives 262.98 of its demand 262.98 from parking slot 93 .
#
#  Demand point 425 receives 221.29 of its demand 221.29 from parking slot 93 .
#
#  Demand point 426 receives 221.02 of its demand 221.02 from parking slot 93 .
#
#  Demand point 427 receives 203.27 of its demand 203.27 from parking slot 93 .
#
#  Demand point 428 receives 204.03 of its demand 204.03 from parking slot 70 .
#
#  Demand point 429 receives 185.9 of its demand 185.9 from parking slot 96 .
#
#  Demand point 430 receives 157.64 of its demand 157.64 from parking slot 1 .
#
#  Demand point 431 receives 226.32 of its demand 226.32 from parking slot 1 .
#
#  Demand point 432 receives 148.5 of its demand 148.5 from parking slot 1 .
#
#  Demand point 433 receives 61.41 of its demand 61.41 from parking slot 1 .
#
#  Demand point 434 receives 70.29 of its demand 70.29 from parking slot 1 .
#
#  Demand point 435 receives 64.24 of its demand 64.24 from parking slot 1 .
#
#  Demand point 436 receives 82.63 of its demand 82.63 from parking slot 11 .
#
#  Demand point 437 receives 72.67 of its demand 72.67 from parking slot 11 .
#
#  Demand point 438 receives 55.68 of its demand 55.68 from parking slot 11 .
#
#  Demand point 439 receives 52.91 of its demand 52.91 from parking slot 1 .
#
#  Demand point 440 receives 71.32 of its demand 71.32 from parking slot 36 .
#
#  Demand point 441 receives 101.69 of its demand 101.69 from parking slot 36 .
#
#  Demand point 442 receives 116.84 of its demand 116.84 from parking slot 36 .
#
#  Demand point 443 receives 105.0 of its demand 105.0 from parking slot 36 .
#
#  Demand point 444 receives 75.67 of its demand 75.67 from parking slot 36 .
#
#  Demand point 445 receives 63.14 of its demand 63.14 from parking slot 36 .
#
#  Demand point 446 receives 74.21 of its demand 74.21 from parking slot 36 .
#
#  Demand point 447 receives 44.94 of its demand 44.94 from parking slot 60 .
#
#  Demand point 448 receives 0.24 of its demand 0.24 from parking slot 60 .
#
#  Demand point 449 receives 46.41 of its demand 46.41 from parking slot 89 .
#
#  Demand point 450 receives 48.45 of its demand 48.45 from parking slot 89 .
#
#  Demand point 451 receives 34.45 of its demand 34.45 from parking slot 89 .
#
#  Demand point 452 receives 13.02 of its demand 13.02 from parking slot 89 .
#
#  Demand point 453 receives 24.43 of its demand 24.43 from parking slot 89 .
#
#  Demand point 454 receives 26.67 of its demand 26.67 from parking slot 89 .
#
#  Demand point 455 receives 31.53 of its demand 31.53 from parking slot 39 .
#
#  Demand point 456 receives 34.67 of its demand 34.67 from parking slot 39 .
#
#  Demand point 457 receives 35.55 of its demand 35.55 from parking slot 39 .
#
#  Demand point 458 receives 36.44 of its demand 36.44 from parking slot 39 .
#
#  Demand point 459 receives 44.34 of its demand 44.34 from parking slot 39 .
#
#  Demand point 460 receives 50.54 of its demand 50.54 from parking slot 25 .
#
#  Demand point 461 receives 48.52 of its demand 48.52 from parking slot 25 .
#
#  Demand point 462 receives 45.65 of its demand 45.65 from parking slot 25 .
#
#  Demand point 463 receives 14.56 of its demand 14.56 from parking slot 25 .
#
#  Demand point 464 receives 42.58 of its demand 42.58 from parking slot 25 .
#
#  Demand point 465 receives 41.33 of its demand 41.33 from parking slot 58 .
#
#  Demand point 466 receives 34.84 of its demand 34.84 from parking slot 58 .
#
#  Demand point 467 receives 34.46 of its demand 34.46 from parking slot 100 .
#
#  Demand point 468 receives 35.87 of its demand 35.87 from parking slot 100 .
#
#  Demand point 469 receives 34.16 of its demand 34.16 from parking slot 100 .
#
#  Demand point 470 receives 30.57 of its demand 30.57 from parking slot 100 .
#
#  Demand point 471 receives 42.78 of its demand 42.78 from parking slot 100 .
#
#  Demand point 472 receives 56.61 of its demand 56.61 from parking slot 100 .
#
#  Demand point 473 receives 47.72 of its demand 47.72 from parking slot 100 .
#
#  Demand point 474 receives 47.08 of its demand 47.08 from parking slot 100 .
#
#  Demand point 475 receives 58.94 of its demand 58.94 from parking slot 75 .
#
#  Demand point 476 receives 52.44 of its demand 52.44 from parking slot 75 .
#
#  Demand point 477 receives 51.85 of its demand 51.85 from parking slot 75 .
#
#  Demand point 478 receives 51.86 of its demand 51.86 from parking slot 75 .
#
#  Demand point 479 receives 59.36 of its demand 59.36 from parking slot 75 .
#
#  Demand point 480 receives 61.08 of its demand 61.08 from parking slot 75 .
#
#  Demand point 481 receives 54.16 of its demand 54.16 from parking slot 75 .
#
#  Demand point 482 receives 61.64 of its demand 61.64 from parking slot 75 .
#
#  Demand point 483 receives 54.71 of its demand 54.71 from parking slot 70 .
#
#  Demand point 484 receives 85.41 of its demand 85.41 from parking slot 93 .
#
#  Demand point 485 receives 95.94 of its demand 95.94 from parking slot 93 .
#
#  Demand point 486 receives 103.47 of its demand 103.47 from parking slot 93 .
#
#  Demand point 487 receives 121.45 of its demand 121.45 from parking slot 93 .
#
#  Demand point 488 receives 210.84 of its demand 210.84 from parking slot 93 .
#
#  Demand point 489 receives 229.33 of its demand 229.33 from parking slot 93 .
#
#  Demand point 490 receives 77.21 of its demand 292.02 from parking slot 70 .
#
#  Demand point 490 receives 214.81 of its demand 292.02 from parking slot 93 .
#
#  Demand point 491 receives 274.64 of its demand 274.64 from parking slot 70 .
#
#  Demand point 492 receives 226.49 of its demand 226.49 from parking slot 70 .
#
#  Demand point 493 receives 196.36 of its demand 196.36 from parking slot 96 .
#
#  Demand point 494 receives 217.51 of its demand 217.51 from parking slot 96 .
#
#  Demand point 495 receives 227.47 of its demand 227.47 from parking slot 1 .
#
#  Demand point 496 receives 144.35 of its demand 144.35 from parking slot 1 .
#
#  Demand point 497 receives 64.43 of its demand 64.43 from parking slot 1 .
#
#  Demand point 498 receives 60.06 of its demand 60.06 from parking slot 1 .
#
#  Demand point 499 receives 60.59 of its demand 60.59 from parking slot 1 .
#
#  Demand point 500 receives 57.08 of its demand 57.08 from parking slot 1 .
#
#  Demand point 501 receives 57.05 of its demand 57.05 from parking slot 1 .
#
#  Demand point 502 receives 65.52 of its demand 65.52 from parking slot 1 .
#
#  Demand point 503 receives 67.47 of its demand 67.47 from parking slot 1 .
#
#  Demand point 504 receives 134.31 of its demand 134.31 from parking slot 36 .
#
#  Demand point 505 receives 124.38 of its demand 124.38 from parking slot 36 .
#
#  Demand point 506 receives 70.8 of its demand 70.8 from parking slot 36 .
#
#  Demand point 507 receives 61.75 of its demand 61.75 from parking slot 36 .
#
#  Demand point 508 receives 49.6 of its demand 49.6 from parking slot 36 .
#
#  Demand point 509 receives 72.27 of its demand 72.27 from parking slot 36 .
#
#  Demand point 510 receives 53.83 of its demand 53.83 from parking slot 60 .
#
#  Demand point 511 receives 1.27 of its demand 1.27 from parking slot 60 .
#
#  Demand point 513 receives 43.73 of its demand 43.73 from parking slot 89 .
#
#  Demand point 514 receives 38.91 of its demand 38.91 from parking slot 89 .
#
#  Demand point 515 receives 34.04 of its demand 34.04 from parking slot 89 .
#
#  Demand point 516 receives 13.25 of its demand 13.25 from parking slot 89 .
#
#  Demand point 517 receives 26.06 of its demand 26.06 from parking slot 89 .
#
#  Demand point 518 receives 31.5 of its demand 31.5 from parking slot 89 .
#
#  Demand point 519 receives 33.97 of its demand 33.97 from parking slot 89 .
#
#  Demand point 520 receives 36.46 of its demand 36.46 from parking slot 39 .
#
#  Demand point 521 receives 40.92 of its demand 40.92 from parking slot 39 .
#
#  Demand point 522 receives 40.35 of its demand 40.35 from parking slot 39 .
#
#  Demand point 523 receives 15.71 of its demand 47.24 from parking slot 25 .
#
#  Demand point 523 receives 31.52 of its demand 47.24 from parking slot 39 .
#
#  Demand point 524 receives 52.21 of its demand 52.21 from parking slot 25 .
#
#  Demand point 525 receives 57.77 of its demand 57.77 from parking slot 25 .
#
#  Demand point 526 receives 52.65 of its demand 52.65 from parking slot 25 .
#
#  Demand point 527 receives 58.79 of its demand 58.79 from parking slot 25 .
#
#  Demand point 528 receives 5.55 of its demand 52.27 from parking slot 25 .
#
#  Demand point 528 receives 46.72 of its demand 52.27 from parking slot 58 .
#
#  Demand point 529 receives 49.56 of its demand 49.56 from parking slot 58 .
#
#  Demand point 530 receives 39.36 of its demand 39.36 from parking slot 58 .
#
#  Demand point 531 receives 44.42 of its demand 44.42 from parking slot 100 .
#
#  Demand point 532 receives 45.88 of its demand 45.88 from parking slot 100 .
#
#  Demand point 533 receives 36.92 of its demand 36.92 from parking slot 100 .
#
#  Demand point 534 receives 35.38 of its demand 35.38 from parking slot 100 .
#
#  Demand point 535 receives 45.73 of its demand 45.73 from parking slot 100 .
#
#  Demand point 536 receives 48.79 of its demand 48.79 from parking slot 100 .
#
#  Demand point 537 receives 57.98 of its demand 57.98 from parking slot 100 .
#
#  Demand point 538 receives 49.2 of its demand 49.2 from parking slot 100 .
#
#  Demand point 539 receives 66.93 of its demand 66.93 from parking slot 100 .
#
#  Demand point 540 receives 76.64 of its demand 76.64 from parking slot 75 .
#
#  Demand point 541 receives 57.72 of its demand 57.72 from parking slot 75 .
#
#  Demand point 542 receives 55.88 of its demand 55.88 from parking slot 75 .
#
#  Demand point 543 receives 78.13 of its demand 78.13 from parking slot 75 .
#
#  Demand point 544 receives 62.03 of its demand 62.03 from parking slot 75 .
#
#  Demand point 545 receives 61.02 of its demand 61.02 from parking slot 75 .
#
#  Demand point 546 receives 116.77 of its demand 116.77 from parking slot 75 .
#
#  Demand point 547 receives 91.77 of its demand 91.77 from parking slot 70 .
#
#  Demand point 548 receives 90.51 of its demand 90.51 from parking slot 70 .
#
#  Demand point 549 receives 62.35 of its demand 62.35 from parking slot 70 .
#
#  Demand point 550 receives 73.37 of its demand 73.37 from parking slot 70 .
#
#  Demand point 551 receives 95.15 of its demand 95.15 from parking slot 70 .
#
#  Demand point 552 receives 113.05 of its demand 113.05 from parking slot 70 .
#
#  Demand point 553 receives 160.38 of its demand 160.38 from parking slot 70 .
#
#  Demand point 554 receives 230.29 of its demand 230.29 from parking slot 70 .
#
#  Demand point 555 receives 234.65 of its demand 234.65 from parking slot 70 .
#
#  Demand point 556 receives 210.22 of its demand 210.22 from parking slot 70 .
#
#  Demand point 557 receives 168.3 of its demand 168.3 from parking slot 96 .
#
#  Demand point 558 receives 149.55 of its demand 149.55 from parking slot 96 .
#
#  Demand point 559 receives 127.48 of its demand 127.48 from parking slot 1 .
#
#  Demand point 560 receives 82.1 of its demand 82.1 from parking slot 1 .
#
#  Demand point 561 receives 82.93 of its demand 82.93 from parking slot 1 .
#
#  Demand point 562 receives 69.65 of its demand 69.65 from parking slot 1 .
#
#  Demand point 563 receives 55.23 of its demand 55.23 from parking slot 1 .
#
#  Demand point 564 receives 59.82 of its demand 59.82 from parking slot 1 .
#
#  Demand point 565 receives 69.46 of its demand 69.46 from parking slot 1 .
#
#  Demand point 566 receives 60.41 of its demand 60.41 from parking slot 1 .
#
#  Demand point 567 receives 54.54 of its demand 54.54 from parking slot 1 .
#
#  Demand point 568 receives 62.56 of its demand 62.56 from parking slot 36 .
#
#  Demand point 569 receives 80.2 of its demand 80.2 from parking slot 36 .
#
#  Demand point 570 receives 53.29 of its demand 53.29 from parking slot 36 .
#
#  Demand point 571 receives 69.36 of its demand 69.36 from parking slot 36 .
#
#  Demand point 572 receives 58.34 of its demand 58.34 from parking slot 36 .
#
#  Demand point 573 receives 53.54 of its demand 53.54 from parking slot 60 .
#
#  Demand point 574 receives 42.76 of its demand 42.76 from parking slot 60 .
#
#  Demand point 575 receives 1.53 of its demand 1.53 from parking slot 60 .
#
#  Demand point 576 receives 1.58 of its demand 1.58 from parking slot 60 .
#
#  Demand point 577 receives 45.61 of its demand 45.61 from parking slot 89 .
#
#  Demand point 578 receives 36.81 of its demand 36.81 from parking slot 89 .
#
#  Demand point 579 receives 33.76 of its demand 33.76 from parking slot 89 .
#
#  Demand point 580 receives 32.32 of its demand 32.32 from parking slot 89 .
#
#  Demand point 581 receives 34.02 of its demand 34.02 from parking slot 89 .
#
#  Demand point 582 receives 37.08 of its demand 37.08 from parking slot 89 .
#
#  Demand point 583 receives 32.03 of its demand 32.03 from parking slot 89 .
#
#  Demand point 584 receives 36.07 of its demand 36.07 from parking slot 89 .
#
#  Demand point 585 receives 41.91 of its demand 41.91 from parking slot 39 .
#
#  Demand point 586 receives 43.56 of its demand 43.56 from parking slot 39 .
#
#  Demand point 587 receives 49.37 of its demand 49.37 from parking slot 25 .
#
#  Demand point 588 receives 49.27 of its demand 49.27 from parking slot 25 .
#
#  Demand point 589 receives 53.3 of its demand 53.3 from parking slot 25 .
#
#  Demand point 590 receives 50.47 of its demand 50.47 from parking slot 25 .
#
#  Demand point 591 receives 47.03 of its demand 47.03 from parking slot 25 .
#
#  Demand point 592 receives 47.63 of its demand 47.63 from parking slot 58 .
#
#  Demand point 593 receives 46.8 of its demand 46.8 from parking slot 58 .
#
#  Demand point 594 receives 51.1 of its demand 51.1 from parking slot 58 .
#
#  Demand point 595 receives 52.13 of its demand 52.13 from parking slot 100 .
#
#  Demand point 597 receives 51.35 of its demand 51.35 from parking slot 100 .
#
#  Demand point 598 receives 50.63 of its demand 50.63 from parking slot 100 .
#
#  Demand point 599 receives 48.62 of its demand 48.62 from parking slot 100 .
#
#  Demand point 600 receives 51.62 of its demand 51.62 from parking slot 100 .
#
#  Demand point 601 receives 50.88 of its demand 50.88 from parking slot 100 .
#
#  Demand point 602 receives 59.22 of its demand 59.22 from parking slot 100 .
#
#  Demand point 603 receives 56.12 of its demand 56.12 from parking slot 100 .
#
#  Demand point 604 receives 80.46 of its demand 80.46 from parking slot 100 .
#
#  Demand point 605 receives 56.18 of its demand 56.18 from parking slot 75 .
#
#  Demand point 606 receives 81.0 of its demand 81.0 from parking slot 75 .
#
#  Demand point 607 receives 98.12 of its demand 98.12 from parking slot 75 .
#
#  Demand point 608 receives 69.44 of its demand 69.44 from parking slot 75 .
#
#  Demand point 609 receives 72.19 of its demand 72.19 from parking slot 75 .
#
#  Demand point 610 receives 192.46 of its demand 192.46 from parking slot 70 .
#
#  Demand point 611 receives 122.73 of its demand 122.73 from parking slot 70 .
#
#  Demand point 612 receives 76.16 of its demand 76.16 from parking slot 70 .
#
#  Demand point 613 receives 65.86 of its demand 65.86 from parking slot 70 .
#
#  Demand point 614 receives 59.61 of its demand 59.61 from parking slot 70 .
#
#  Demand point 615 receives 54.93 of its demand 54.93 from parking slot 70 .
#
#  Demand point 616 receives 62.98 of its demand 62.98 from parking slot 70 .
#
#  Demand point 617 receives 85.82 of its demand 85.82 from parking slot 70 .
#
#  Demand point 618 receives 119.52 of its demand 119.52 from parking slot 70 .
#
#  Demand point 619 receives 120.53 of its demand 120.53 from parking slot 70 .
#
#  Demand point 620 receives 88.28 of its demand 88.28 from parking slot 70 .
#
#  Demand point 621 receives 91.03 of its demand 91.03 from parking slot 96 .
#
#  Demand point 622 receives 96.02 of its demand 96.02 from parking slot 96 .
#
#  Demand point 623 receives 90.81 of its demand 90.81 from parking slot 1 .
#
#  Demand point 624 receives 74.7 of its demand 74.7 from parking slot 1 .
#
#  Demand point 625 receives 90.77 of its demand 90.77 from parking slot 1 .
#
# ...
#
#  Demand point 3887 receives 8.33 of its demand 8.33 from parking slot 3 .
#
#  Demand point 3888 receives 13.78 of its demand 13.78 from parking slot 3 .
#
#  Demand point 3889 receives 14.29 of its demand 14.29 from parking slot 3 .
#
#  Demand point 3890 receives 14.67 of its demand 14.67 from parking slot 3 .
#
#  Demand point 3891 receives 16.92 of its demand 16.92 from parking slot 3 .
#
#  Demand point 3892 receives 8.09 of its demand 8.09 from parking slot 3 .
#
#  Demand point 3893 receives 9.09 of its demand 9.09 from parking slot 3 .
#
#  Demand point 3894 receives 8.92 of its demand 8.92 from parking slot 3 .
#
#  Demand point 3895 receives 9.33 of its demand 9.33 from parking slot 3 .
#
#  Demand point 3896 receives 10.61 of its demand 10.61 from parking slot 3 .
#
#  Demand point 3897 receives 10.47 of its demand 10.47 from parking slot 17 .
#
#  Demand point 3898 receives 11.82 of its demand 11.82 from parking slot 17 .
#
#  Demand point 3899 receives 9.66 of its demand 9.66 from parking slot 17 .
#
#  Demand point 3900 receives 5.32 of its demand 5.32 from parking slot 17 .
#
#  Demand point 3901 receives 2.58 of its demand 2.58 from parking slot 17 .
#
#  Demand point 3902 receives 54.33 of its demand 54.33 from parking slot 17 .
#
#  Demand point 3903 receives 58.7 of its demand 58.7 from parking slot 17 .
#
#  Demand point 3904 receives 57.96 of its demand 57.96 from parking slot 17 .
#
#  Demand point 3905 receives 1.19 of its demand 1.19 from parking slot 62 .
#
#  Demand point 3906 receives 1.29 of its demand 1.29 from parking slot 62 .
#
#  Demand point 3907 receives 1.53 of its demand 1.53 from parking slot 62 .
#
#  Demand point 3908 receives 1.46 of its demand 1.46 from parking slot 62 .
#
#  Demand point 3909 receives 1.77 of its demand 1.77 from parking slot 62 .
#
#  Demand point 3910 receives 2.21 of its demand 2.21 from parking slot 62 .
#
#  Demand point 3911 receives 2.79 of its demand 2.79 from parking slot 62 .
#
#  Demand point 3912 receives 2.9 of its demand 2.9 from parking slot 62 .
#
#  Demand point 3913 receives 2.67 of its demand 2.67 from parking slot 45 .
#
#  Demand point 3914 receives 2.61 of its demand 2.61 from parking slot 45 .
#
#  Demand point 3915 receives 0.56 of its demand 0.56 from parking slot 45 .
#
#  Demand point 3916 receives 7.16 of its demand 7.16 from parking slot 45 .
#
#  Demand point 3917 receives 10.96 of its demand 10.96 from parking slot 45 .
#
#  Demand point 3918 receives 7.16 of its demand 7.16 from parking slot 45 .
#
#  Demand point 3919 receives 7.54 of its demand 7.54 from parking slot 45 .
#
#  Demand point 3920 receives 7.07 of its demand 7.07 from parking slot 45 .
#
#  Demand point 3921 receives 7.48 of its demand 7.48 from parking slot 45 .
#
#  Demand point 3922 receives 5.94 of its demand 5.94 from parking slot 94 .
#
#  Demand point 3923 receives 4.51 of its demand 4.51 from parking slot 94 .
#
#  Demand point 3924 receives 7.46 of its demand 7.46 from parking slot 94 .
#
#  Demand point 3925 receives 7.81 of its demand 7.81 from parking slot 94 .
#
#  Demand point 3926 receives 9.21 of its demand 9.21 from parking slot 94 .
#
#  Demand point 3927 receives 9.7 of its demand 9.7 from parking slot 94 .
#
#  Demand point 3928 receives 7.15 of its demand 7.15 from parking slot 94 .
#
#  Demand point 3929 receives 6.39 of its demand 6.39 from parking slot 94 .
#
#  Demand point 3930 receives 4.96 of its demand 4.96 from parking slot 94 .
#
#  Demand point 3931 receives 4.28 of its demand 4.28 from parking slot 53 .
#
#  Demand point 3932 receives 4.78 of its demand 4.78 from parking slot 6 .
#
#  Demand point 3933 receives 10.61 of its demand 10.61 from parking slot 6 .
#
#  Demand point 3934 receives 7.35 of its demand 7.35 from parking slot 6 .
#
#  Demand point 3935 receives 10.57 of its demand 10.57 from parking slot 6 .
#
#  Demand point 3936 receives 10.8 of its demand 10.8 from parking slot 6 .
#
#  Demand point 3937 receives 18.1 of its demand 18.1 from parking slot 6 .
#
#  Demand point 3938 receives 19.66 of its demand 19.66 from parking slot 6 .
#
#  Demand point 3939 receives 18.76 of its demand 18.76 from parking slot 6 .
#
#  Demand point 3940 receives 19.23 of its demand 19.23 from parking slot 6 .
#
#  Demand point 3941 receives 16.21 of its demand 16.21 from parking slot 6 .
#
#  Demand point 3942 receives 14.06 of its demand 14.06 from parking slot 2 .
#
#  Demand point 3943 receives 14.18 of its demand 14.18 from parking slot 2 .
#
#  Demand point 3944 receives 16.4 of its demand 16.4 from parking slot 2 .
#
#  Demand point 3945 receives 14.06 of its demand 14.06 from parking slot 2 .
#
#  Demand point 3946 receives 8.89 of its demand 8.89 from parking slot 3 .
#
#  Demand point 3947 receives 16.6 of its demand 16.6 from parking slot 3 .
#
#  Demand point 3948 receives 16.01 of its demand 16.01 from parking slot 3 .
#
#  Demand point 3949 receives 12.27 of its demand 12.27 from parking slot 3 .
#
#  Demand point 3950 receives 14.08 of its demand 14.08 from parking slot 3 .
#
#  Demand point 3951 receives 14.27 of its demand 14.27 from parking slot 3 .
#
#  Demand point 3952 receives 14.83 of its demand 14.83 from parking slot 3 .
#
#  Demand point 3953 receives 16.02 of its demand 16.02 from parking slot 3 .
#
#  Demand point 3954 receives 17.28 of its demand 17.28 from parking slot 3 .
#
#  Demand point 3955 receives 16.31 of its demand 16.31 from parking slot 3 .
#
#  Demand point 3956 receives 14.72 of its demand 14.72 from parking slot 3 .
#
#  Demand point 3957 receives 12.64 of its demand 12.64 from parking slot 3 .
#
#  Demand point 3958 receives 8.13 of its demand 8.13 from parking slot 3 .
#
#  Demand point 3959 receives 6.82 of its demand 6.82 from parking slot 3 .
#
#  Demand point 3960 receives 12.17 of its demand 12.17 from parking slot 3 .
#
#  Demand point 3961 receives 7.49 of its demand 7.49 from parking slot 3 .
#
#  Demand point 3962 receives 10.17 of its demand 10.17 from parking slot 3 .
#
#  Demand point 3963 receives 12.36 of its demand 12.36 from parking slot 17 .
#
#  Demand point 3964 receives 9.87 of its demand 9.87 from parking slot 17 .
#
#  Demand point 3965 receives 4.45 of its demand 4.45 from parking slot 17 .
#
#  Demand point 3966 receives 2.99 of its demand 2.99 from parking slot 17 .
#
#  Demand point 3967 receives 10.17 of its demand 10.17 from parking slot 17 .
#
#  Demand point 3968 receives 68.08 of its demand 68.08 from parking slot 17 .
#
#  Demand point 3969 receives 1.24 of its demand 1.24 from parking slot 62 .
#
#  Demand point 3970 receives 1.38 of its demand 1.38 from parking slot 62 .
#
#  Demand point 3971 receives 1.34 of its demand 1.34 from parking slot 62 .
#
#  Demand point 3972 receives 1.38 of its demand 1.38 from parking slot 62 .
#
#  Demand point 3973 receives 1.45 of its demand 1.45 from parking slot 62 .
#
#  Demand point 3974 receives 1.86 of its demand 1.86 from parking slot 62 .
#
#  Demand point 3975 receives 3.04 of its demand 3.04 from parking slot 62 .
#
#  Demand point 3976 receives 3.9 of its demand 3.9 from parking slot 62 .
#
#  Demand point 3977 receives 3.83 of its demand 3.83 from parking slot 62 .
#
#  Demand point 3978 receives 3.08 of its demand 3.08 from parking slot 45 .
#
#  Demand point 3979 receives 7.45 of its demand 7.45 from parking slot 45 .
#
#  Demand point 3980 receives 9.31 of its demand 9.31 from parking slot 45 .
#
#  Demand point 3981 receives 8.7 of its demand 8.7 from parking slot 45 .
#
#  Demand point 3982 receives 6.78 of its demand 6.78 from parking slot 45 .
#
#  Demand point 3983 receives 7.02 of its demand 7.02 from parking slot 45 .
#
#  Demand point 3984 receives 6.56 of its demand 6.56 from parking slot 45 .
#
#  Demand point 3985 receives 6.81 of its demand 6.81 from parking slot 45 .
#
#  Demand point 3986 receives 6.4 of its demand 6.4 from parking slot 94 .
#
#  Demand point 3987 receives 6.65 of its demand 6.65 from parking slot 94 .
#
#  Demand point 3988 receives 7.45 of its demand 7.45 from parking slot 94 .
#
#  Demand point 3989 receives 7.6 of its demand 7.6 from parking slot 94 .
#
#  Demand point 3990 receives 11.31 of its demand 11.31 from parking slot 94 .
#
#  Demand point 3991 receives 11.24 of its demand 11.24 from parking slot 94 .
#
#  Demand point 3992 receives 8.52 of its demand 8.52 from parking slot 94 .
#
#  Demand point 3993 receives 3.88 of its demand 3.88 from parking slot 94 .
#
#  Demand point 3994 receives 3.22 of its demand 3.22 from parking slot 94 .
#
#  Demand point 3995 receives 2.67 of its demand 2.67 from parking slot 6 .
#
#  Demand point 3996 receives 3.58 of its demand 3.58 from parking slot 6 .
#
#  Demand point 3997 receives 5.37 of its demand 5.37 from parking slot 6 .
#
#  Demand point 3998 receives 10.44 of its demand 10.44 from parking slot 6 .
#
#  Demand point 3999 receives 14.59 of its demand 14.59 from parking slot 6 .
#
#  Demand point 4000 receives 11.01 of its demand 11.01 from parking slot 6 .
#
#  Demand point 4001 receives 19.02 of its demand 19.02 from parking slot 6 .
#
#  Demand point 4002 receives 19.4 of its demand 19.4 from parking slot 6 .
#
#  Demand point 4003 receives 9.12 of its demand 9.12 from parking slot 6 .
#
#  Demand point 4004 receives 17.24 of its demand 17.24 from parking slot 6 .
#
#  Demand point 4005 receives 19.0 of its demand 19.0 from parking slot 6 .
#
#  Demand point 4006 receives 13.85 of its demand 13.85 from parking slot 6 .
#
#  Demand point 4007 receives 13.36 of its demand 13.36 from parking slot 2 .
#
#  Demand point 4008 receives 17.65 of its demand 17.65 from parking slot 2 .
#
#  Demand point 4009 receives 17.24 of its demand 17.24 from parking slot 2 .
#
#  Demand point 4010 receives 10.65 of its demand 10.65 from parking slot 3 .
#
#  Demand point 4011 receives 16.42 of its demand 16.42 from parking slot 3 .
#
#  Demand point 4012 receives 15.96 of its demand 15.96 from parking slot 3 .
#
#  Demand point 4013 receives 12.31 of its demand 12.31 from parking slot 3 .
#
#  Demand point 4014 receives 11.81 of its demand 11.81 from parking slot 3 .
#
#  Demand point 4015 receives 11.46 of its demand 11.46 from parking slot 3 .
#
#  Demand point 4016 receives 12.12 of its demand 12.12 from parking slot 3 .
#
#  Demand point 4017 receives 17.24 of its demand 17.24 from parking slot 3 .
#
#  Demand point 4018 receives 17.84 of its demand 17.84 from parking slot 3 .
#
#  Demand point 4019 receives 18.8 of its demand 18.8 from parking slot 3 .
#
#  Demand point 4020 receives 18.41 of its demand 18.41 from parking slot 3 .
#
#  Demand point 4021 receives 15.87 of its demand 15.87 from parking slot 3 .
#
#  Demand point 4022 receives 14.36 of its demand 14.36 from parking slot 3 .
#
#  Demand point 4023 receives 8.22 of its demand 8.22 from parking slot 3 .
#
#  Demand point 4024 receives 5.79 of its demand 5.79 from parking slot 3 .
#
#  Demand point 4025 receives 5.15 of its demand 5.15 from parking slot 3 .
#
#  Demand point 4026 receives 6.69 of its demand 6.69 from parking slot 3 .
#
#  Demand point 4027 receives 9.97 of its demand 9.97 from parking slot 3 .
#
#  Demand point 4028 receives 9.32 of its demand 9.32 from parking slot 3 .
#
#  Demand point 4029 receives 3.75 of its demand 3.75 from parking slot 17 .
#
#  Demand point 4030 receives 2.18 of its demand 2.18 from parking slot 17 .
#
#  Demand point 4031 receives 4.7 of its demand 4.7 from parking slot 17 .
#
#  Demand point 4032 receives 7.76 of its demand 7.76 from parking slot 17 .
#
#  Demand point 4033 receives 1.33 of its demand 1.33 from parking slot 62 .
#
#  Demand point 4034 receives 1.42 of its demand 1.42 from parking slot 62 .
#
#  Demand point 4035 receives 1.53 of its demand 1.53 from parking slot 62 .
#
#  Demand point 4036 receives 1.79 of its demand 1.79 from parking slot 62 .
#
#  Demand point 4037 receives 2.12 of its demand 2.12 from parking slot 62 .
#
#  Demand point 4038 receives 2.16 of its demand 2.16 from parking slot 62 .
#
#  Demand point 4039 receives 3.21 of its demand 3.21 from parking slot 62 .
#
#  Demand point 4040 receives 4.49 of its demand 4.49 from parking slot 62 .
#
#  Demand point 4041 receives 4.66 of its demand 4.66 from parking slot 62 .
#
#  Demand point 4042 receives 6.91 of its demand 6.91 from parking slot 62 .
#
#  Demand point 4043 receives 8.49 of its demand 8.49 from parking slot 45 .
#
#  Demand point 4044 receives 7.55 of its demand 7.55 from parking slot 45 .
#
#  Demand point 4045 receives 5.65 of its demand 5.65 from parking slot 45 .
#
#  Demand point 4046 receives 5.92 of its demand 5.92 from parking slot 45 .
#
#  Demand point 4047 receives 5.44 of its demand 5.44 from parking slot 45 .
#
#  Demand point 4048 receives 5.06 of its demand 5.06 from parking slot 45 .
#
#  Demand point 4049 receives 6.17 of its demand 6.17 from parking slot 45 .
#
#  Demand point 4050 receives 5.18 of its demand 5.18 from parking slot 94 .
#
#  Demand point 4051 receives 7.92 of its demand 7.92 from parking slot 94 .
#
#  Demand point 4052 receives 9.93 of its demand 9.93 from parking slot 94 .
#
#  Demand point 4053 receives 9.75 of its demand 9.75 from parking slot 94 .
#
#  Demand point 4054 receives 10.73 of its demand 10.73 from parking slot 94 .
#
#  Demand point 4055 receives 11.13 of its demand 11.13 from parking slot 94 .
#
#  Demand point 4056 receives 11.59 of its demand 11.59 from parking slot 94 .
#
#  Demand point 4057 receives 5.87 of its demand 5.87 from parking slot 94 .
#
#  Demand point 4058 receives 4.02 of its demand 4.02 from parking slot 6 .
#
#  Demand point 4059 receives 2.65 of its demand 2.65 from parking slot 6 .
#
#  Demand point 4060 receives 2.27 of its demand 2.27 from parking slot 6 .
#
#  Demand point 4061 receives 4.16 of its demand 4.16 from parking slot 6 .
#
#  Demand point 4062 receives 11.3 of its demand 11.3 from parking slot 6 .
#
#  Demand point 4063 receives 12.24 of its demand 12.24 from parking slot 6 .
#
#  Demand point 4064 receives 10.76 of its demand 10.76 from parking slot 6 .
#
#  Demand point 4065 receives 17.14 of its demand 17.14 from parking slot 6 .
#
#  Demand point 4066 receives 19.25 of its demand 19.25 from parking slot 6 .
#
#  Demand point 4067 receives 19.9 of its demand 19.9 from parking slot 6 .
#
#  Demand point 4068 receives 19.23 of its demand 19.23 from parking slot 6 .
#
#  Demand point 4069 receives 15.56 of its demand 15.56 from parking slot 6 .
#
#  Demand point 4070 receives 14.0 of its demand 14.0 from parking slot 6 .
#
#  Demand point 4071 receives 14.15 of its demand 14.15 from parking slot 2 .
#
#  Demand point 4072 receives 16.02 of its demand 16.02 from parking slot 2 .
#
#  Demand point 4073 receives 16.6 of its demand 16.6 from parking slot 2 .
#
#  Demand point 4074 receives 19.42 of its demand 19.42 from parking slot 3 .
#
#  Demand point 4075 receives 18.12 of its demand 18.12 from parking slot 3 .
#
#  Demand point 4076 receives 15.74 of its demand 15.74 from parking slot 3 .
#
#  Demand point 4077 receives 13.49 of its demand 13.49 from parking slot 3 .
#
#  Demand point 4078 receives 11.5 of its demand 11.5 from parking slot 3 .
#
#  Demand point 4079 receives 11.02 of its demand 11.02 from parking slot 3 .
#
#  Demand point 4080 receives 13.34 of its demand 13.34 from parking slot 3 .
#
#  Demand point 4081 receives 16.7 of its demand 16.7 from parking slot 3 .
#
#  Demand point 4082 receives 19.01 of its demand 19.01 from parking slot 3 .
#
#  Demand point 4083 receives 16.65 of its demand 16.65 from parking slot 3 .
#
#  Demand point 4084 receives 18.55 of its demand 18.55 from parking slot 3 .
#
#  Demand point 4085 receives 12.5 of its demand 12.5 from parking slot 3 .
#
#  Demand point 4086 receives 15.23 of its demand 15.23 from parking slot 3 .
#
#  Demand point 4087 receives 7.98 of its demand 7.98 from parking slot 3 .
#
#  Demand point 4088 receives 4.24 of its demand 4.24 from parking slot 3 .
#
#  Demand point 4089 receives 3.61 of its demand 3.61 from parking slot 3 .
#
#  Demand point 4090 receives 5.67 of its demand 5.67 from parking slot 3 .
#
#  Demand point 4091 receives 11.63 of its demand 11.63 from parking slot 3 .
#
#  Demand point 4092 receives 8.41 of its demand 8.41 from parking slot 3 .
#
#  Demand point 4093 receives 2.58 of its demand 2.58 from parking slot 3 .
#
#  Demand point 4094 receives 4.79 of its demand 4.79 from parking slot 3 .
#
#  Demand point 4095 receives 9.39 of its demand 9.39 from parking slot 17 .
#
#  Demand point 4096 receives 10.35 of its demand 10.35 from parking slot 17 .

# %%
total_supply = 0
for j in range(num_facilities):
    total_supply += slow[j].solution_value()*200 + fast[j].solution_value()*400

# %%
sum(demands), total_supply
# Out:
# (444363.90464364795, 473600.0)

# %%
total_demand = 0.0
for i in range(num_customers):
    for j in range(num_facilities):
        total_demand += assign[(i,j)].solution_value()

# %%
sum(demands), total_demand
# Out:
# (444363.90464364795, 444363.90464364795)

# %%
df = pd.DataFrame(["year", "data_type", "demand_point_index", "supply_point_index", "value"])

# %%
slow_list = []
for j in range(num_facilities):
    slow_list.append((2019, "SCS", "", j, slow[j].solution_value()))
fast_list = []
for j in range(num_facilities):
    fast_list.append((2019, "FCS", "", j, fast[j].solution_value()))

# %%
assign_list = []
for i in range(num_customers):
    for j in range(num_facilities):
        assign_list.append((2019, "DS", i, j, assign[(i,j)].solution_value()))

# %%
result = slow_list + fast_list + assign_list

# %%
df_result = pd.DataFrame(result, columns=["year", "data_type", "demand_point_index", "supply_point_index", "value"])

# %%
df_result
# Out:
#         year data_type demand_point_index  supply_point_index  value
# 0       2019       SCS                                      0    5.0
# 1       2019       SCS                                      1    4.0
# 2       2019       SCS                                      2    6.0
# 3       2019       SCS                                      3    5.0
# 4       2019       SCS                                      4   11.0
# ...      ...       ...                ...                 ...    ...
# 409795  2019        DS               4095                  95    0.0
# 409796  2019        DS               4095                  96    0.0
# 409797  2019        DS               4095                  97    0.0
# 409798  2019        DS               4095                  98    0.0
# 409799  2019        DS               4095                  99    0.0
#
# [409800 rows x 5 columns]

# %%
df_result.to_csv("../data/processed/result_2019.csv")

# %%
supply_2019 = supply.copy()
supply_2019["existing_num_SCS"] = [entry[4] for entry in slow_list]
supply_2019["existing_num_FCS"] = [entry[4] for entry in fast_list]

# %%
supply_2019
# Out:
#     supply_point_index  x_coordinate  y_coordinate  total_parking_slots  \
# 0                    0     50.163110     19.412014                   23
# 1                    1     37.336451     58.119225                   27
# 2                    2     46.709232     57.525650                   31
# 3                    3     30.528626     55.379835                   26
# 4                    4     51.521781     35.116755                   32
# ..                 ...           ...           ...                  ...
# 95                  95     45.471204     20.999414                   24
# 96                  96     30.318396     33.388335                   32
# 97                  97     36.218839     22.235766                   32
# 98                  98     42.936915     38.122442                   28
# 99                  99     19.590263      3.830284                   24
#
#     existing_num_SCS  existing_num_FCS
# 0                5.0              18.0
# 1                4.0               7.0
# 2                6.0              14.0
# 3                5.0               5.0
# 4               11.0               6.0
# ..               ...               ...
# 95               3.0              16.0
# 96               5.0              24.0
# 97               4.0              28.0
# 98               7.0               5.0
# 99               2.0              11.0
#
# [100 rows x 6 columns]

# %%
supply_2019.to_csv("../data/processed/exisiting_EV_infrastructure_2019.csv")
