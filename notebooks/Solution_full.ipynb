# %%
from math import sqrt
from itertools import product

import pandas as pd

from ortools.linear_solver import pywraplp
from ortools.init import pywrapinit

# %%
supply = pd.read_csv("../data/raw/exisiting_EV_infrastructure_2018.csv")

# %%
demand = pd.read_csv("../data/raw/Demand_History.csv")

# %%
slow_charger = 200
slow_costs = 1.0*600
fast_charger = 400
fast_costs = 1.5*600

facilities = list(supply[["x_coordinate","y_coordinate"]].itertuples(index=False, name=None))
# real capacities
real_capacities = (supply["existing_num_SCS"]*slow_charger + supply["existing_num_FCS"]*fast_charger).tolist()
# maximum theoretical capacities
capacities = (supply["total_parking_slots"]*fast_charger).tolist()
# maximum slots for chargers
slots = supply["total_parking_slots"].tolist()

slow_slots = supply["existing_num_SCS"].tolist()
fast_slots = supply["existing_num_FCS"].tolist()

## For testing 
# slow_slots = [0]*len(facilities)
# fast_slots = [0]*len(facilities)

customers = list(demand[["x_coordinate","y_coordinate"]].itertuples(index=False, name=None))
demands = demand["2018"].tolist()

# %%
sum(capacities) > sum(demands), sum(capacities), sum(demands), sum(real_capacities)
# Out:
# (True, 1000000, 361529.6365968905, 361600)

# %%
# This function determines the Euclidean distance between a facility and customer sites.

def compute_distance(loc1, loc2):
    dx = loc1[0] - loc2[0]
    dy = loc1[1] - loc2[1]
    return sqrt(dx*dx + dy*dy)

# %%
# Compute key parameters of MIP model formulation

num_facilities = len(facilities)
num_customers = len(customers)
cartesian_prod = list(product(range(num_customers), range(num_facilities)))

# %%
# Compute distance matrix

distance = {(c,f): compute_distance(customers[c], facilities[f]) for c, f in cartesian_prod}

# %%
# solver = pywraplp.Solver.CreateSolver('CBC_MIXED_INTEGER_PROGRAMMING')
solver = pywraplp.Solver.CreateSolver('SCIP_MIXED_INTEGER_PROGRAMMING')

# %%
assign = {}
for i,j in distance.keys(): 
    assign[(i,j)] = solver.NumVar(0,solver.infinity(),"Assign")

# %%
# Constraint/Boundaries 2 
slow = {}
for j in range(num_facilities):
    slow[j] = solver.IntVar(slow_slots[j], solver.infinity(), "Slow")

fast = {}
for j in range(num_facilities):
    fast[j] = solver.IntVar(fast_slots[j], solver.infinity(), "Fast")

# %%
# Constraint 3 (slots)
for j in range(num_facilities):
    solver.Add(slow[j] + fast[j] <= slots[j])

# %%
# Constraint 5 (capacity constraints)
for j in range(num_facilities):
    solver.Add(sum(assign[(i,j)] for i in range(num_customers)) <= (slow[j]*200 + fast[j]*400))

# %%
# Constraint 6 (demand constraints)
for i in range(num_customers):
    solver.Add(sum(assign[(i,j)] for j in range(num_facilities)) == demands[i] )

# %%
objective = solver.Objective()

# %%
for j in range(num_facilities):
    objective.SetCoefficient(slow[j], slow_costs)
for j in range(num_facilities):
    objective.SetCoefficient(fast[j], fast_costs)

# %%
for i in range(num_customers):
    for j in range(num_facilities):
        objective.SetCoefficient(assign[(i,j)],distance[(i,j)])

# %%
objective.SetMinimization()

# %%
status = solver.Solve()

# %%
if status == pywraplp.Solver.OPTIMAL:
    print('Objective value =', solver.Objective().Value())
    print()
    print('Problem solved in %f milliseconds' % solver.wall_time())
    print('Problem solved in %d iterations' % solver.iterations())
    print('Problem solved in %d branch-and-bound nodes' % solver.nodes())
else:
    print('The problem does not have an optimal solution.')
# Out:
# Objective value = 2276576.673923479
#
# Problem solved in 19944.000000 milliseconds
# Problem solved in 14110 iterations
# Problem solved in 1 branch-and-bound nodes

# %%
# display optimal values of decision variables
for j in range(num_facilities):
    print(f"\n Build {slow[j].solution_value() - slow_slots[j]} slow charger  and {fast[j].solution_value() - fast_slots[j]} fast charger at location {j + 1}.")
# Out:
#  Build 0.0 slow charger  and 6.0 fast charger at location 1.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 2.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 3.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 4.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 5.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 6.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 7.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 8.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 9.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 10.
#
#  Build 0.0 slow charger  and 8.0 fast charger at location 11.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 12.
#
#  Build 0.0 slow charger  and 8.0 fast charger at location 13.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 14.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 15.
#
#  Build 0.0 slow charger  and 5.0 fast charger at location 16.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 17.
#
#  Build 0.0 slow charger  and 3.0 fast charger at location 18.
#
#  Build 0.0 slow charger  and 2.0 fast charger at location 19.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 20.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 21.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 22.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 23.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 24.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 25.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 26.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 27.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 28.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 29.
#
#  Build 0.0 slow charger  and 6.0 fast charger at location 30.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 31.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 32.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 33.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 34.
#
#  Build 0.0 slow charger  and 13.0 fast charger at location 35.
#
#  Build 0.0 slow charger  and 6.0 fast charger at location 36.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 37.
#
#  Build 0.0 slow charger  and 5.0 fast charger at location 38.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 39.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 40.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 41.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 42.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 43.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 44.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 45.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 46.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 47.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 48.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 49.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 50.
#
#  Build 0.0 slow charger  and 15.0 fast charger at location 51.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 52.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 53.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 54.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 55.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 56.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 57.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 58.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 59.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 60.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 61.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 62.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 63.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 64.
#
#  Build 0.0 slow charger  and 13.0 fast charger at location 65.
#
#  Build 0.0 slow charger  and 1.0 fast charger at location 66.
#
#  Build 0.0 slow charger  and 10.0 fast charger at location 67.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 68.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 69.
#
#  Build 0.0 slow charger  and 19.0 fast charger at location 70.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 71.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 72.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 73.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 74.
#
#  Build 0.0 slow charger  and 7.0 fast charger at location 75.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 76.
#
#  Build 0.0 slow charger  and 4.0 fast charger at location 77.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 78.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 79.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 80.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 81.
#
#  Build 0.0 slow charger  and 5.0 fast charger at location 82.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 83.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 84.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 85.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 86.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 87.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 88.
#
#  Build 0.0 slow charger  and 3.0 fast charger at location 89.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 90.
#
#  Build 0.0 slow charger  and 10.0 fast charger at location 91.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 92.
#
#  Build 0.0 slow charger  and 10.0 fast charger at location 93.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 94.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 95.
#
#  Build 0.0 slow charger  and 3.0 fast charger at location 96.
#
#  Build 0.0 slow charger  and 7.0 fast charger at location 97.
#
#  Build 0.0 slow charger  and 1.0 fast charger at location 98.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 99.
#
#  Build 0.0 slow charger  and 0.0 fast charger at location 100.

# %%
# Shipments from facilities to customers.

for i, j in assign.keys():
    if (abs(assign[i, j].solution_value()) > 1e-6):
        print(f"\n Demand point {i + 1} receives {round(assign[i, j].solution_value(), 2)} of its demand {round(demands[i],2)} from parking slot {j + 1} .")
# Out:
#  Demand point 1 receives 13.12 of its demand 13.12 from parking slot 39 .
#
#  Demand point 2 receives 12.02 of its demand 12.02 from parking slot 39 .
#
#  Demand point 3 receives 14.02 of its demand 14.02 from parking slot 39 .
#
#  Demand point 4 receives 15.01 of its demand 15.01 from parking slot 39 .
#
#  Demand point 5 receives 16.36 of its demand 16.36 from parking slot 39 .
#
#  Demand point 6 receives 17.56 of its demand 17.56 from parking slot 39 .
#
#  Demand point 7 receives 19.7 of its demand 19.7 from parking slot 39 .
#
#  Demand point 8 receives 19.37 of its demand 19.37 from parking slot 39 .
#
#  Demand point 9 receives 21.9 of its demand 21.9 from parking slot 39 .
#
#  Demand point 10 receives 21.77 of its demand 21.77 from parking slot 39 .
#
#  Demand point 11 receives 22.6 of its demand 22.6 from parking slot 39 .
#
#  Demand point 12 receives 23.92 of its demand 23.92 from parking slot 39 .
#
#  Demand point 13 receives 19.59 of its demand 19.59 from parking slot 25 .
#
#  Demand point 14 receives 21.44 of its demand 21.44 from parking slot 25 .
#
#  Demand point 15 receives 20.47 of its demand 20.47 from parking slot 25 .
#
#  Demand point 16 receives 22.48 of its demand 22.48 from parking slot 25 .
#
#  Demand point 17 receives 23.04 of its demand 23.04 from parking slot 58 .
#
#  Demand point 18 receives 22.27 of its demand 22.27 from parking slot 58 .
#
#  Demand point 19 receives 20.12 of its demand 20.12 from parking slot 61 .
#
#  Demand point 20 receives 18.33 of its demand 18.33 from parking slot 61 .
#
#  Demand point 21 receives 19.87 of its demand 19.87 from parking slot 61 .
#
#  Demand point 22 receives 18.87 of its demand 18.87 from parking slot 61 .
#
#  Demand point 23 receives 22.01 of its demand 22.01 from parking slot 61 .
#
#  Demand point 24 receives 21.78 of its demand 21.78 from parking slot 61 .
#
#  Demand point 25 receives 21.23 of its demand 21.23 from parking slot 61 .
#
#  Demand point 26 receives 17.7 of its demand 17.7 from parking slot 61 .
#
#  Demand point 27 receives 18.32 of its demand 18.32 from parking slot 61 .
#
#  Demand point 28 receives 18.09 of its demand 18.09 from parking slot 61 .
#
#  Demand point 29 receives 16.62 of its demand 16.62 from parking slot 61 .
#
#  Demand point 30 receives 19.02 of its demand 19.02 from parking slot 61 .
#
#  Demand point 31 receives 23.38 of its demand 23.38 from parking slot 61 .
#
#  Demand point 32 receives 28.85 of its demand 28.85 from parking slot 61 .
#
#  Demand point 33 receives 33.71 of its demand 33.71 from parking slot 61 .
#
#  Demand point 34 receives 38.99 of its demand 38.99 from parking slot 61 .
#
#  Demand point 35 receives 44.36 of its demand 44.36 from parking slot 61 .
#
#  Demand point 36 receives 46.03 of its demand 46.03 from parking slot 75 .
#
#  Demand point 37 receives 49.53 of its demand 49.53 from parking slot 93 .
#
#  Demand point 38 receives 47.98 of its demand 47.98 from parking slot 93 .
#
#  Demand point 39 receives 50.17 of its demand 50.17 from parking slot 93 .
#
#  Demand point 40 receives 51.78 of its demand 51.78 from parking slot 93 .
#
#  Demand point 41 receives 91.95 of its demand 91.95 from parking slot 93 .
#
#  Demand point 42 receives 74.88 of its demand 74.88 from parking slot 77 .
#
#  Demand point 43 receives 64.13 of its demand 64.13 from parking slot 77 .
#
#  Demand point 44 receives 46.35 of its demand 46.35 from parking slot 77 .
#
#  Demand point 45 receives 35.6 of its demand 35.6 from parking slot 77 .
#
#  Demand point 46 receives 28.46 of its demand 28.46 from parking slot 77 .
#
#  Demand point 47 receives 28.77 of its demand 28.77 from parking slot 77 .
#
#  Demand point 48 receives 40.79 of its demand 40.79 from parking slot 77 .
#
#  Demand point 49 receives 24.78 of its demand 44.32 from parking slot 11 .
#
#  Demand point 49 receives 19.54 of its demand 44.32 from parking slot 77 .
#
#  Demand point 50 receives 40.4 of its demand 40.4 from parking slot 11 .
#
#  Demand point 51 receives 55.85 of its demand 55.85 from parking slot 11 .
#
#  Demand point 52 receives 90.68 of its demand 90.68 from parking slot 11 .
#
#  Demand point 53 receives 124.06 of its demand 124.06 from parking slot 11 .
#
#  Demand point 54 receives 65.52 of its demand 65.52 from parking slot 11 .
#
#  Demand point 55 receives 82.41 of its demand 82.41 from parking slot 11 .
#
#  Demand point 56 receives 68.7 of its demand 68.7 from parking slot 11 .
#
#  Demand point 57 receives 80.41 of its demand 80.41 from parking slot 11 .
#
#  Demand point 58 receives 55.54 of its demand 55.54 from parking slot 11 .
#
#  Demand point 59 receives 43.26 of its demand 43.26 from parking slot 11 .
#
#  Demand point 60 receives 44.82 of its demand 44.82 from parking slot 11 .
#
#  Demand point 61 receives 38.21 of its demand 38.21 from parking slot 36 .
#
#  Demand point 62 receives 32.04 of its demand 32.04 from parking slot 36 .
#
#  Demand point 63 receives 34.21 of its demand 34.21 from parking slot 36 .
#
#  Demand point 64 receives 35.82 of its demand 35.82 from parking slot 36 .
#
#  Demand point 65 receives 16.2 of its demand 16.2 from parking slot 39 .
#
#  Demand point 66 receives 13.35 of its demand 13.35 from parking slot 39 .
#
#  Demand point 67 receives 13.93 of its demand 13.93 from parking slot 39 .
#
#  Demand point 68 receives 15.38 of its demand 15.38 from parking slot 39 .
#
#  Demand point 69 receives 16.17 of its demand 16.17 from parking slot 39 .
#
#  Demand point 70 receives 14.84 of its demand 14.84 from parking slot 39 .
#
#  Demand point 71 receives 22.09 of its demand 22.09 from parking slot 39 .
#
#  Demand point 72 receives 30.89 of its demand 30.89 from parking slot 39 .
#
#  Demand point 73 receives 29.84 of its demand 29.84 from parking slot 39 .
#
#  Demand point 74 receives 29.17 of its demand 29.17 from parking slot 39 .
#
#  Demand point 75 receives 33.53 of its demand 33.53 from parking slot 39 .
#
#  Demand point 76 receives 28.91 of its demand 28.91 from parking slot 39 .
#
#  Demand point 77 receives 27.42 of its demand 27.42 from parking slot 25 .
#
#  Demand point 78 receives 18.54 of its demand 18.54 from parking slot 25 .
#
#  Demand point 79 receives 17.83 of its demand 17.83 from parking slot 25 .
#
#  Demand point 80 receives 24.7 of its demand 24.7 from parking slot 25 .
#
#  Demand point 81 receives 31.16 of its demand 31.16 from parking slot 58 .
#
#  Demand point 82 receives 26.32 of its demand 26.32 from parking slot 58 .
#
#  Demand point 83 receives 24.73 of its demand 24.73 from parking slot 58 .
#
#  Demand point 84 receives 23.04 of its demand 23.04 from parking slot 61 .
#
#  Demand point 85 receives 22.6 of its demand 22.6 from parking slot 61 .
#
#  Demand point 86 receives 24.63 of its demand 24.63 from parking slot 61 .
#
#  Demand point 87 receives 26.66 of its demand 26.66 from parking slot 61 .
#
#  Demand point 88 receives 32.35 of its demand 32.35 from parking slot 61 .
#
#  Demand point 89 receives 32.65 of its demand 32.65 from parking slot 61 .
#
#  Demand point 90 receives 22.81 of its demand 22.81 from parking slot 61 .
#
#  Demand point 91 receives 21.16 of its demand 21.16 from parking slot 61 .
#
#  Demand point 92 receives 19.33 of its demand 19.33 from parking slot 61 .
#
#  Demand point 93 receives 18.95 of its demand 18.95 from parking slot 61 .
#
#  Demand point 94 receives 20.11 of its demand 20.11 from parking slot 61 .
#
#  Demand point 95 receives 20.78 of its demand 20.78 from parking slot 75 .
#
#  Demand point 96 receives 28.83 of its demand 28.83 from parking slot 75 .
#
#  Demand point 97 receives 24.89 of its demand 24.89 from parking slot 75 .
#
#  Demand point 99 receives 47.6 of its demand 47.6 from parking slot 75 .
#
#  Demand point 100 receives 59.78 of its demand 59.78 from parking slot 75 .
#
#  Demand point 101 receives 76.28 of its demand 76.28 from parking slot 93 .
#
#  Demand point 102 receives 64.2 of its demand 64.2 from parking slot 93 .
#
#  Demand point 103 receives 76.79 of its demand 76.79 from parking slot 93 .
#
#  Demand point 104 receives 67.3 of its demand 67.3 from parking slot 93 .
#
#  Demand point 105 receives 120.7 of its demand 120.7 from parking slot 93 .
#
#  Demand point 106 receives 76.34 of its demand 76.34 from parking slot 77 .
#
#  Demand point 107 receives 58.61 of its demand 58.61 from parking slot 77 .
#
#  Demand point 108 receives 8.8 of its demand 8.8 from parking slot 77 .
#
#  Demand point 110 receives 41.51 of its demand 41.51 from parking slot 77 .
#
#  Demand point 111 receives 36.77 of its demand 36.77 from parking slot 77 .
#
#  Demand point 112 receives 43.99 of its demand 43.99 from parking slot 77 .
#
#  Demand point 113 receives 42.55 of its demand 42.55 from parking slot 11 .
#
#  Demand point 114 receives 40.28 of its demand 40.28 from parking slot 11 .
#
#  Demand point 115 receives 47.95 of its demand 47.95 from parking slot 11 .
#
#  Demand point 116 receives 80.67 of its demand 80.67 from parking slot 11 .
#
#  Demand point 117 receives 86.92 of its demand 86.92 from parking slot 11 .
#
#  Demand point 118 receives 48.88 of its demand 48.88 from parking slot 11 .
#
#  Demand point 119 receives 43.12 of its demand 43.12 from parking slot 11 .
#
#  Demand point 120 receives 58.0 of its demand 58.0 from parking slot 11 .
#
#  Demand point 121 receives 54.76 of its demand 54.76 from parking slot 11 .
#
#  Demand point 122 receives 40.89 of its demand 40.89 from parking slot 11 .
#
#  Demand point 123 receives 37.3 of its demand 37.3 from parking slot 11 .
#
#  Demand point 124 receives 41.16 of its demand 41.16 from parking slot 11 .
#
#  Demand point 125 receives 7.37 of its demand 7.37 from parking slot 36 .
#
#  Demand point 126 receives 6.83 of its demand 6.83 from parking slot 36 .
#
#  Demand point 127 receives 8.24 of its demand 8.24 from parking slot 36 .
#
#  Demand point 128 receives 34.09 of its demand 34.09 from parking slot 36 .
#
#  Demand point 129 receives 15.49 of its demand 15.49 from parking slot 39 .
#
#  Demand point 130 receives 16.72 of its demand 16.72 from parking slot 39 .
#
#  Demand point 131 receives 18.26 of its demand 18.26 from parking slot 39 .
#
#  Demand point 132 receives 18.66 of its demand 18.66 from parking slot 39 .
#
#  Demand point 133 receives 16.61 of its demand 16.61 from parking slot 39 .
#
#  Demand point 134 receives 18.14 of its demand 18.14 from parking slot 39 .
#
#  Demand point 135 receives 22.41 of its demand 22.41 from parking slot 39 .
#
#  Demand point 136 receives 31.52 of its demand 31.52 from parking slot 39 .
#
#  Demand point 137 receives 33.23 of its demand 33.23 from parking slot 39 .
#
#  Demand point 138 receives 31.35 of its demand 31.35 from parking slot 39 .
#
#  Demand point 139 receives 36.88 of its demand 36.88 from parking slot 39 .
#
#  Demand point 140 receives 31.88 of its demand 31.88 from parking slot 25 .
#
#  Demand point 141 receives 27.67 of its demand 27.67 from parking slot 25 .
#
#  Demand point 142 receives 22.0 of its demand 22.0 from parking slot 25 .
#
#  Demand point 143 receives 21.02 of its demand 21.02 from parking slot 25 .
#
#  Demand point 144 receives 27.43 of its demand 27.43 from parking slot 25 .
#
#  Demand point 145 receives 31.23 of its demand 31.23 from parking slot 58 .
#
#  Demand point 146 receives 28.34 of its demand 28.34 from parking slot 58 .
#
#  Demand point 147 receives 28.24 of its demand 28.24 from parking slot 58 .
#
#  Demand point 148 receives 23.82 of its demand 23.82 from parking slot 100 .
#
#  Demand point 149 receives 24.68 of its demand 24.68 from parking slot 61 .
#
#  Demand point 150 receives 27.52 of its demand 27.52 from parking slot 61 .
#
#  Demand point 151 receives 35.33 of its demand 35.33 from parking slot 61 .
#
#  Demand point 152 receives 42.17 of its demand 42.17 from parking slot 61 .
#
#  Demand point 153 receives 35.74 of its demand 35.74 from parking slot 61 .
#
#  Demand point 154 receives 31.33 of its demand 31.33 from parking slot 61 .
#
#  Demand point 155 receives 23.73 of its demand 23.73 from parking slot 75 .
#
#  Demand point 156 receives 20.38 of its demand 20.38 from parking slot 75 .
#
#  Demand point 157 receives 20.15 of its demand 20.15 from parking slot 75 .
#
#  Demand point 158 receives 22.54 of its demand 22.54 from parking slot 75 .
#
#  Demand point 159 receives 25.9 of its demand 25.9 from parking slot 75 .
#
#  Demand point 160 receives 30.72 of its demand 30.72 from parking slot 75 .
#
#  Demand point 161 receives 28.67 of its demand 28.67 from parking slot 75 .
#
#  Demand point 162 receives 32.68 of its demand 32.68 from parking slot 75 .
#
#  Demand point 163 receives 41.26 of its demand 41.26 from parking slot 75 .
#
#  Demand point 164 receives 37.94 of its demand 37.94 from parking slot 93 .
#
#  Demand point 165 receives 61.16 of its demand 61.16 from parking slot 93 .
#
#  Demand point 166 receives 73.36 of its demand 73.36 from parking slot 93 .
#
#  Demand point 167 receives 67.53 of its demand 67.53 from parking slot 93 .
#
#  Demand point 168 receives 55.4 of its demand 55.4 from parking slot 93 .
#
#  Demand point 169 receives 83.87 of its demand 83.87 from parking slot 93 .
#
#  Demand point 170 receives 67.62 of its demand 67.62 from parking slot 77 .
#
#  Demand point 171 receives 44.2 of its demand 44.2 from parking slot 77 .
#
#  Demand point 172 receives 46.34 of its demand 46.34 from parking slot 77 .
#
#  Demand point 176 receives 49.51 of its demand 49.51 from parking slot 77 .
#
#  Demand point 177 receives 63.07 of its demand 63.07 from parking slot 11 .
#
#  Demand point 178 receives 78.82 of its demand 78.82 from parking slot 11 .
#
#  Demand point 179 receives 63.09 of its demand 63.09 from parking slot 11 .
#
#  Demand point 180 receives 52.26 of its demand 52.26 from parking slot 11 .
#
#  Demand point 181 receives 38.28 of its demand 38.28 from parking slot 11 .
#
#  Demand point 182 receives 40.4 of its demand 40.4 from parking slot 11 .
#
#  Demand point 183 receives 39.4 of its demand 39.4 from parking slot 11 .
#
#  Demand point 184 receives 38.3 of its demand 38.3 from parking slot 11 .
#
#  Demand point 185 receives 35.49 of its demand 35.49 from parking slot 11 .
#
#  Demand point 186 receives 56.38 of its demand 56.38 from parking slot 11 .
#
#  Demand point 187 receives 49.54 of its demand 49.54 from parking slot 11 .
#
#  Demand point 188 receives 40.58 of its demand 40.58 from parking slot 36 .
#
#  Demand point 189 receives 1.01 of its demand 1.01 from parking slot 36 .
#
#  Demand point 190 receives 0.95 of its demand 0.95 from parking slot 36 .
#
#  Demand point 191 receives 1.05 of its demand 1.05 from parking slot 36 .
#
#  Demand point 192 receives 1.5 of its demand 1.5 from parking slot 36 .
#
#  Demand point 193 receives 21.42 of its demand 21.42 from parking slot 89 .
#
#  Demand point 194 receives 19.59 of its demand 19.59 from parking slot 39 .
#
#  Demand point 195 receives 27.58 of its demand 27.58 from parking slot 39 .
#
#  Demand point 196 receives 28.38 of its demand 28.38 from parking slot 39 .
#
#  Demand point 197 receives 20.43 of its demand 20.43 from parking slot 39 .
#
#  Demand point 198 receives 18.55 of its demand 18.55 from parking slot 39 .
#
#  Demand point 199 receives 19.04 of its demand 19.04 from parking slot 39 .
#
#  Demand point 200 receives 19.3 of its demand 19.3 from parking slot 39 .
#
#  Demand point 201 receives 23.0 of its demand 23.0 from parking slot 39 .
#
#  Demand point 202 receives 24.9 of its demand 24.9 from parking slot 39 .
#
#  Demand point 203 receives 29.94 of its demand 29.94 from parking slot 39 .
#
#  Demand point 204 receives 26.88 of its demand 26.88 from parking slot 25 .
#
#  Demand point 205 receives 25.49 of its demand 25.49 from parking slot 25 .
#
#  Demand point 206 receives 22.59 of its demand 22.59 from parking slot 25 .
#
#  Demand point 207 receives 25.29 of its demand 25.29 from parking slot 25 .
#
#  Demand point 208 receives 27.58 of its demand 27.58 from parking slot 25 .
#
#  Demand point 209 receives 24.41 of its demand 24.41 from parking slot 58 .
#
#  Demand point 210 receives 25.31 of its demand 25.31 from parking slot 58 .
#
#  Demand point 211 receives 23.62 of its demand 23.62 from parking slot 100 .
#
#  Demand point 212 receives 21.35 of its demand 21.35 from parking slot 100 .
#
#  Demand point 213 receives 21.3 of its demand 21.3 from parking slot 100 .
#
#  Demand point 214 receives 29.39 of its demand 29.39 from parking slot 61 .
#
#  Demand point 215 receives 34.27 of its demand 34.27 from parking slot 61 .
#
#  Demand point 216 receives 39.92 of its demand 39.92 from parking slot 61 .
#
#  Demand point 217 receives 37.78 of its demand 37.78 from parking slot 75 .
#
#  Demand point 218 receives 34.68 of its demand 34.68 from parking slot 75 .
#
#  Demand point 219 receives 0.72 of its demand 0.72 from parking slot 75 .
#
#  Demand point 220 receives 25.52 of its demand 25.52 from parking slot 75 .
#
#  Demand point 221 receives 24.78 of its demand 24.78 from parking slot 75 .
#
#  Demand point 222 receives 23.2 of its demand 23.2 from parking slot 75 .
#
#  Demand point 223 receives 21.96 of its demand 21.96 from parking slot 75 .
#
#  Demand point 224 receives 32.35 of its demand 32.35 from parking slot 75 .
#
#  Demand point 225 receives 34.79 of its demand 34.79 from parking slot 75 .
#
#  Demand point 226 receives 38.28 of its demand 38.28 from parking slot 75 .
#
#  Demand point 227 receives 44.69 of its demand 44.69 from parking slot 75 .
#
#  Demand point 228 receives 31.91 of its demand 31.91 from parking slot 93 .
#
#  Demand point 229 receives 48.85 of its demand 48.85 from parking slot 93 .
#
#  Demand point 230 receives 59.92 of its demand 59.92 from parking slot 93 .
#
#  Demand point 231 receives 57.62 of its demand 57.62 from parking slot 93 .
#
#  Demand point 232 receives 65.51 of its demand 65.51 from parking slot 93 .
#
#  Demand point 233 receives 94.24 of its demand 94.24 from parking slot 93 .
#
#  Demand point 234 receives 109.73 of its demand 109.73 from parking slot 77 .
#
#  Demand point 235 receives 87.33 of its demand 87.33 from parking slot 77 .
#
#  Demand point 236 receives 103.63 of its demand 103.63 from parking slot 77 .
#
#  Demand point 237 receives 72.21 of its demand 72.21 from parking slot 77 .
#
#  Demand point 238 receives 21.17 of its demand 21.17 from parking slot 77 .
#
#  Demand point 240 receives 22.7 of its demand 22.7 from parking slot 77 .
#
#  Demand point 241 receives 70.98 of its demand 70.98 from parking slot 11 .
#
#  Demand point 242 receives 133.44 of its demand 133.44 from parking slot 11 .
#
#  Demand point 243 receives 143.68 of its demand 143.68 from parking slot 11 .
#
#  Demand point 244 receives 50.84 of its demand 50.84 from parking slot 11 .
#
#  Demand point 245 receives 39.52 of its demand 39.52 from parking slot 11 .
#
#  Demand point 246 receives 2.14 of its demand 2.14 from parking slot 11 .
#
#  Demand point 247 receives 40.45 of its demand 40.45 from parking slot 11 .
#
#  Demand point 248 receives 50.34 of its demand 50.34 from parking slot 11 .
#
#  Demand point 249 receives 44.69 of its demand 44.69 from parking slot 11 .
#
#  Demand point 250 receives 52.21 of its demand 52.21 from parking slot 11 .
#
#  Demand point 251 receives 54.61 of its demand 54.61 from parking slot 36 .
#
#  Demand point 252 receives 1.28 of its demand 1.28 from parking slot 36 .
#
#  Demand point 253 receives 1.02 of its demand 1.02 from parking slot 36 .
#
#  Demand point 254 receives 1.47 of its demand 1.47 from parking slot 36 .
#
#  Demand point 255 receives 1.8 of its demand 1.8 from parking slot 36 .
#
#  Demand point 256 receives 1.53 of its demand 1.53 from parking slot 36 .
#
#  Demand point 257 receives 25.58 of its demand 25.58 from parking slot 89 .
#
#  Demand point 258 receives 27.13 of its demand 27.13 from parking slot 89 .
#
#  Demand point 259 receives 30.15 of its demand 30.15 from parking slot 39 .
#
#  Demand point 260 receives 31.07 of its demand 31.07 from parking slot 39 .
#
#  Demand point 261 receives 23.44 of its demand 23.44 from parking slot 39 .
#
#  Demand point 262 receives 19.42 of its demand 19.42 from parking slot 39 .
#
#  Demand point 263 receives 16.7 of its demand 16.7 from parking slot 39 .
#
#  Demand point 264 receives 17.63 of its demand 17.63 from parking slot 39 .
#
#  Demand point 265 receives 20.0 of its demand 20.0 from parking slot 39 .
#
#  Demand point 266 receives 30.57 of its demand 30.57 from parking slot 39 .
#
#  Demand point 267 receives 36.06 of its demand 36.06 from parking slot 39 .
#
#  Demand point 268 receives 27.91 of its demand 27.91 from parking slot 25 .
#
#  Demand point 269 receives 25.07 of its demand 25.07 from parking slot 25 .
#
#  Demand point 270 receives 22.81 of its demand 22.81 from parking slot 25 .
#
#  Demand point 271 receives 23.32 of its demand 23.32 from parking slot 25 .
#
#  Demand point 272 receives 19.15 of its demand 19.15 from parking slot 25 .
#
#  Demand point 273 receives 17.76 of its demand 17.76 from parking slot 58 .
#
#  Demand point 274 receives 19.93 of its demand 19.93 from parking slot 58 .
#
#  Demand point 275 receives 21.28 of its demand 21.28 from parking slot 100 .
#
#  Demand point 276 receives 20.05 of its demand 20.05 from parking slot 100 .
#
#  Demand point 277 receives 20.81 of its demand 20.81 from parking slot 100 .
#
#  Demand point 278 receives 24.44 of its demand 24.44 from parking slot 100 .
#
#  Demand point 279 receives 33.0 of its demand 33.0 from parking slot 100 .
#
#  Demand point 280 receives 37.79 of its demand 37.79 from parking slot 61 .
#
#  Demand point 281 receives 35.31 of its demand 35.31 from parking slot 75 .
#
#  Demand point 282 receives 36.84 of its demand 36.84 from parking slot 75 .
#
#  Demand point 283 receives 34.87 of its demand 34.87 from parking slot 75 .
#
#  Demand point 284 receives 32.15 of its demand 32.15 from parking slot 75 .
#
#  Demand point 285 receives 32.17 of its demand 32.17 from parking slot 75 .
#
#  Demand point 286 receives 30.95 of its demand 30.95 from parking slot 75 .
#
#  Demand point 287 receives 31.5 of its demand 31.5 from parking slot 75 .
#
#  Demand point 288 receives 36.44 of its demand 36.44 from parking slot 75 .
#
#  Demand point 289 receives 38.07 of its demand 38.07 from parking slot 75 .
#
#  Demand point 290 receives 44.35 of its demand 44.35 from parking slot 75 .
#
#  Demand point 291 receives 47.46 of its demand 47.46 from parking slot 75 .
#
#  Demand point 292 receives 46.4 of its demand 46.4 from parking slot 93 .
#
#  Demand point 293 receives 98.44 of its demand 98.44 from parking slot 93 .
#
#  Demand point 294 receives 60.37 of its demand 60.37 from parking slot 93 .
#
#  Demand point 295 receives 103.72 of its demand 103.72 from parking slot 93 .
#
#  Demand point 296 receives 127.13 of its demand 127.13 from parking slot 93 .
#
#  Demand point 297 receives 152.38 of its demand 152.38 from parking slot 93 .
#
#  Demand point 298 receives 182.33 of its demand 182.33 from parking slot 77 .
#
#  Demand point 299 receives 147.17 of its demand 147.17 from parking slot 77 .
#
#  Demand point 300 receives 185.44 of its demand 185.44 from parking slot 77 .
#
#  Demand point 301 receives 174.9 of its demand 174.9 from parking slot 77 .
#
#  Demand point 302 receives 122.71 of its demand 122.71 from parking slot 77 .
#
#  Demand point 303 receives 65.67 of its demand 65.67 from parking slot 77 .
#
#  Demand point 304 receives 71.27 of its demand 71.27 from parking slot 77 .
#
#  Demand point 305 receives 97.46 of its demand 97.46 from parking slot 11 .
#
#  Demand point 306 receives 163.59 of its demand 163.59 from parking slot 11 .
#
#  Demand point 307 receives 105.84 of its demand 105.84 from parking slot 11 .
#
#  Demand point 308 receives 54.55 of its demand 54.55 from parking slot 11 .
#
#  Demand point 309 receives 41.61 of its demand 41.61 from parking slot 11 .
#
#  Demand point 310 receives 3.88 of its demand 3.88 from parking slot 11 .
#
#  Demand point 311 receives 40.48 of its demand 40.48 from parking slot 11 .
#
#  Demand point 312 receives 43.74 of its demand 43.74 from parking slot 11 .
#
#  Demand point 313 receives 75.78 of its demand 75.78 from parking slot 11 .
#
#  Demand point 314 receives 59.62 of its demand 59.62 from parking slot 36 .
#
#  Demand point 315 receives 41.56 of its demand 41.56 from parking slot 36 .
#
#  Demand point 316 receives 1.04 of its demand 1.04 from parking slot 36 .
#
#  Demand point 317 receives 1.04 of its demand 1.04 from parking slot 36 .
#
#  Demand point 318 receives 1.24 of its demand 1.24 from parking slot 36 .
#
#  Demand point 319 receives 2.71 of its demand 2.71 from parking slot 36 .
#
#  Demand point 320 receives 2.98 of its demand 2.98 from parking slot 36 .
#
#  Demand point 321 receives 24.02 of its demand 24.02 from parking slot 89 .
#
#  Demand point 322 receives 26.06 of its demand 26.06 from parking slot 89 .
#
#  Demand point 323 receives 22.98 of its demand 22.98 from parking slot 89 .
#
#  Demand point 324 receives 22.15 of its demand 22.15 from parking slot 39 .
#
#  Demand point 325 receives 18.18 of its demand 18.18 from parking slot 39 .
#
#  Demand point 326 receives 17.95 of its demand 17.95 from parking slot 39 .
#
#  Demand point 327 receives 19.45 of its demand 19.45 from parking slot 39 .
#
#  Demand point 328 receives 20.76 of its demand 20.76 from parking slot 39 .
#
#  Demand point 329 receives 26.56 of its demand 26.56 from parking slot 39 .
#
#  Demand point 330 receives 32.83 of its demand 32.83 from parking slot 39 .
#
#  Demand point 331 receives 39.34 of its demand 39.34 from parking slot 39 .
#
#  Demand point 332 receives 38.92 of its demand 38.92 from parking slot 25 .
#
#  Demand point 333 receives 28.65 of its demand 28.65 from parking slot 25 .
#
#  Demand point 334 receives 24.93 of its demand 24.93 from parking slot 25 .
#
#  Demand point 335 receives 23.59 of its demand 23.59 from parking slot 25 .
#
#  Demand point 336 receives 19.32 of its demand 19.32 from parking slot 58 .
#
#  Demand point 337 receives 18.44 of its demand 18.44 from parking slot 58 .
#
#  Demand point 338 receives 18.9 of its demand 18.9 from parking slot 100 .
#
#  Demand point 339 receives 20.28 of its demand 20.28 from parking slot 100 .
#
#  Demand point 340 receives 20.71 of its demand 20.71 from parking slot 100 .
#
#  Demand point 341 receives 21.6 of its demand 21.6 from parking slot 100 .
#
#  Demand point 342 receives 22.84 of its demand 22.84 from parking slot 100 .
#
#  Demand point 343 receives 25.67 of its demand 25.67 from parking slot 100 .
#
#  Demand point 344 receives 30.77 of its demand 30.77 from parking slot 100 .
#
#  Demand point 345 receives 32.08 of its demand 32.08 from parking slot 75 .
#
#  Demand point 346 receives 29.76 of its demand 29.76 from parking slot 75 .
#
#  Demand point 347 receives 28.93 of its demand 28.93 from parking slot 75 .
#
#  Demand point 348 receives 27.43 of its demand 27.43 from parking slot 75 .
#
#  Demand point 349 receives 29.58 of its demand 29.58 from parking slot 75 .
#
#  Demand point 350 receives 35.37 of its demand 35.37 from parking slot 75 .
#
#  Demand point 351 receives 39.8 of its demand 39.8 from parking slot 75 .
#
#  Demand point 352 receives 46.94 of its demand 46.94 from parking slot 75 .
#
#  Demand point 353 receives 45.21 of its demand 45.21 from parking slot 75 .
#
#  Demand point 354 receives 49.36 of its demand 49.36 from parking slot 75 .
#
#  Demand point 355 receives 47.27 of its demand 47.27 from parking slot 75 .
#
#  Demand point 356 receives 56.57 of its demand 56.57 from parking slot 93 .
#
#  Demand point 357 receives 83.98 of its demand 83.98 from parking slot 93 .
#
#  Demand point 358 receives 88.23 of its demand 88.23 from parking slot 93 .
#
#  Demand point 359 receives 147.08 of its demand 147.08 from parking slot 93 .
#
#  Demand point 360 receives 209.13 of its demand 209.13 from parking slot 93 .
#
#  Demand point 361 receives 200.97 of its demand 200.97 from parking slot 93 .
#
#  Demand point 362 receives 194.28 of its demand 194.28 from parking slot 93 .
#
#  Demand point 363 receives 208.32 of its demand 208.32 from parking slot 77 .
#
#  Demand point 364 receives 164.98 of its demand 164.98 from parking slot 77 .
#
#  Demand point 365 receives 119.01 of its demand 119.01 from parking slot 77 .
#
#  Demand point 366 receives 140.51 of its demand 140.51 from parking slot 77 .
#
#  Demand point 367 receives 99.13 of its demand 99.13 from parking slot 77 .
#
#  Demand point 368 receives 4.18 of its demand 103.65 from parking slot 1 .
#
#  Demand point 368 receives 99.47 of its demand 103.65 from parking slot 11 .
#
#  Demand point 369 receives 76.4 of its demand 76.4 from parking slot 11 .
#
#  Demand point 370 receives 99.08 of its demand 99.08 from parking slot 11 .
#
#  Demand point 371 receives 87.11 of its demand 87.11 from parking slot 11 .
#
#  Demand point 372 receives 61.87 of its demand 61.87 from parking slot 11 .
#
#  Demand point 373 receives 74.7 of its demand 74.7 from parking slot 11 .
#
#  Demand point 374 receives 69.02 of its demand 69.02 from parking slot 11 .
#
#  Demand point 375 receives 56.96 of its demand 56.96 from parking slot 11 .
#
#  Demand point 376 receives 66.13 of its demand 66.13 from parking slot 11 .
#
#  Demand point 377 receives 86.4 of its demand 86.4 from parking slot 36 .
#
#  Demand point 378 receives 74.68 of its demand 74.68 from parking slot 36 .
#
#  Demand point 379 receives 47.1 of its demand 47.1 from parking slot 36 .
#
#  Demand point 380 receives 3.21 of its demand 3.21 from parking slot 36 .
#
#  Demand point 381 receives 3.33 of its demand 3.33 from parking slot 36 .
#
#  Demand point 382 receives 1.35 of its demand 1.35 from parking slot 36 .
#
#  Demand point 383 receives 3.16 of its demand 3.16 from parking slot 36 .
#
#  Demand point 384 receives 2.04 of its demand 2.04 from parking slot 36 .
#
#  Demand point 385 receives 34.82 of its demand 34.82 from parking slot 89 .
#
#  Demand point 386 receives 33.37 of its demand 33.37 from parking slot 89 .
#
#  Demand point 387 receives 23.5 of its demand 23.5 from parking slot 89 .
#
#  Demand point 388 receives 9.24 of its demand 9.24 from parking slot 89 .
#
#  Demand point 389 receives 18.32 of its demand 18.32 from parking slot 39 .
#
#  Demand point 390 receives 18.35 of its demand 18.35 from parking slot 39 .
#
#  Demand point 391 receives 21.91 of its demand 21.91 from parking slot 39 .
#
#  Demand point 392 receives 24.37 of its demand 24.37 from parking slot 39 .
#
#  Demand point 393 receives 29.78 of its demand 29.78 from parking slot 39 .
#
#  Demand point 394 receives 34.14 of its demand 34.14 from parking slot 39 .
#
#  Demand point 395 receives 43.46 of its demand 43.46 from parking slot 25 .
#
#  Demand point 396 receives 36.88 of its demand 36.88 from parking slot 25 .
#
#  Demand point 397 receives 30.05 of its demand 30.05 from parking slot 25 .
#
#  Demand point 398 receives 27.41 of its demand 27.41 from parking slot 25 .
#
#  Demand point 399 receives 23.79 of its demand 23.79 from parking slot 25 .
#
#  Demand point 400 receives 23.34 of its demand 23.34 from parking slot 58 .
#
#  Demand point 401 receives 20.96 of its demand 20.96 from parking slot 58 .
#
#  Demand point 402 receives 19.2 of its demand 19.2 from parking slot 100 .
#
#  Demand point 403 receives 20.1 of its demand 20.1 from parking slot 100 .
#
#  Demand point 404 receives 20.55 of its demand 20.55 from parking slot 100 .
#
#  Demand point 405 receives 20.78 of its demand 20.78 from parking slot 100 .
#
#  Demand point 406 receives 24.07 of its demand 24.07 from parking slot 100 .
#
#  Demand point 407 receives 34.62 of its demand 34.62 from parking slot 100 .
#
#  Demand point 408 receives 37.0 of its demand 37.0 from parking slot 100 .
#
#  Demand point 409 receives 37.64 of its demand 37.64 from parking slot 100 .
#
#  Demand point 410 receives 36.43 of its demand 36.43 from parking slot 75 .
#
#  Demand point 411 receives 35.61 of its demand 35.61 from parking slot 75 .
#
#  Demand point 412 receives 36.83 of its demand 36.83 from parking slot 75 .
#
#  Demand point 413 receives 42.77 of its demand 42.77 from parking slot 75 .
#
#  Demand point 414 receives 43.49 of its demand 43.49 from parking slot 75 .
#
#  Demand point 415 receives 39.16 of its demand 39.16 from parking slot 75 .
#
#  Demand point 416 receives 45.47 of its demand 45.47 from parking slot 75 .
#
#  Demand point 417 receives 41.73 of its demand 41.73 from parking slot 75 .
#
#  Demand point 419 receives 44.84 of its demand 44.84 from parking slot 75 .
#
#  Demand point 420 receives 53.79 of its demand 53.79 from parking slot 93 .
#
#  Demand point 421 receives 82.09 of its demand 82.09 from parking slot 93 .
#
#  Demand point 422 receives 221.64 of its demand 221.64 from parking slot 93 .
#
#  Demand point 423 receives 223.43 of its demand 223.43 from parking slot 93 .
#
#  Demand point 424 receives 222.22 of its demand 222.22 from parking slot 93 .
#
#  Demand point 425 receives 176.0 of its demand 176.0 from parking slot 93 .
#
#  Demand point 426 receives 191.18 of its demand 191.18 from parking slot 93 .
#
#  Demand point 427 receives 181.08 of its demand 181.08 from parking slot 93 .
#
#  Demand point 428 receives 173.96 of its demand 173.96 from parking slot 93 .
#
#  Demand point 429 receives 162.1 of its demand 162.1 from parking slot 77 .
#
#  Demand point 430 receives 127.51 of its demand 127.51 from parking slot 77 .
#
#  Demand point 431 receives 184.19 of its demand 184.19 from parking slot 1 .
#
#  Demand point 432 receives 115.47 of its demand 115.47 from parking slot 1 .
#
#  Demand point 433 receives 48.05 of its demand 48.05 from parking slot 1 .
#
#  Demand point 434 receives 50.87 of its demand 50.87 from parking slot 11 .
#
#  Demand point 435 receives 49.22 of its demand 49.22 from parking slot 11 .
#
#  Demand point 436 receives 73.17 of its demand 73.17 from parking slot 11 .
#
#  Demand point 437 receives 47.42 of its demand 47.42 from parking slot 11 .
#
#  Demand point 438 receives 45.37 of its demand 45.37 from parking slot 11 .
#
#  Demand point 439 receives 43.15 of its demand 43.15 from parking slot 11 .
#
#  Demand point 440 receives 49.77 of its demand 49.77 from parking slot 36 .
#
#  Demand point 441 receives 79.14 of its demand 79.14 from parking slot 36 .
#
#  Demand point 442 receives 85.69 of its demand 85.69 from parking slot 36 .
#
#  Demand point 443 receives 78.31 of its demand 78.31 from parking slot 36 .
#
#  Demand point 444 receives 58.37 of its demand 58.37 from parking slot 36 .
#
#  Demand point 445 receives 43.12 of its demand 43.12 from parking slot 36 .
#
#  Demand point 446 receives 47.71 of its demand 47.71 from parking slot 36 .
#
#  Demand point 447 receives 37.64 of its demand 37.64 from parking slot 36 .
#
#  Demand point 448 receives 0.19 of its demand 0.19 from parking slot 36 .
#
#  Demand point 449 receives 36.08 of its demand 36.08 from parking slot 89 .
#
#  Demand point 450 receives 33.55 of its demand 33.55 from parking slot 89 .
#
#  Demand point 451 receives 24.32 of its demand 24.32 from parking slot 89 .
#
#  Demand point 452 receives 9.3 of its demand 9.3 from parking slot 89 .
#
#  Demand point 453 receives 19.1 of its demand 19.1 from parking slot 89 .
#
#  Demand point 454 receives 18.78 of its demand 18.78 from parking slot 39 .
#
#  Demand point 455 receives 23.4 of its demand 23.4 from parking slot 39 .
#
#  Demand point 456 receives 27.53 of its demand 27.53 from parking slot 39 .
#
#  Demand point 457 receives 23.05 of its demand 23.05 from parking slot 39 .
#
#  Demand point 458 receives 27.32 of its demand 27.32 from parking slot 39 .
#
#  Demand point 459 receives 32.17 of its demand 32.17 from parking slot 25 .
#
#  Demand point 460 receives 35.19 of its demand 35.19 from parking slot 25 .
#
#  Demand point 461 receives 37.3 of its demand 37.3 from parking slot 25 .
#
#  Demand point 462 receives 31.68 of its demand 31.68 from parking slot 25 .
#
#  Demand point 463 receives 10.99 of its demand 10.99 from parking slot 25 .
#
#  Demand point 464 receives 29.96 of its demand 29.96 from parking slot 58 .
#
#  Demand point 465 receives 28.32 of its demand 28.32 from parking slot 58 .
#
#  Demand point 466 receives 24.42 of its demand 24.42 from parking slot 100 .
#
#  Demand point 467 receives 25.23 of its demand 25.23 from parking slot 100 .
#
#  Demand point 468 receives 25.46 of its demand 25.46 from parking slot 100 .
#
#  Demand point 469 receives 23.21 of its demand 23.21 from parking slot 100 .
#
#  Demand point 470 receives 21.66 of its demand 21.66 from parking slot 100 .
#
#  Demand point 471 receives 29.29 of its demand 29.29 from parking slot 100 .
#
#  Demand point 472 receives 40.23 of its demand 40.23 from parking slot 100 .
#
#  Demand point 473 receives 32.84 of its demand 32.84 from parking slot 100 .
#
#  Demand point 474 receives 36.07 of its demand 36.07 from parking slot 100 .
#
#  Demand point 475 receives 48.07 of its demand 48.07 from parking slot 75 .
#
#  Demand point 476 receives 40.91 of its demand 40.91 from parking slot 75 .
#
#  Demand point 477 receives 38.85 of its demand 38.85 from parking slot 75 .
#
#  Demand point 478 receives 41.53 of its demand 41.53 from parking slot 75 .
#
#  Demand point 479 receives 43.38 of its demand 43.38 from parking slot 75 .
#
#  Demand point 480 receives 42.63 of its demand 42.63 from parking slot 75 .
#
#  Demand point 481 receives 43.7 of its demand 43.7 from parking slot 75 .
#
#  Demand point 482 receives 45.12 of its demand 45.12 from parking slot 75 .
#
#  Demand point 483 receives 40.27 of its demand 40.27 from parking slot 75 .
#
#  Demand point 484 receives 68.43 of its demand 68.43 from parking slot 93 .
#
#  Demand point 485 receives 71.99 of its demand 71.99 from parking slot 93 .
#
#  Demand point 486 receives 81.35 of its demand 81.35 from parking slot 93 .
#
#  Demand point 487 receives 88.74 of its demand 88.74 from parking slot 93 .
#
#  Demand point 488 receives 184.93 of its demand 184.93 from parking slot 93 .
#
#  Demand point 489 receives 188.46 of its demand 188.46 from parking slot 93 .
#
#  Demand point 490 receives 252.82 of its demand 252.82 from parking slot 93 .
#
#  Demand point 491 receives 229.43 of its demand 229.43 from parking slot 93 .
#
#  Demand point 492 receives 185.8 of its demand 185.8 from parking slot 93 .
#
#  Demand point 493 receives 167.11 of its demand 167.11 from parking slot 70 .
#
#  Demand point 494 receives 191.3 of its demand 191.3 from parking slot 70 .
#
#  Demand point 495 receives 190.2 of its demand 190.2 from parking slot 1 .
#
#  Demand point 496 receives 107.99 of its demand 107.99 from parking slot 1 .
#
#  Demand point 497 receives 50.16 of its demand 50.16 from parking slot 1 .
#
#  Demand point 498 receives 47.68 of its demand 47.68 from parking slot 1 .
#
#  Demand point 499 receives 45.69 of its demand 45.69 from parking slot 11 .
#
#  Demand point 500 receives 48.38 of its demand 48.38 from parking slot 11 .
#
#  Demand point 501 receives 44.27 of its demand 44.27 from parking slot 11 .
#
#  Demand point 502 receives 52.57 of its demand 52.57 from parking slot 11 .
#
#  Demand point 503 receives 53.22 of its demand 53.22 from parking slot 36 .
#
#  Demand point 504 receives 99.97 of its demand 99.97 from parking slot 36 .
#
#  Demand point 505 receives 94.81 of its demand 94.81 from parking slot 36 .
#
#  Demand point 506 receives 52.61 of its demand 52.61 from parking slot 36 .
#
#  Demand point 507 receives 48.64 of its demand 48.64 from parking slot 36 .
#
#  Demand point 508 receives 39.82 of its demand 39.82 from parking slot 36 .
#
#  Demand point 509 receives 47.72 of its demand 47.72 from parking slot 36 .
#
#  Demand point 510 receives 46.64 of its demand 46.64 from parking slot 36 .
#
#  Demand point 511 receives 0.99 of its demand 0.99 from parking slot 36 .
#
#  Demand point 513 receives 32.06 of its demand 32.06 from parking slot 89 .
#
#  Demand point 514 receives 25.98 of its demand 25.98 from parking slot 89 .
#
#  Demand point 515 receives 21.68 of its demand 21.68 from parking slot 89 .
#
#  Demand point 516 receives 9.01 of its demand 9.01 from parking slot 89 .
#
#  Demand point 517 receives 19.5 of its demand 19.5 from parking slot 89 .
#
#  Demand point 518 receives 21.73 of its demand 21.73 from parking slot 89 .
#
#  Demand point 519 receives 25.23 of its demand 25.23 from parking slot 39 .
#
#  Demand point 520 receives 24.82 of its demand 24.82 from parking slot 39 .
#
#  Demand point 521 receives 30.71 of its demand 30.71 from parking slot 39 .
#
#  Demand point 522 receives 30.82 of its demand 30.82 from parking slot 39 .
#
#  Demand point 523 receives 31.96 of its demand 31.96 from parking slot 25 .
#
#  Demand point 524 receives 36.49 of its demand 36.49 from parking slot 25 .
#
#  Demand point 525 receives 41.65 of its demand 41.65 from parking slot 25 .
#
#  Demand point 526 receives 35.5 of its demand 35.5 from parking slot 25 .
#
#  Demand point 527 receives 39.13 of its demand 39.13 from parking slot 25 .
#
#  Demand point 528 receives 30.06 of its demand 30.06 from parking slot 58 .
#
#  Demand point 529 receives 34.41 of its demand 34.41 from parking slot 100 .
#
#  Demand point 530 receives 27.94 of its demand 27.94 from parking slot 100 .
#
#  Demand point 531 receives 33.43 of its demand 33.43 from parking slot 100 .
#
#  Demand point 532 receives 33.25 of its demand 33.25 from parking slot 100 .
#
#  Demand point 533 receives 24.94 of its demand 24.94 from parking slot 100 .
#
#  Demand point 534 receives 23.73 of its demand 23.73 from parking slot 100 .
#
#  Demand point 535 receives 31.82 of its demand 31.82 from parking slot 100 .
#
#  Demand point 536 receives 34.8 of its demand 34.8 from parking slot 100 .
#
#  Demand point 537 receives 39.61 of its demand 39.61 from parking slot 100 .
#
#  Demand point 538 receives 38.33 of its demand 38.33 from parking slot 100 .
#
#  Demand point 539 receives 46.43 of its demand 46.43 from parking slot 100 .
#
#  Demand point 540 receives 59.81 of its demand 59.81 from parking slot 75 .
#
#  Demand point 541 receives 47.48 of its demand 47.48 from parking slot 75 .
#
#  Demand point 542 receives 43.39 of its demand 43.39 from parking slot 75 .
#
#  Demand point 543 receives 59.37 of its demand 59.37 from parking slot 75 .
#
#  Demand point 544 receives 47.3 of its demand 47.3 from parking slot 75 .
#
#  Demand point 545 receives 50.74 of its demand 50.74 from parking slot 75 .
#
#  Demand point 546 receives 85.63 of its demand 85.63 from parking slot 75 .
#
#  Demand point 547 receives 51.38 of its demand 66.92 from parking slot 70 .
#
#  Demand point 547 receives 15.55 of its demand 66.92 from parking slot 75 .
#
#  Demand point 548 receives 58.39 of its demand 58.39 from parking slot 93 .
#
#  Demand point 549 receives 48.23 of its demand 48.23 from parking slot 93 .
#
#  Demand point 550 receives 50.19 of its demand 50.19 from parking slot 93 .
#
#  Demand point 551 receives 69.32 of its demand 69.32 from parking slot 93 .
#
#  Demand point 552 receives 80.79 of its demand 80.79 from parking slot 93 .
#
#  Demand point 553 receives 123.2 of its demand 123.2 from parking slot 93 .
#
#  Demand point 554 receives 102.28 of its demand 192.15 from parking slot 70 .
#
#  Demand point 554 receives 89.87 of its demand 192.15 from parking slot 93 .
#
#  Demand point 555 receives 199.12 of its demand 199.12 from parking slot 70 .
#
#  Demand point 556 receives 174.03 of its demand 174.03 from parking slot 70 .
#
#  Demand point 557 receives 133.56 of its demand 133.56 from parking slot 70 .
#
#  Demand point 558 receives 120.11 of its demand 120.11 from parking slot 70 .
#
#  Demand point 559 receives 112.73 of its demand 112.73 from parking slot 1 .
#
#  Demand point 560 receives 71.1 of its demand 71.1 from parking slot 1 .
#
#  Demand point 561 receives 71.67 of its demand 71.67 from parking slot 1 .
#
#  Demand point 562 receives 55.4 of its demand 55.4 from parking slot 1 .
#
#  Demand point 563 receives 40.56 of its demand 40.56 from parking slot 1 .
#
#  Demand point 564 receives 40.27 of its demand 40.27 from parking slot 1 .
#
#  Demand point 565 receives 47.36 of its demand 47.36 from parking slot 36 .
#
#  Demand point 566 receives 41.19 of its demand 41.19 from parking slot 36 .
#
#  Demand point 567 receives 38.18 of its demand 38.18 from parking slot 36 .
#
#  Demand point 568 receives 49.46 of its demand 49.46 from parking slot 36 .
#
#  Demand point 569 receives 65.36 of its demand 65.36 from parking slot 36 .
#
#  Demand point 570 receives 42.05 of its demand 42.05 from parking slot 36 .
#
#  Demand point 571 receives 45.06 of its demand 45.06 from parking slot 36 .
#
#  Demand point 572 receives 44.93 of its demand 44.93 from parking slot 36 .
#
#  Demand point 573 receives 36.83 of its demand 36.83 from parking slot 36 .
#
#  Demand point 574 receives 27.21 of its demand 27.21 from parking slot 36 .
#
#  Demand point 575 receives 1.17 of its demand 1.17 from parking slot 36 .
#
#  Demand point 576 receives 1.23 of its demand 1.23 from parking slot 36 .
#
#  Demand point 577 receives 30.77 of its demand 30.77 from parking slot 89 .
#
#  Demand point 578 receives 26.66 of its demand 26.66 from parking slot 89 .
#
#  Demand point 579 receives 20.12 of its demand 20.12 from parking slot 89 .
#
#  Demand point 580 receives 23.67 of its demand 23.67 from parking slot 89 .
#
#  Demand point 581 receives 24.23 of its demand 24.23 from parking slot 89 .
#
#  Demand point 582 receives 26.65 of its demand 26.65 from parking slot 89 .
#
#  Demand point 583 receives 21.95 of its demand 21.95 from parking slot 39 .
#
#  Demand point 584 receives 25.71 of its demand 25.71 from parking slot 39 .
#
#  Demand point 585 receives 28.12 of its demand 28.12 from parking slot 39 .
#
#  Demand point 586 receives 28.56 of its demand 28.56 from parking slot 39 .
#
#  Demand point 587 receives 30.97 of its demand 30.97 from parking slot 25 .
#
#  Demand point 588 receives 37.1 of its demand 37.1 from parking slot 25 .
#
#  Demand point 589 receives 43.62 of its demand 43.62 from parking slot 25 .
#
#  Demand point 590 receives 39.99 of its demand 39.99 from parking slot 25 .
#
#  Demand point 591 receives 37.76 of its demand 37.76 from parking slot 25 .
#
#  Demand point 592 receives 35.39 of its demand 35.39 from parking slot 58 .
#
#  Demand point 593 receives 33.8 of its demand 33.8 from parking slot 100 .
#
#  Demand point 594 receives 35.29 of its demand 35.29 from parking slot 100 .
#
#  Demand point 595 receives 37.18 of its demand 37.18 from parking slot 100 .
#
#  Demand point 597 receives 39.58 of its demand 39.58 from parking slot 100 .
#
#  Demand point 598 receives 36.29 of its demand 36.29 from parking slot 100 .
#
#  Demand point 599 receives 37.53 of its demand 37.53 from parking slot 100 .
#
#  Demand point 600 receives 39.53 of its demand 39.53 from parking slot 100 .
#
#  Demand point 601 receives 35.56 of its demand 35.56 from parking slot 100 .
#
#  Demand point 602 receives 44.53 of its demand 44.53 from parking slot 100 .
#
#  Demand point 603 receives 44.56 of its demand 44.56 from parking slot 100 .
#
#  Demand point 604 receives 2.98 of its demand 62.26 from parking slot 75 .
#
#  Demand point 604 receives 59.29 of its demand 62.26 from parking slot 100 .
#
#  Demand point 605 receives 45.18 of its demand 45.18 from parking slot 75 .
#
#  Demand point 606 receives 60.84 of its demand 60.84 from parking slot 75 .
#
#  Demand point 607 receives 76.02 of its demand 76.02 from parking slot 75 .
#
#  Demand point 608 receives 53.3 of its demand 53.3 from parking slot 75 .
#
#  Demand point 609 receives 51.53 of its demand 51.53 from parking slot 75 .
#
#  Demand point 610 receives 150.7 of its demand 150.7 from parking slot 75 .
#
#  Demand point 611 receives 94.98 of its demand 94.98 from parking slot 70 .
#
#  Demand point 612 receives 61.69 of its demand 61.69 from parking slot 70 .
#
#  Demand point 613 receives 46.66 of its demand 46.66 from parking slot 70 .
#
#  Demand point 614 receives 45.44 of its demand 45.44 from parking slot 70 .
#
#  Demand point 615 receives 43.01 of its demand 43.01 from parking slot 70 .
#
#  Demand point 616 receives 49.35 of its demand 49.35 from parking slot 70 .
#
#  Demand point 617 receives 68.11 of its demand 68.11 from parking slot 70 .
#
#  Demand point 618 receives 92.93 of its demand 92.93 from parking slot 70 .
#
#  Demand point 619 receives 93.72 of its demand 93.72 from parking slot 70 .
#
#  Demand point 620 receives 64.61 of its demand 64.61 from parking slot 70 .
#
#  Demand point 621 receives 68.3 of its demand 68.3 from parking slot 70 .
#
#  Demand point 622 receives 62.58 of its demand 75.38 from parking slot 1 .
#
#  Demand point 622 receives 12.8 of its demand 75.38 from parking slot 70 .
#
#  Demand point 623 receives 71.75 of its demand 71.75 from parking slot 1 .
#
#  Demand point 624 receives 56.75 of its demand 56.75 from parking slot 1 .
#
#  Demand point 625 receives 75.3 of its demand 75.3 from parking slot 1 .
#
#  Demand point 626 receives 55.92 of its demand 55.92 from parking slot 1 .
#
#  Demand point 627 receives 34.35 of its demand 34.35 from parking slot 1 .
#
#  Demand point 628 receives 40.62 of its demand 40.62 from parking slot 1 .
#
# ...
#
#  Demand point 3886 receives 9.51 of its demand 9.51 from parking slot 3 .
#
#  Demand point 3887 receives 7.21 of its demand 7.21 from parking slot 3 .
#
#  Demand point 3888 receives 8.87 of its demand 8.87 from parking slot 3 .
#
#  Demand point 3889 receives 9.06 of its demand 9.06 from parking slot 3 .
#
#  Demand point 3890 receives 9.43 of its demand 9.43 from parking slot 3 .
#
#  Demand point 3891 receives 10.82 of its demand 10.82 from parking slot 3 .
#
#  Demand point 3892 receives 6.27 of its demand 6.27 from parking slot 3 .
#
#  Demand point 3893 receives 7.11 of its demand 7.11 from parking slot 3 .
#
#  Demand point 3894 receives 6.28 of its demand 6.28 from parking slot 3 .
#
#  Demand point 3895 receives 5.94 of its demand 5.94 from parking slot 17 .
#
#  Demand point 3896 receives 7.51 of its demand 7.51 from parking slot 17 .
#
#  Demand point 3897 receives 7.42 of its demand 7.42 from parking slot 17 .
#
#  Demand point 3898 receives 7.45 of its demand 7.45 from parking slot 17 .
#
#  Demand point 3899 receives 6.19 of its demand 6.19 from parking slot 17 .
#
#  Demand point 3900 receives 3.74 of its demand 3.74 from parking slot 17 .
#
#  Demand point 3901 receives 2.12 of its demand 2.12 from parking slot 17 .
#
#  Demand point 3902 receives 45.63 of its demand 45.63 from parking slot 17 .
#
#  Demand point 3903 receives 51.83 of its demand 51.83 from parking slot 17 .
#
#  Demand point 3904 receives 44.75 of its demand 44.75 from parking slot 17 .
#
#  Demand point 3905 receives 0.81 of its demand 0.81 from parking slot 62 .
#
#  Demand point 3906 receives 0.88 of its demand 0.88 from parking slot 62 .
#
#  Demand point 3907 receives 0.96 of its demand 0.96 from parking slot 62 .
#
#  Demand point 3908 receives 1.02 of its demand 1.02 from parking slot 62 .
#
#  Demand point 3909 receives 1.11 of its demand 1.11 from parking slot 62 .
#
#  Demand point 3910 receives 1.52 of its demand 1.52 from parking slot 62 .
#
#  Demand point 3911 receives 1.84 of its demand 1.84 from parking slot 62 .
#
#  Demand point 3912 receives 1.69 of its demand 1.69 from parking slot 45 .
#
#  Demand point 3913 receives 1.89 of its demand 1.89 from parking slot 45 .
#
#  Demand point 3914 receives 1.95 of its demand 1.95 from parking slot 45 .
#
#  Demand point 3915 receives 0.3 of its demand 0.3 from parking slot 45 .
#
#  Demand point 3916 receives 5.68 of its demand 5.68 from parking slot 45 .
#
#  Demand point 3917 receives 8.35 of its demand 8.35 from parking slot 45 .
#
#  Demand point 3918 receives 6.33 of its demand 6.33 from parking slot 45 .
#
#  Demand point 3919 receives 6.33 of its demand 6.33 from parking slot 45 .
#
#  Demand point 3920 receives 5.3 of its demand 5.3 from parking slot 45 .
#
#  Demand point 3921 receives 6.17 of its demand 6.17 from parking slot 94 .
#
#  Demand point 3922 receives 4.89 of its demand 4.89 from parking slot 94 .
#
#  Demand point 3923 receives 3.32 of its demand 3.32 from parking slot 94 .
#
#  Demand point 3924 receives 5.63 of its demand 5.63 from parking slot 94 .
#
#  Demand point 3925 receives 6.55 of its demand 6.55 from parking slot 94 .
#
#  Demand point 3926 receives 6.94 of its demand 6.94 from parking slot 94 .
#
#  Demand point 3927 receives 6.88 of its demand 6.88 from parking slot 94 .
#
#  Demand point 3928 receives 5.44 of its demand 5.44 from parking slot 94 .
#
#  Demand point 3929 receives 4.61 of its demand 4.61 from parking slot 94 .
#
#  Demand point 3930 receives 3.86 of its demand 3.86 from parking slot 94 .
#
#  Demand point 3931 receives 3.01 of its demand 3.01 from parking slot 94 .
#
#  Demand point 3932 receives 3.38 of its demand 3.38 from parking slot 6 .
#
#  Demand point 3933 receives 7.16 of its demand 7.16 from parking slot 6 .
#
#  Demand point 3934 receives 5.11 of its demand 5.11 from parking slot 6 .
#
#  Demand point 3935 receives 6.65 of its demand 6.65 from parking slot 6 .
#
#  Demand point 3936 receives 6.87 of its demand 6.87 from parking slot 6 .
#
#  Demand point 3937 receives 11.83 of its demand 11.83 from parking slot 6 .
#
#  Demand point 3938 receives 11.87 of its demand 11.87 from parking slot 6 .
#
#  Demand point 3939 receives 11.76 of its demand 11.76 from parking slot 6 .
#
#  Demand point 3940 receives 11.75 of its demand 11.75 from parking slot 6 .
#
#  Demand point 3941 receives 10.75 of its demand 10.75 from parking slot 6 .
#
#  Demand point 3942 receives 8.42 of its demand 8.42 from parking slot 2 .
#
#  Demand point 3943 receives 9.4 of its demand 9.4 from parking slot 2 .
#
#  Demand point 3944 receives 10.85 of its demand 10.85 from parking slot 2 .
#
#  Demand point 3945 receives 9.86 of its demand 9.86 from parking slot 2 .
#
#  Demand point 3946 receives 6.23 of its demand 6.23 from parking slot 73 .
#
#  Demand point 3947 receives 11.02 of its demand 11.02 from parking slot 3 .
#
#  Demand point 3948 receives 10.55 of its demand 10.55 from parking slot 3 .
#
#  Demand point 3949 receives 7.86 of its demand 7.86 from parking slot 3 .
#
#  Demand point 3950 receives 9.96 of its demand 9.96 from parking slot 3 .
#
#  Demand point 3951 receives 9.46 of its demand 9.46 from parking slot 3 .
#
#  Demand point 3952 receives 10.43 of its demand 10.43 from parking slot 3 .
#
#  Demand point 3953 receives 11.01 of its demand 11.01 from parking slot 3 .
#
#  Demand point 3954 receives 11.79 of its demand 11.79 from parking slot 3 .
#
#  Demand point 3955 receives 10.64 of its demand 10.64 from parking slot 3 .
#
#  Demand point 3956 receives 9.19 of its demand 9.19 from parking slot 3 .
#
#  Demand point 3957 receives 8.36 of its demand 8.36 from parking slot 3 .
#
#  Demand point 3958 receives 6.87 of its demand 6.87 from parking slot 3 .
#
#  Demand point 3959 receives 5.26 of its demand 5.26 from parking slot 3 .
#
#  Demand point 3960 receives 8.4 of its demand 8.4 from parking slot 3 .
#
#  Demand point 3961 receives 5.96 of its demand 5.96 from parking slot 17 .
#
#  Demand point 3962 receives 7.33 of its demand 7.33 from parking slot 17 .
#
#  Demand point 3963 receives 8.28 of its demand 8.28 from parking slot 17 .
#
#  Demand point 3964 receives 6.4 of its demand 6.4 from parking slot 17 .
#
#  Demand point 3965 receives 3.53 of its demand 3.53 from parking slot 17 .
#
#  Demand point 3966 receives 2.3 of its demand 2.3 from parking slot 17 .
#
#  Demand point 3967 receives 9.47 of its demand 9.47 from parking slot 17 .
#
#  Demand point 3968 receives 53.8 of its demand 53.8 from parking slot 17 .
#
#  Demand point 3969 receives 0.84 of its demand 0.84 from parking slot 62 .
#
#  Demand point 3970 receives 1.01 of its demand 1.01 from parking slot 62 .
#
#  Demand point 3971 receives 0.91 of its demand 0.91 from parking slot 62 .
#
#  Demand point 3972 receives 1.07 of its demand 1.07 from parking slot 62 .
#
#  Demand point 3973 receives 1.07 of its demand 1.07 from parking slot 62 .
#
#  Demand point 3974 receives 1.39 of its demand 1.39 from parking slot 62 .
#
#  Demand point 3975 receives 2.02 of its demand 2.02 from parking slot 62 .
#
#  Demand point 3976 receives 2.4 of its demand 2.4 from parking slot 62 .
#
#  Demand point 3977 receives 2.45 of its demand 2.45 from parking slot 45 .
#
#  Demand point 3978 receives 2.17 of its demand 2.17 from parking slot 45 .
#
#  Demand point 3979 receives 5.46 of its demand 5.46 from parking slot 45 .
#
#  Demand point 3980 receives 6.49 of its demand 6.49 from parking slot 45 .
#
#  Demand point 3981 receives 7.26 of its demand 7.26 from parking slot 45 .
#
#  Demand point 3982 receives 5.21 of its demand 5.21 from parking slot 45 .
#
#  Demand point 3983 receives 5.88 of its demand 5.88 from parking slot 45 .
#
#  Demand point 3984 receives 5.15 of its demand 5.15 from parking slot 45 .
#
#  Demand point 3985 receives 4.78 of its demand 4.78 from parking slot 94 .
#
#  Demand point 3986 receives 4.98 of its demand 4.98 from parking slot 94 .
#
#  Demand point 3987 receives 5.33 of its demand 5.33 from parking slot 94 .
#
#  Demand point 3988 receives 5.85 of its demand 5.85 from parking slot 94 .
#
#  Demand point 3989 receives 6.67 of its demand 6.67 from parking slot 94 .
#
#  Demand point 3990 receives 8.38 of its demand 8.38 from parking slot 94 .
#
#  Demand point 3991 receives 7.57 of its demand 7.57 from parking slot 94 .
#
#  Demand point 3992 receives 5.88 of its demand 5.88 from parking slot 94 .
#
#  Demand point 3993 receives 2.82 of its demand 2.82 from parking slot 94 .
#
#  Demand point 3994 receives 2.28 of its demand 2.28 from parking slot 94 .
#
#  Demand point 3995 receives 1.86 of its demand 1.86 from parking slot 94 .
#
#  Demand point 3996 receives 2.42 of its demand 2.42 from parking slot 6 .
#
#  Demand point 3997 receives 4.16 of its demand 4.16 from parking slot 6 .
#
#  Demand point 3998 receives 7.52 of its demand 7.52 from parking slot 6 .
#
#  Demand point 3999 receives 10.36 of its demand 10.36 from parking slot 6 .
#
#  Demand point 4000 receives 6.32 of its demand 6.32 from parking slot 6 .
#
#  Demand point 4001 receives 11.07 of its demand 11.07 from parking slot 6 .
#
#  Demand point 4002 receives 11.68 of its demand 11.68 from parking slot 6 .
#
#  Demand point 4003 receives 7.24 of its demand 7.24 from parking slot 6 .
#
#  Demand point 4004 receives 11.01 of its demand 11.01 from parking slot 6 .
#
#  Demand point 4005 receives 11.22 of its demand 11.22 from parking slot 6 .
#
#  Demand point 4006 receives 8.12 of its demand 8.12 from parking slot 2 .
#
#  Demand point 4007 receives 7.65 of its demand 7.65 from parking slot 2 .
#
#  Demand point 4008 receives 10.89 of its demand 10.89 from parking slot 2 .
#
#  Demand point 4009 receives 10.16 of its demand 10.16 from parking slot 2 .
#
#  Demand point 4010 receives 7.58 of its demand 7.58 from parking slot 73 .
#
#  Demand point 4011 receives 11.04 of its demand 11.04 from parking slot 3 .
#
#  Demand point 4012 receives 10.5 of its demand 10.5 from parking slot 3 .
#
#  Demand point 4013 receives 8.18 of its demand 8.18 from parking slot 3 .
#
#  Demand point 4014 receives 7.57 of its demand 7.57 from parking slot 3 .
#
#  Demand point 4015 receives 7.24 of its demand 7.24 from parking slot 3 .
#
#  Demand point 4016 receives 7.67 of its demand 7.67 from parking slot 3 .
#
#  Demand point 4017 receives 9.42 of its demand 9.42 from parking slot 3 .
#
#  Demand point 4018 receives 10.74 of its demand 10.74 from parking slot 3 .
#
#  Demand point 4019 receives 11.77 of its demand 11.77 from parking slot 3 .
#
#  Demand point 4020 receives 11.02 of its demand 11.02 from parking slot 3 .
#
#  Demand point 4021 receives 10.48 of its demand 10.48 from parking slot 3 .
#
#  Demand point 4022 receives 9.25 of its demand 9.25 from parking slot 3 .
#
#  Demand point 4023 receives 6.8 of its demand 6.8 from parking slot 3 .
#
#  Demand point 4024 receives 4.67 of its demand 4.67 from parking slot 3 .
#
#  Demand point 4025 receives 3.78 of its demand 3.78 from parking slot 3 .
#
#  Demand point 4026 receives 5.09 of its demand 5.09 from parking slot 17 .
#
#  Demand point 4027 receives 6.42 of its demand 6.42 from parking slot 17 .
#
#  Demand point 4028 receives 6.13 of its demand 6.13 from parking slot 17 .
#
#  Demand point 4029 receives 3.05 of its demand 3.05 from parking slot 17 .
#
#  Demand point 4030 receives 1.88 of its demand 1.88 from parking slot 17 .
#
#  Demand point 4031 receives 3.5 of its demand 3.5 from parking slot 17 .
#
#  Demand point 4032 receives 5.55 of its demand 5.55 from parking slot 17 .
#
#  Demand point 4033 receives 0.94 of its demand 0.94 from parking slot 62 .
#
#  Demand point 4034 receives 1.02 of its demand 1.02 from parking slot 62 .
#
#  Demand point 4035 receives 0.95 of its demand 0.95 from parking slot 62 .
#
#  Demand point 4036 receives 1.17 of its demand 1.17 from parking slot 62 .
#
#  Demand point 4037 receives 1.23 of its demand 1.23 from parking slot 62 .
#
#  Demand point 4038 receives 1.42 of its demand 1.42 from parking slot 62 .
#
#  Demand point 4039 receives 2.32 of its demand 2.32 from parking slot 62 .
#
#  Demand point 4040 receives 3.42 of its demand 3.42 from parking slot 62 .
#
#  Demand point 4041 receives 3.11 of its demand 3.11 from parking slot 62 .
#
#  Demand point 4042 receives 5.5 of its demand 5.5 from parking slot 45 .
#
#  Demand point 4043 receives 6.21 of its demand 6.21 from parking slot 45 .
#
#  Demand point 4044 receives 6.2 of its demand 6.2 from parking slot 45 .
#
#  Demand point 4045 receives 4.76 of its demand 4.76 from parking slot 45 .
#
#  Demand point 4046 receives 4.44 of its demand 4.44 from parking slot 45 .
#
#  Demand point 4047 receives 3.86 of its demand 3.86 from parking slot 45 .
#
#  Demand point 4048 receives 3.95 of its demand 3.95 from parking slot 45 .
#
#  Demand point 4049 receives 4.36 of its demand 4.36 from parking slot 94 .
#
#  Demand point 4050 receives 3.49 of its demand 3.49 from parking slot 94 .
#
#  Demand point 4051 receives 6.76 of its demand 6.76 from parking slot 94 .
#
#  Demand point 4052 receives 7.65 of its demand 7.65 from parking slot 94 .
#
#  Demand point 4053 receives 7.53 of its demand 7.53 from parking slot 94 .
#
#  Demand point 4054 receives 8.07 of its demand 8.07 from parking slot 94 .
#
#  Demand point 4055 receives 7.82 of its demand 7.82 from parking slot 94 .
#
#  Demand point 4056 receives 7.83 of its demand 7.83 from parking slot 94 .
#
#  Demand point 4057 receives 4.26 of its demand 4.26 from parking slot 94 .
#
#  Demand point 4058 receives 2.82 of its demand 2.82 from parking slot 94 .
#
#  Demand point 4059 receives 2.1 of its demand 2.1 from parking slot 6 .
#
#  Demand point 4060 receives 1.58 of its demand 1.58 from parking slot 6 .
#
#  Demand point 4061 receives 3.05 of its demand 3.05 from parking slot 6 .
#
#  Demand point 4062 receives 7.93 of its demand 7.93 from parking slot 6 .
#
#  Demand point 4063 receives 8.36 of its demand 8.36 from parking slot 6 .
#
#  Demand point 4064 receives 6.9 of its demand 6.9 from parking slot 6 .
#
#  Demand point 4065 receives 11.22 of its demand 11.22 from parking slot 6 .
#
#  Demand point 4066 receives 11.58 of its demand 11.58 from parking slot 6 .
#
#  Demand point 4067 receives 11.89 of its demand 11.89 from parking slot 6 .
#
#  Demand point 4068 receives 11.36 of its demand 11.36 from parking slot 6 .
#
#  Demand point 4069 receives 10.29 of its demand 10.29 from parking slot 6 .
#
#  Demand point 4070 receives 8.09 of its demand 8.09 from parking slot 6 .
#
#  Demand point 4071 receives 8.36 of its demand 8.36 from parking slot 2 .
#
#  Demand point 4072 receives 10.56 of its demand 10.56 from parking slot 2 .
#
#  Demand point 4073 receives 11.0 of its demand 11.0 from parking slot 2 .
#
#  Demand point 4074 receives 11.21 of its demand 11.21 from parking slot 2 .
#
#  Demand point 4075 receives 11.21 of its demand 11.21 from parking slot 3 .
#
#  Demand point 4076 receives 11.2 of its demand 11.2 from parking slot 3 .
#
#  Demand point 4077 receives 8.4 of its demand 8.4 from parking slot 3 .
#
#  Demand point 4078 receives 7.61 of its demand 7.61 from parking slot 3 .
#
#  Demand point 4079 receives 6.45 of its demand 6.45 from parking slot 3 .
#
#  Demand point 4080 receives 8.71 of its demand 8.71 from parking slot 3 .
#
#  Demand point 4081 receives 10.23 of its demand 10.23 from parking slot 3 .
#
#  Demand point 4082 receives 12.15 of its demand 12.15 from parking slot 3 .
#
#  Demand point 4083 receives 10.48 of its demand 10.48 from parking slot 3 .
#
#  Demand point 4084 receives 10.95 of its demand 10.95 from parking slot 3 .
#
#  Demand point 4085 receives 8.34 of its demand 8.34 from parking slot 3 .
#
#  Demand point 4086 receives 8.84 of its demand 8.84 from parking slot 3 .
#
#  Demand point 4087 receives 6.63 of its demand 6.63 from parking slot 3 .
#
#  Demand point 4088 receives 3.61 of its demand 3.61 from parking slot 3 .
#
#  Demand point 4089 receives 2.64 of its demand 2.64 from parking slot 3 .
#
#  Demand point 4090 receives 4.13 of its demand 4.13 from parking slot 3 .
#
#  Demand point 4091 receives 7.83 of its demand 7.83 from parking slot 17 .
#
#  Demand point 4092 receives 5.43 of its demand 5.43 from parking slot 17 .
#
#  Demand point 4093 receives 2.06 of its demand 2.06 from parking slot 17 .
#
#  Demand point 4094 receives 3.22 of its demand 3.22 from parking slot 17 .
#
#  Demand point 4095 receives 6.26 of its demand 6.26 from parking slot 17 .
#
#  Demand point 4096 receives 6.86 of its demand 6.86 from parking slot 17 .

# %%
total_supply = 0
for j in range(num_facilities):
    total_supply += slow[j].solution_value()*200 + fast[j].solution_value()*400

# %%
sum(demands), total_supply
# Out:
# (361529.6365968905, 429600.0)

# %%
total_demand = 0.0
for i in range(num_customers):
    for j in range(num_facilities):
        total_demand += assign[(i,j)].solution_value()

# %%
sum(demands), total_demand
# Out:
# (361529.6365968905, 361529.6365968906)
